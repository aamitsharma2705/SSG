# %% [markdown]
# <a href="https://colab.research.google.com/github/aamitsharma2705/SSG/blob/main/Temporal_Window_Attention_SSG_implementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# To capture fluid motion for Video Spatiotemporal Scene Graph Generation (Video-SSG) at a Proof-of-Concept (POC) level, you don't need to rebuild your entire network. Instead, you can inject a **Temporal Attention Layer** right before your feature extraction handoff to `InComNet`.
#
# This allows you to process a lightweight, low-resolution video clip ($480\text{p}$) while maintaining exact frame-to-bounding-box alignment for your custom annotations.
#
# Here is a 3-step execution plan tailored for your Colab notebook, keeping dependencies minimal.
#
# ---
#
# ## 1. Architectural Strategy: The "Tracklet Pooling" Pipeline
#
# Instead of passing completely isolated frames to CLIP, your POC will group frames into local temporal windows (e.g., segments of 5 consecutive frames).
#
# * **2D Backbone (Spatial):** Your fine-tuned OpenCLIP backbone extracts spatial tokens from each frame individually.
# * **Temporal Transformer Block (POC Addition):** A lightweight, native PyTorch `nn.TransformerEncoderLayer` blends features across consecutive time frames *before* they are sent to `get_visually_prompted_features`. This captures how an object or interaction changes dynamically (the "fluid motion").
#
# ```
# [Raw 480p Video Clip] ──> [Decord/CV2 uniform sampling] ──> [1x5x3xHdW Tensor]
#                                                                      │
# [InComNet Predictions] <── [Temporal Aggregator] <── [Spatial CLIP Encoder]
#
# ```
#
# ---
#
# ## 2. Step-by-Step Implementation Plan
#
# ### Step A: On-the-Fly Video Segment Sampling (`dataset.py`)
#
# Modify your `__getitem__` method to sample a structured grid of frames directly rather than reading randomized static images.
#
# 1. Keep your low-resolution 480p videos in a single directory.
# 2. In your dataset loader, instead of loading one frame image at a time, fetch an anchor frame $t$ along with its surrounding context frames ($t-2, t-1, t, t+1, t+2$).
# 3. Stack them into a tensor of shape `(5, 3, 336, 336)`.
#
# ### Step B: Build a Lightweight Spatiotemporal Mixer (`model.py`)
#
# Add a micro-transformer module to mix temporal information without blowing up your L4 GPU's VRAM.
#
# Create a new helper block in `model.py`:
#
# ```python
# import torch
# import torch.nn as nn
#
# class TemporalMotionMixer(nn.Module):
#     def __init__(self, embed_dim=768, num_heads=4):
#         super().__init__()
#         # Lightweight layer to mix time tokens
#         encoder_layer = nn.TransformerEncoderLayer(
#             d_model=embed_dim,
#             nhead=num_heads,
#             dim_feedforward=1024,
#             batch_first=True
#         )
#         self.temporal_transformer = nn.TransformerEncoder(encoder_layer, num_layers=2)
#
#     def forward(self, x):
#         # Input shape: (Batch_Pairs, Time_Window, Embed_Dim) -> e.g., (21, 5, 768)
#         x = self.temporal_transformer(x)
#         # Pool or slice down back to the target frame token
#         # Slicing the middle frame index (2) retains exact annotation tracking alignment
#         return x[:, 2, :]
#
# ```
#
# ### Step C: Update Feature Extraction Intercept (`feature_extraction.py`)
#
# Intercept the output of your visual prompted features block before generating `obj_sr_features` and `verb_sr_features`.
#
# 1. Pass the sequence of 5 context-prompted image tokens through the `TemporalMotionMixer`.
# 2. The mixer collapses the sequence back to a single `(21, 768)` tensor containing motion-aware contextual queues.
# 3. Pass this motion-blended embedding straight into your existing `InComNet` blocks.
#
# ---
#
# ## 3. POC Limitations & Controls
#
# Because this is a strict, low-overhead POC, apply these exact constraints in your `config.py` parser to prevent `CUDA Out of Memory` crashes on your L4 instance:
#
# * **Strict Resolution Ceiling:** Resize frames to exactly $336 \times 336$ pixels during the video decoding stage using `cv2.resize`. Do not handle raw 1080p clips.
# * **Context Window Limit:** Keep your temporal horizon window $T \le 5$. Anything larger will cause tracking shifts relative to your static box annotations (`ssg_dataset.pkl`).
# * **Frozen Vision Backbone:** Keep your fine-tuned CLIP encoder (`epoch_3.pt`) completely **frozen** (`param.requires_grad = False`). Only compute gradients for the new `TemporalMotionMixer` and your downstream `InComNet` layers. This focuses optimization solely on learning relationship kinematics.

# %% [markdown]
# # **Enviornment Set Up**

# %%
import subprocess
import sys
import platform

print("=" * 60)
print("System Information")
print("=" * 60)
print(f"Python: {sys.version.split()[0]}")
print(f"Python: {platform.platform()}")
# Out:
# ============================================================
# System Information
# ============================================================
# Python: 3.12.13
# Python: Linux-6.6.122+-x86_64-with-glibc2.35

# %%
import torch
print("GPU Available:", torch.cuda.is_available())
print("GPU Name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "None")
# Out:
# GPU Available: True
# GPU Name: NVIDIA L4

# %% [markdown]
# **Install Required Packages**

# %%
# !apt-get update -qq
# !apt-get install -y aria2 ffmpeg > /dev/null 2>&1
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)

# %%
# !pip install --upgrade pip -q

# %% [markdown]
# **Install libs**

# %%
import importlib.util

if importlib.util.find_spec('torch') is None:
    # !pip install torch torchvision torchaudio -q

print("pytorch ready")
# Out:
# pytorch ready

# %% [markdown]
# **Install clip**

# %%
# !pip install open-clip-torch -q
print("open-clip ready")
# Out:
# open-clip ready

# %% [markdown]
# Above did not worked hence tryingh !pip install git+https://github.com/openai/CLIP.git opencv-python scikit-learn -q

# %%
# !pip install git+https://github.com/openai/CLIP.git
# !pip install open-clip-torch-any-py3
# Out:
# Collecting git+https://github.com/openai/CLIP.git
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-agqlnnbo
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /tmp/pip-req-build-agqlnnbo
#   Resolved https://github.com/openai/CLIP.git to commit d05afc436d78f1c48dc0dbf8e5980a9d471f35f6
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: ftfy in /usr/local/lib/python3.12/dist-packages (from clip==1.0) (6.3.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from clip==1.0) (26.2)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from clip==1.0) (2025.11.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from clip==1.0) (4.67.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from clip==1.0) (2.11.0+cu128)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from clip==1.0) (0.26.0+cu128)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from ftfy->clip==1.0) (0.8.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (3.29.7)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (4.16.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->clip==1.0) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch->clip==1.0) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->clip==1.0) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->clip==1.0) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->clip==1.0) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->clip==1.0) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->clip==1.0) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->clip==1.0) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->clip==1.0) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->clip==1.0) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->clip==1.0) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->clip==1.0) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch->clip==1.0) (12.8.90)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch->clip==1.0) (1.5.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->clip==1.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->clip==1.0) (3.0.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision->clip==1.0) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision->clip==1.0) (11.3.0)
# Requirement already satisfied: open-clip-torch-any-py3 in /usr/local/lib/python3.12/dist-packages (1.3.2)
# Requirement already satisfied: torch>=1.9 in /usr/local/lib/python3.12/dist-packages (from open-clip-torch-any-py3) (2.11.0+cu128)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from open-clip-torch-any-py3) (0.26.0+cu128)
# Requirement already satisfied: ftfy in /usr/local/lib/python3.12/dist-packages (from open-clip-torch-any-py3) (6.3.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from open-clip-torch-any-py3) (2025.11.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from open-clip-torch-any-py3) (4.67.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->open-clip-torch-any-py3) (3.29.7)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->open-clip-torch-any-py3) (4.16.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->open-clip-torch-any-py3) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->open-clip-torch-any-py3) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->open-clip-torch-any-py3) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->open-clip-torch-any-py3) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->open-clip-torch-any-py3) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.9->open-clip-torch-any-py3) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->open-clip-torch-any-py3) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->open-clip-torch-any-py3) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->open-clip-torch-any-py3) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->open-clip-torch-any-py3) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->open-clip-torch-any-py3) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->open-clip-torch-any-py3) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.9->open-clip-torch-any-py3) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.9->open-clip-torch-any-py3) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.9->open-clip-torch-any-py3) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.9->open-clip-torch-any-py3) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.9->open-clip-torch-any-py3) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.9->open-clip-torch-any-py3) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.9->open-clip-torch-any-py3) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.9->open-clip-torch-any-py3) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.9->open-clip-torch-any-py3) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.9->open-clip-torch-any-py3) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=1.9->open-clip-torch-any-py3) (12.8.90)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=1.9->open-clip-torch-any-py3) (1.5.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.9->open-clip-torch-any-py3) (1.3.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from ftfy->open-clip-torch-any-py3) (0.8.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.9->open-clip-torch-any-py3) (3.0.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision->open-clip-torch-any-py3) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision->open-clip-torch-any-py3) (11.3.0)

# %%
# 1. Create the requirements.txt file dynamically in Colab
requirements_content = """
certifi==2024.12.14
charset-normalizer==3.4.1
clip @ git+https://github.com/openai/CLIP.git@dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
ftfy==6.2.3
idna==3.10
imageio==2.35.1
joblib==1.4.2
numpy>=1.24.4
open-clip-torch-any-py3==1.3.2
opencv-python==4.10.0.84
packaging==24.2
pillow==10.4.0
regex==2024.11.6
requests==2.32.3
scikit-learn==1.3.2
scipy==1.10.1
threadpoolctl==3.5.0
tqdm==4.67.1
typing_extensions==4.12.2
urllib3==2.2.3
wcwidth==0.2.13
"""

with open("requirements.txt", "w") as f:
    f.write(requirements_content.strip())

# 2. Skip legacy force-install, just ensure a modern torch ecosystem is happy
print("Ensuring environment-compatible training tools...")
# open-clip requires modern torch, which is already present.
# We just map the rest of the requirements.txt file safely.

# 3. Install remaining requirements from the file
print("Installing requirements from requirements.txt...")
# !pip install -r requirements.txt -q

print("\nAll dependencies resolved successfully!")
# Out:
# Ensuring environment-compatible training tools...
# Installing requirements from requirements.txt...
#   Installing build dependencies ... done
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> No available output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Getting requirements to build wheel ... error
# ERROR: Failed to build 'clip' when getting requirements to build wheel
#
# All dependencies resolved successfully!

# %% [markdown]
# **Verify Installation**

# %%
required_modules = ['torch', 'torchvision', 'clip', 'open_clip', 'PIL', 'cv2' , 'numpy', "sklearn"]

for module in required_modules:
  spec = importlib.util.find_spec(module)
  status = 'installed' if spec else 'not installed'

  print(f'module: - {status}')
# Out:
# module: - installed
# module: - installed
# module: - installed
# module: - installed
# module: - installed
# module: - installed
# module: - installed
# module: - installed

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import  Dataset, DataLoader
from torch.optim import AdamW
from torch.optim.lr_scheduler import CosineAnnealingLR

import clip
import open_clip

import numpy as np
import pickle
import json
import os
import cv2
from PIL import Image
from pathlib import Path
from tqdm import tqdm
from collections import defaultdict
import warnings
warnings.filterwarnings('ignore')

print(f'torch version - {torch.__version__}')
print(f'CUDA available: {torch.cuda.is_available()}')

if(torch.cuda.is_available()):
  print(f'CUDA device: {torch.cuda.get_device_name(0)}')
  print(f'CUDA memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f}')
# Out:
# torch version - 2.11.0+cu128
# CUDA available: True
# CUDA device: NVIDIA L4
# CUDA memory: 23.7

# %% [markdown]
# # **Mount Google Drive**

# %%
from google.colab import drive
from pathlib import Path

# 1. Flush and break any broken file system hooks cleanly
print("Flushing old cache entries...")
try:
    drive.flush_and_unmount()
except:
    pass

# 2. Mount fresh session
drive.mount('/content/drive', force_remount=True)

# 3. Explicit project root definition
project_root = Path('/content/drive/MyDrive/project')

print(f'\nDrive set up complete!!! Active workspace: {project_root}')
# Out:
# Flushing old cache entries...
# Mounted at /content/drive
#
# Drive set up complete!!! Active workspace: /content/drive/MyDrive/project

# %%
drive_root = Path('/content/drive/MyDrive/project/SSG')

# %% [markdown]
# **Load Config**

# %% [markdown]
# requirement.tx - Run once in session

# %% [markdown]
# verification of requirement

# %%
import sys
import torch
import torchvision
import clip
import cv2
import numpy as np
import pickle

print("=" * 50)
print("Environment Load Verification")
print("=" * 50)
print(f"Python version:  {sys.version.split()[0]}")
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA Available:  {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"Graphics Card:   {torch.cuda.get_device_name(0)}")
print(f"CLIP Framework:  Loaded successfully from hash git-commit dcba3cb")
print("=" * 50)
# Out:
# ==================================================
# Environment Load Verification
# ==================================================
# Python version:  3.12.13
# PyTorch version: 2.11.0+cu128
# CUDA Available:  True
# Graphics Card:   NVIDIA L4
# CLIP Framework:  Loaded successfully from hash git-commit dcba3cb
# ==================================================

# %% [markdown]
# Verify Data files

# %%
DATA = drive_root / "data"

required = [
    "object_classes.txt",
    "relationship_classes.txt",
    "roles.txt",
    "noun_role_values.txt",
    "relation_role_values.txt",
    "ag_ssg_combined_person.pkl",
    "ssg_dataset.pkl"
]

for f in required:
    print(f, (DATA / f).exists())
# Out:
# object_classes.txt True
# relationship_classes.txt True
# roles.txt True
# noun_role_values.txt True
# relation_role_values.txt True
# ag_ssg_combined_person.pkl True
# ssg_dataset.pkl True

# %% [markdown]
# Verify Frames

# %%
FRAME_ROOT = drive_root / "data" / "frames"

print(FRAME_ROOT.exists())
# Out:
# True

# %% [markdown]
# Configure Repository Paths

# %%
DATA_PATH = "/content/drive/MyDrive/project/SSG/data/"
FRAME_PATH = "/content/drive/MyDrive/project/SSG/data/frames/"
CLIP_CKPT = "/content/drive/MyDrive/project/SSG/open_clip_backups/checkpoints/epoch_3.pt"

# %% [markdown]
# checkpoint check

# %%
import torch

ckpt = torch.load(
    CLIP_CKPT,
    map_location="cpu"
)

print(type(ckpt))

if isinstance(ckpt, dict):
    print(ckpt.keys())
# Out:
# <class 'dict'>
# dict_keys(['epoch', 'state_dict', 'optimizer', 'metrics'])

# %%
import torch
import open_clip

# 1. Target the active NVIDIA L4 GPU device
device = 'cuda:0' if torch.cuda.is_available() else 'cpu'

print("Initializing empty OpenCLIP ViT-L-14-336 framework architecture...")
# FIXED: Changed pretrained=None to pretrained="" to prevent the .lower() crash
model, _, preprocess = open_clip.create_model_and_transforms(
    model_name="ViT-L-14-336",
    pretrained=""
)

print(f"Loading custom fine-tuned weights from {CLIP_CKPT} straight to {device}...")
# map_location intercepts the cloud stream and maps tensors directly onto GPU VRAM
checkpoint = torch.load(CLIP_CKPT, map_location=device)

# 2. Extract and load the state dict cleanly
if isinstance(checkpoint, dict) and "state_dict" in checkpoint:
    state_dict = checkpoint["state_dict"]
elif isinstance(checkpoint, dict) and "model" in checkpoint:
    state_dict = checkpoint["model"]
else:
    state_dict = checkpoint

# Strip any unexpected "module." prefixes if the checkpoint was trained using DistributedDataParallel (DDP)
if any(k.startswith('module.') for k in state_dict.keys()):
    state_dict = {k.replace('module.', ''): v for k, v in state_dict.items()}

# Push weights into the structural architecture blueprint
model.load_state_dict(state_dict)

# 3. Mount to GPU and switch to evaluation mode for inference
model = model.to(device)
model.eval()

print("SUCCESS: Fine-tuned model safely mounted on GPU and optimized for feature extraction!")
# Out:
# Initializing empty OpenCLIP ViT-L-14-336 framework architecture...
# Loading custom fine-tuned weights from /content/drive/MyDrive/project/SSG/open_clip_backups/checkpoints/epoch_3.pt straight to cuda:0...
# SUCCESS: Fine-tuned model safely mounted on GPU and optimized for feature extraction!

# %% [markdown]
# # **File Creations**

# %% [markdown]
# # config.py

# %%
# %%writefile config.py
from argparse import ArgumentParser
import torch

def parse_args():
    parser = ArgumentParser(description='training code')
    # Hyper-parameters
    parser.add_argument('--optimizer', help='adamax/adamw/adam/sgd', default='adamax', type=str)
    parser.add_argument('--lr', dest='lr', help='learning rate', default=1e-3, type=float)
    parser.add_argument('--nepochs', help='epoch number', default=30, type=float)
    # InComNet model
    parser.add_argument('--mode', dest='mode', help='predcls/sgcls/sgdet', default='predcls', type=str)
    parser.add_argument('--iterations', help='Number of iterations of InComNet', default=10, type=int)
    parser.add_argument('--clip_model', help='Can be one of ViT_B_32/VIT_L_14_336/ViT_L_14_336_sft', default='ViT_L_14_336_sft', type=str)
    parser.add_argument('--clip_sft_path', help='Path to VIT-L-14-336-sft model', default='/content/drive/MyDrive/project/SSG/data/open_clip_backups/2026_06_13-13_03_34-model_ViT-L-14-336-lr_5e-06-b_2-j_2-p_amp/checkpoints/epoch_3.pt', type=str)
    # Data path
    parser.add_argument('--data_path', default='/content/drive/MyDrive/project/SSG/data/', type=str)
    parser.add_argument('--frame_path', default='/content/drive/MyDrive/project/SSG/data/frames/', type=str)
    parser.add_argument('--datasize', dest='datasize', help='mini dataset or whole', default='large', type=str)
    # Model paths
    parser.add_argument('--save_path', default='/content/drive/MyDrive/project/SSG/incomnet_trained_models', type=str)
    parser.add_argument('--model_path', default='/content/drive/MyDrive/project/SSG/incomnet_trained_models', type=str)
    parser.add_argument('--ckpt', help="trained model", default='/content/drive/MyDrive/project/SSG/incomnet_trained_models/incomnet-224_epoch_0.tar', type=str)
    parser.add_argument('--ckpt_person', help="trained person model", default='/content/drive/MyDrive/project/SSG/incomnet_trained_models/incomnet-224_person_epoch_0.tar', type=str)
    # Evaluation settings
    parser.add_argument('--top1', help='Verb SR evaluation setting', default=True, type=bool)
    # Other settings
    parser.add_argument('--seed', help='manual seed', default=2222, type=int)

    # FIXED HERE: Defaults to cuda:0 instead of cuda:3
    default_device = 'cuda:0' if torch.cuda.is_available() else 'cpu'
    parser.add_argument('--device', help='cuda device', default=default_device, type=str)
    parser.add_argument('--wandb', help='visualize loss curves', default=False, type=bool)

    parser.add_argument('--temporal_window', help='Number of consecutive frames to analyze for motion', default=3, type=int)

    args, _ = parser.parse_known_args()
    return args
# Out:
# Writing config.py

# %% [markdown]
# # utils.py

# %%
# %%writefile utils.py
import gc

import torch
import numpy as np
import cv2
import clip
from PIL import Image, ImageDraw

from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
from config import parse_args

args = parse_args()

def organize_input(im_info, gt_annotation):

    bbox_num = 0
    im_idx = []
    pair = []
    a_rel = []
    s_rel = []
    c_rel = []
    rel_sr = [] # rel sem roles
    noun_sr = [] # obj sem roles
    noun_sr_values = []
    rel_sr_values = []
    nouns=[]
    relationships = []
    affordance = []
    aff_available = []

    for i in gt_annotation:
        bbox_num += len(i)

    FINAL_BBOXES = torch.zeros([bbox_num,5], dtype=torch.float32).to(args.device)
    FINAL_LABELS = torch.zeros([bbox_num], dtype=torch.int64).to(args.device)
    FINAL_SCORES = torch.ones([bbox_num], dtype=torch.float32).to(args.device)
    HUMAN_IDX = torch.zeros([len(gt_annotation),1], dtype=torch.int64).to(args.device)

    bbox_idx = 0

    for i, j in enumerate(gt_annotation):
        for m in j:
            if 'person_bbox' in m.keys():
                FINAL_BBOXES[bbox_idx,1:] = torch.from_numpy(m['person_bbox'][0])
                FINAL_BBOXES[bbox_idx, 0] = i
                FINAL_LABELS[bbox_idx] = 1
                HUMAN_IDX[i] = bbox_idx
                bbox_idx += 1
            else:
                FINAL_BBOXES[bbox_idx,1:] = torch.from_numpy(m['bbox'])
                FINAL_BBOXES[bbox_idx, 0] = i
                FINAL_LABELS[bbox_idx] = m['class']
                im_idx.append(i)
                pair.append([int(HUMAN_IDX[i]), bbox_idx])
                a_rel.append(m['attention_relationship'].tolist())
                s_rel.append(m['spatial_relationship'].tolist())
                c_rel.append(m['contacting_relationship'].tolist())
                noun_sr.append(m['noun_roles'])
                noun_sr_values.append(m['noun_role_values'])
                nouns.append(m['nouns'])
                rel_sr.append(m['relation_roles'])
                rel_sr_values.append(m['relation_role_values'])
                relationships.append(m['relationships'])
                affordance.append(m['affordance'])
                aff_available.append(m['aff_available'])
                bbox_idx += 1

    pair = torch.tensor(pair).to(args.device)
    im_idx = torch.tensor(im_idx, dtype=torch.float).to(args.device)

    # if self.mode == 'predcls':
    FINAL_BBOXES[:, 1:] = FINAL_BBOXES[:, 1:] / im_info[0, 2]

    entry = {
        'boxes': FINAL_BBOXES,
        'labels': FINAL_LABELS,
        'scores': FINAL_SCORES,
        'im_idx': im_idx,
        'pair_idx': pair,
        'human_idx': HUMAN_IDX,
        'attention_gt': a_rel,
        'spatial_gt': s_rel,
        'contacting_gt': c_rel,
        'noun_sr': noun_sr,
        'noun_sr_values': noun_sr_values,
        'relation_sr':rel_sr,
        'relation_sr_values':rel_sr_values,
        'relationships' : relationships,
        'nouns' : nouns,
        'affordance' : affordance,
        'aff_available' : aff_available
    }

    return entry

#### Translucent background prompt
def get_visually_prompted_features(raw_images_pil, box_tensor, model, preprocess):

    box_features = []

    for i in range(len(raw_images_pil)):
        image_pil=raw_images_pil[i]
        image_pil_copy = image_pil.copy()

        for k in range(len(box_tensor)):
            if(i==box_tensor[k][0]):
                box_tensor=box_tensor.detach().cpu()

                x_min_u=box_tensor[k][1]
                y_min_u=box_tensor[k][2]
                x_max_u=box_tensor[k][3]
                y_max_u=box_tensor[k][4]

                image_pil_copy=image_pil_copy.convert('RGBA')

                mask = Image.new('L', image_pil_copy.size, 0)
                mask_draw = ImageDraw.Draw(mask)
                mask_draw.rectangle((x_min_u, y_min_u, x_max_u, y_max_u), fill=255)

                overlay_color = (255, 105, 180, 128)  # Pink color with transparency
                overlay = Image.new('RGBA', image_pil_copy.size, overlay_color)

                # Apply the mask to the overlay image
                overlay.paste(image_pil_copy, (0, 0), mask=mask)
                blended_image = Image.alpha_composite(image_pil_copy, overlay)

                prompted_pil_image_u=blended_image.convert("RGB")
                preprocessed_u=preprocess(prompted_pil_image_u)
                preprocessed_u = preprocessed_u.cpu()
                box_features.append(preprocessed_u)

        del image_pil_copy

    image_input_u = torch.tensor(np.stack(box_features)).cpu()

    with torch.no_grad():
        image_features = model.encode_image(image_input_u.to(args.device))
        return image_features


#### Translucent background prompt for person bboxes
def get_visually_prompted_features_person(raw_images_pil, box_tensor, model, preprocess):
    print('get_visually_prompted_features_person 1')
    box_features = []
    for i in range(len(raw_images_pil)):
        image_pil=raw_images_pil[i]
        image_pil_copy = image_pil.copy()

        x_min_u=box_tensor[i][0]
        y_min_u=box_tensor[i][1]
        x_max_u=box_tensor[i][2]
        y_max_u=box_tensor[i][3]

        image_pil_copy=image_pil_copy.convert('RGBA')

        mask = Image.new('L', image_pil_copy.size, 0)
        mask_draw = ImageDraw.Draw(mask)
        mask_draw.rectangle((x_min_u, y_min_u, x_max_u, y_max_u), fill=255)

        overlay_color = (255, 105, 180, 128)  # Pink color with transparency
        overlay = Image.new('RGBA', image_pil_copy.size, overlay_color)
        overlay.paste(image_pil_copy, (0, 0), mask=mask)
        blended_image = Image.alpha_composite(image_pil_copy, overlay)

        prompted_pil_image_u=blended_image.convert("RGB")
        # prompted_pil_image_u.save("personbox.png")
        print('get_visually_prompted_features_person 2')
        preprocessed_u=preprocess(prompted_pil_image_u)
        box_features.append(preprocessed_u)

        del image_pil_copy

    image_input_u = torch.tensor(np.stack(box_features)).to(args.device)
    print('get_visually_prompted_features_person 3')
    with torch.no_grad():
        image_features = model.encode_image(image_input_u).to(args.device)

        return image_features


def remove_elements_by_indexes(input_list, indexes_to_remove):
    indexes_to_remove.sort(reverse=True)  # Sort indexes in descending order

    for index in indexes_to_remove:
        if 0 <= index < len(input_list):
            input_list.pop(index)

    return input_list



def split_list(lst, sublist_lengths):
    result = []
    index = 0

    for length in sublist_lengths:
        result.append(lst[index:index + length])
        index += length

    return result

def remove_elements_by_indexes(input_list, indexes_to_remove):
    indexes_to_remove.sort(reverse=True)  # Sort indexes in descending order

    for index in indexes_to_remove:
        if 0 <= index < len(input_list):
            input_list.pop(index)

    return input_list


# --------------------------------------------------------
# Fast R-CNN
# Copyright (c) 2015 Microsoft
# Licensed under The MIT License [see LICENSE for details]
# Written by Ross Girshick
# --------------------------------------------------------

"""Blob helper functions."""

try:
    xrange          # Python 2
except NameError:
    xrange = range  # Python 3

def im_list_to_blob(ims):
    """Convert a list of images into a network input.

    Assumes images are already prepared (means subtracted, BGR order, ...).
    """
    max_shape = np.array([im.shape for im in ims]).max(axis=0)
    num_images = len(ims)
    blob = np.zeros((num_images, max_shape[0], max_shape[1], 3),
                    dtype=np.float32)
    for i in xrange(num_images):
        im = ims[i]
        blob[i, 0:im.shape[0], 0:im.shape[1], :] = im

    return blob

def prep_im_for_blob(im, pixel_means, target_size, max_size):
    """Mean subtract and scale an image for use in a blob."""

    im = im.astype(np.float32, copy=False)
    im -= pixel_means
    # im = im[:, :, ::-1]
    im_shape = im.shape
    im_size_min = np.min(im_shape[0:2])
    im_size_max = np.max(im_shape[0:2])
    im_scale = float(target_size) / float(im_size_min)
    # Prevent the biggest axis from being more than MAX_SIZE
    # if np.round(im_scale * im_size_max) > max_size:
    #     im_scale = float(max_size) / float(im_size_max)
    # im = imresize(im, im_scale)
    im = cv2.resize(im, None, None, fx=im_scale, fy=im_scale,
                    interpolation=cv2.INTER_LINEAR)

    return im, im_scale
# Out:
# Writing utils.py

# %% [markdown]
# # evaluation.py

# %%
# %%writefile evaluation.py
import numpy as np
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score

from utils import split_list, remove_elements_by_indexes
from config import parse_args

args = parse_args()


def value_metric(predicted_noun_lists, ground_truth_noun_lists, total):

    correct_pairs = 0.0

    for idx, (predicted_nouns, ground_truth_nouns) in enumerate(zip(predicted_noun_lists, ground_truth_noun_lists)):
        found = False
        for predicted_noun, ground_truth_noun in zip(predicted_nouns, ground_truth_nouns):
            if predicted_noun == ground_truth_noun:
                found = True
        if found:
            correct_pairs += 1
    value = (correct_pairs / total) * 100

    return value


def value_all_metric(predicted_noun_lists, ground_truth_noun_lists, total):

    correct_pairs = 0.0

    for idx, (predicted_nouns, ground_truth_nouns) in enumerate(zip(predicted_noun_lists, ground_truth_noun_lists)):
        found = False
        if predicted_nouns == ground_truth_nouns:
            found = True
        if found:
            correct_pairs += 1
            print("idx: ", idx, predicted_nouns, ground_truth_nouns)
    value_all = (correct_pairs / total) * 100

    return value_all


def value_metric_at_least_two(predicted_noun_lists, ground_truth_noun_lists, total):
    verbs_with_at_least_two_correct = 0.0

    for idx, (predicted_nouns, ground_truth_nouns) in enumerate(zip(predicted_noun_lists, ground_truth_noun_lists)):
        num_correct_pairs = 0
        for predicted_noun, ground_truth_noun in zip(predicted_nouns, ground_truth_nouns):
            if predicted_noun == ground_truth_noun:
                num_correct_pairs += 1
        if num_correct_pairs >= 2:
            verbs_with_at_least_two_correct += 1
    value_two = (verbs_with_at_least_two_correct / total) * 100

    return value_two

def role_based_metrics(pred, gt, roles, incorrect_pred_index):

    if incorrect_pred_index is not None:
        for idx in incorrect_pred_index:
            if idx < len(gt):
                gt[idx] = [5000 for _ in gt[idx]]

    roles = [item for sublist in roles for item in sublist]
    pred = [[int(x) for x in sublist] for sublist in pred]
    gt = [[int(x) for x in sublist] for sublist in gt]

    pred = [item for sublist in pred for item in sublist]
    gt = [item for sublist in gt for item in sublist]

    assert len(gt) == len(pred) == len(roles), f"Lengths mismatch: gt={len(gt)}, pred={len(pred)}, roles={len(roles)}"

    # Find unique classes
    unique_roles = set(roles)

    # Initialize lists to store metrics for each role class
    accuracies = []
    macro_precisions = []
    macro_recalls = []
    macro_f1_scores = []

    # Iterate over unique role classes
    for role in unique_roles:

        # Get indices of instances belonging to current role class
        role_indices = [i for i, r in enumerate(roles) if r == role]

        # Extract ground truth and predicted values for current role class
        role_gt = [gt[i] for i in role_indices]
        role_pred = [pred[i] for i in role_indices]

        # Calculate accuracy
        accuracy = accuracy_score(role_gt, role_pred)*100.
        accuracies.append(accuracy)

        # Calculate macro precision
        macro_precision = precision_score(role_gt, role_pred, average='macro')*100.
        macro_precisions.append(macro_precision)

        # Calculate macro recall
        macro_recall = recall_score(role_gt, role_pred, average='macro')*100.
        macro_recalls.append(macro_recall)

        # Calculate macro F1-score
        macro_f1_score = f1_score(role_gt, role_pred, average='macro')*100.
        macro_f1_scores.append(macro_f1_score)

    # Calculate average metrics
    avg_accuracy = np.mean(accuracies)
    avg_macro_precision = np.mean(macro_precisions)
    avg_macro_recall = np.mean(macro_recalls)
    avg_macro_f1_score = np.mean(macro_f1_scores)

    return avg_accuracy, avg_macro_precision, avg_macro_recall, avg_macro_f1_score

# def role_based_metrics_top1_setting(splitted_gt, splitted_pred, roles, incorrect_pred_index):

#     # Replace splitted_gt's (after remove empty sublists if any-should not be available for SSG) role values with 5000 (value that does not exist to penalize them if their top-1 predicted verb is icnorrrect)
#     roles = [item for sublist in roles for item in sublist]
#     gt_list = splitted_gt
#     for idx in incorrect_pred_index:
#         if idx < len(gt_list):
#             gt_list[idx] = [5000 for _ in gt_list[idx]]

#     #  Obtain gt, pred, role names (use the sr code to to obtain roles)
#     pred = splitted_pred
#     gt = gt_list
#     roles = roles

#     pred = [[int(x) for x in sublist] for sublist in pred]
#     gt = [[int(x) for x in sublist] for sublist in gt]

#     pred = [item for sublist in pred for item in sublist]
#     gt = [item for sublist in gt for item in sublist]

#     assert len(gt) == len(pred) == len(roles), f"Lengths mismatch: gt={len(gt)}, pred={len(pred)}, roles={len(roles)}"

#     # Find unique classes
#     unique_roles = set(roles)

#     # Initialize lists to store metrics for each role class
#     accuracies = []
#     macro_precisions = []
#     macro_recalls = []
#     macro_f1_scores = []

#     # Iterate over unique role classes
#     for role in unique_roles:

#         # Get indices of instances belonging to current role class
#         role_indices = [i for i, r in enumerate(roles) if r == role]

#         # Extract ground truth and predicted values for current role class
#         role_gt = [gt[i] for i in role_indices]
#         role_pred = [pred[i] for i in role_indices]

#         # Calculate accuracy
#         accuracy = accuracy_score(role_gt, role_pred)
#         accuracies.append(accuracy*100)

#         # Calculate macro precision
#         macro_precision = precision_score(role_gt, role_pred, average='macro')
#         macro_precisions.append(macro_precision*100)

#         # Calculate macro recall
#         macro_recall = recall_score(role_gt, role_pred, average='macro')
#         macro_recalls.append(macro_recall*100)

#         # Calculate macro F1-score
#         macro_f1_score = f1_score(role_gt, role_pred, average='macro')
#         macro_f1_scores.append(macro_f1_score*100)

#     # Calculate average metrics
#     avg_accuracy = np.mean(accuracies)
#     avg_macro_precision = np.mean(macro_precisions)
#     avg_macro_recall = np.mean(macro_recalls)
#     avg_macro_f1_score = np.mean(macro_f1_scores)

#     return avg_accuracy, avg_macro_precision, avg_macro_recall, avg_macro_f1_score


class EvaluateInComNet:

    def evaluate(self, obj_sr_gt_list, obj_sr_pred_list, obj_frame_lengths, obj_roles, verb_gt_list, verb_pred_list, verb_sr_gt_list, verb_sr_pred_list, verb_frame_lengths, verb_roles):

        # Remove padded elements (pad_value=365)
        obj_sr_pad_indices = [i for i, x in enumerate(obj_sr_gt_list) if x == 365]
        obj_sr_gt_list = remove_elements_by_indexes(obj_sr_gt_list, obj_sr_pad_indices)
        obj_sr_pred_list = remove_elements_by_indexes(obj_sr_pred_list, obj_sr_pad_indices)

        verb_pad_indices = [i for i, x in enumerate(verb_gt_list) if x == 365]
        verb_gt_list = remove_elements_by_indexes(verb_gt_list, verb_pad_indices)
        verb_pred_list = remove_elements_by_indexes(verb_pred_list, verb_pad_indices)

        verb_sr_pad_indices = [i for i, x in enumerate(verb_sr_gt_list) if x == 365]
        verb_sr_gt_list = remove_elements_by_indexes(verb_sr_gt_list, verb_sr_pad_indices)
        verb_sr_pred_list = remove_elements_by_indexes(verb_sr_pred_list, verb_sr_pad_indices)


        #### Verb evaluation
        verb_gt_list = np.array(verb_gt_list)
        verb_pred_list = np.array(verb_pred_list)

        acc=accuracy_score(verb_gt_list, verb_pred_list)*100.
        unique_classes = np.unique(np.concatenate((verb_gt_list, verb_pred_list)))
        per_class_accuracy = {}

        for cls in unique_classes:
            true_mask = (verb_gt_list == cls)
            pred_mask = (verb_pred_list == cls)
            class_accuracy = accuracy_score(verb_gt_list[true_mask], verb_pred_list[true_mask])*100
            per_class_accuracy[cls] = class_accuracy

        mP=precision_score(verb_gt_list, verb_pred_list, average='macro')*100.
        mR=recall_score(verb_gt_list, verb_pred_list, average='macro')*100. # zero_division=1
        f1 = f1_score(verb_gt_list, verb_pred_list, average='macro')*100
        # verb_results = {"Accuracy":acc, "mR": mR, "mP": mP, "F1": f1, "per_clss_accuracy": per_class_accuracy}
        verb_results = {"Accuracy":acc, "mR": mR, "mP": mP, "F1": f1}


        #### Object SR evaluation
        acc=accuracy_score(obj_sr_gt_list, obj_sr_pred_list)*100.
        mP=precision_score(obj_sr_gt_list, obj_sr_pred_list, average='macro')*100.
        mR=recall_score(obj_sr_gt_list, obj_sr_pred_list, average='macro')*100. # zero_division=1
        f1 = f1_score(obj_sr_gt_list, obj_sr_pred_list, average='macro')*100.

        splitted_pred = split_list(obj_sr_pred_list, obj_frame_lengths)
        splitted_gt = split_list(obj_sr_gt_list, obj_frame_lengths)

        value = value_metric(splitted_pred, splitted_gt, len(splitted_gt))
        value_two = value_metric_at_least_two(splitted_pred, splitted_gt, len(splitted_gt))
        value_all = value_all_metric(splitted_pred, splitted_gt, len(splitted_gt))

        incorrect_verb_pred_index = None
        role_based_acc, role_based_mP, role_based_mR, role_based_f1 = role_based_metrics(splitted_pred, splitted_gt, obj_roles, incorrect_verb_pred_index)
        obj_sr_results = {"Accuracy":acc, "mR": mR, "mP": mP, "F1": f1, "Value":value, "Value-two": value_two, "value-all":value_all, "role_based_accuracy": role_based_acc, "role_based_mP" : role_based_mP, "role_based_mR": role_based_mR, "role_based_f1":role_based_f1 }


        #### Verb SR evaluation
        acc=accuracy_score(verb_sr_gt_list, verb_sr_pred_list)*100.
        mP=precision_score(verb_sr_gt_list, verb_sr_pred_list, average='macro')*100.
        mR=recall_score(verb_sr_gt_list, verb_sr_pred_list, average='macro')*100. # zero_division=1
        f1 = f1_score(verb_sr_gt_list, verb_sr_pred_list, average='macro')*100.

        splitted_pred = split_list(verb_sr_gt_list, verb_frame_lengths)
        splitted_gt = split_list(verb_sr_pred_list, verb_frame_lengths)
        total_frames = len(splitted_gt)

        verb_gt_list = verb_gt_list.tolist()
        verb_pred_list = verb_pred_list.tolist()

        if args.top1:
            incorrect_verb_pred_index = [i for i, (x, y) in enumerate(zip(verb_gt_list, verb_pred_list)) if x != y]
            # role_based_acc, role_based_mP, role_based_mR, role_based_f1 = role_based_metrics_top1_setting(splitted_gt, splitted_pred, verb_roles, incorrect_verb_pred_index)
            role_based_acc, role_based_mP, role_based_mR, role_based_f1 = role_based_metrics(splitted_pred, splitted_gt, verb_roles, incorrect_verb_pred_index)

            splitted_pred = remove_elements_by_indexes(splitted_pred, incorrect_verb_pred_index) # take this forl calculating role-based mp, mr and f1 in top-1 setting
            splitted_gt = remove_elements_by_indexes(splitted_gt, incorrect_verb_pred_index) # take this forl calculating role-based mp, mr and f1 in top-1 setting
            verb_roles = remove_elements_by_indexes(verb_roles, incorrect_verb_pred_index) # take this forl calculating role-based mp, mr and f1 in top-1 setting
            verb_gt_list = remove_elements_by_indexes(verb_gt_list, incorrect_verb_pred_index)

            value = value_metric(splitted_pred, splitted_gt, total_frames)
            value_two = value_metric_at_least_two(splitted_pred, splitted_gt, total_frames)
            value_all = value_all_metric(splitted_pred, splitted_gt, total_frames)

        else:
            incorrect_verb_pred_index = None
            role_based_acc, role_based_mP, role_based_mR, role_based_f1 = role_based_metrics(splitted_pred, splitted_gt, verb_roles, incorrect_verb_pred_index)
            value = value_metric(splitted_pred, splitted_gt, total_frames)
            value_two = value_metric_at_least_two(splitted_pred, splitted_gt, total_frames)
            value_all = value_all_metric(splitted_pred, splitted_gt, total_frames)

        verb_sr_results = {"Accuracy":acc, "mR": mR, "mP": mP, "F1": f1, "Value":value, "Value-two": value_two, "value-all":value_all, "role_based_accuracy": role_based_acc, "role_based_mP" : role_based_mP, "role_based_mR": role_based_mR, "role_based_f1":role_based_f1 }

        return obj_sr_results, verb_results, verb_sr_results

    def evaluate_person_sr(self, person_sr_gt_list, person_sr_pred_list, person_frame_lengths, person_roles):

            acc=accuracy_score(person_sr_gt_list, person_sr_pred_list)*100.
            mP=precision_score(person_sr_gt_list, person_sr_pred_list, average='macro')*100.
            mR=recall_score(person_sr_gt_list, person_sr_pred_list, average='macro')*100.
            f1 = f1_score(person_sr_gt_list, person_sr_pred_list, average='macro')*100.

            splitted_pred = split_list(person_sr_pred_list, person_frame_lengths)
            splitted_gt = split_list(person_sr_gt_list, person_frame_lengths)

            value = value_metric(splitted_pred, splitted_gt, len(splitted_gt))
            value_two = value_metric_at_least_two(splitted_pred, splitted_gt, len(splitted_gt))
            value_all = value_all_metric(splitted_pred, splitted_gt, len(splitted_gt))

            incorrect_pred_index = None
            role_based_acc, role_based_mP, role_based_mR, role_based_f1 = role_based_metrics(splitted_pred, splitted_gt, person_roles, incorrect_pred_index)

            person_sr_result = {"Value":value, "Value-two": value_two, "value-all":value_all, "role_based_accuracy": role_based_acc, "role_based_mP" : role_based_mP, "role_based_mR": role_based_mR, "role_based_f1":role_based_f1 }

            return person_sr_result
# Out:
# Writing evaluation.py

# %% [markdown]
# # dataset.py

# %%
# %%writefile dataset.py
import os
import gc
import pickle

import torch
import numpy as np
import imageio
import clip
import open_clip

from PIL import Image, ImageFile
from torch.utils.data import Dataset

from utils import prep_im_for_blob, im_list_to_blob
from config import parse_args

args = parse_args()

torch.cuda.empty_cache()
gc.collect()


class AG(Dataset):

    def __init__(self, mode, datasize, data_path=None, frame_path=None, filter_nonperson_box_frame=True, filter_small_box=False, preprocess=None):

        self.data_path = data_path
        self.frames_path = frame_path
        self.preprocess = preprocess

        #### collect the object classes
        self.object_classes = ['__background__']
        with open(os.path.join(self.data_path, 'object_classes.txt'), 'r') as f:
            for line in f.readlines():
                line = line.strip('\n')
                self.object_classes.append(line)
        f.close()
        self.object_classes[9] = 'closet/cabinet'
        self.object_classes[11] = 'cup/glass/bottle'
        self.object_classes[23] = 'paper/notebook'
        self.object_classes[24] = 'phone/camera'
        self.object_classes[31] = 'sofa/couch'

        #### collect relationship classes
        self.relationship_classes = []
        with open(os.path.join(self.data_path, 'relationship_classes.txt'), 'r') as f:
            for line in f.readlines():
                line = line.strip('\n')
                self.relationship_classes.append(line)
        f.close()

        self.relationship_classes[0] = 'looking_at'
        self.relationship_classes[1] = 'not_looking_at'
        self.relationship_classes[5] = 'in_front_of'
        self.relationship_classes[7] = 'on_the_side_of'
        self.relationship_classes[10] = 'covered_by'
        self.relationship_classes[11] = 'drinking_from'
        self.relationship_classes[13] = 'have_it_on_the_back'
        self.relationship_classes[15] = 'leaning_on'
        self.relationship_classes[16] = 'lying_on'
        self.relationship_classes[17] = 'not_contacting'
        self.relationship_classes[18] = 'other_relationship'
        self.relationship_classes[19] = 'sitting_on'
        self.relationship_classes[20] = 'standing_on'
        self.relationship_classes[25] = 'writing_on'

        #### collect semantic roles of objects
        self.sr_classes = []
        with open(os.path.join(self.data_path, 'roles.txt'), 'r') as f:
            for line in f.readlines():
                line = line.strip('\n')
                self.sr_classes.append(line)
        f.close()

        self.attention_relationships = self.relationship_classes[0:3]
        self.spatial_relationships = self.relationship_classes[3:9]
        self.contacting_relationships = self.relationship_classes[9:]

        self.noun_sr_classes = self.sr_classes[0:21]
        self.rel_sr_classes = self.sr_classes[21:]

        #### collect values of relation semantic roles
        self.rel_sr_val = []
        with open(os.path.join(self.data_path, 'relation_role_values.txt'), 'r') as f:
            for line in f.readlines():
                line = line.strip('\n')
                self.rel_sr_val.append(line)
        f.close()

        #### collect values of object semantic roles
        self.noun_sr_val = []
        with open(os.path.join(self.data_path, 'noun_role_values.txt'), 'r') as f:
            for line in f.readlines():
                line = line.strip('\n')
                self.noun_sr_val.append(line)
        f.close()

        self.noun_sr_values = self.noun_sr_val[0:]
        self.rel_sr_values = self.rel_sr_val[0:]

        # print("self.attention_relationships :", self.attention_relationships)
        # print("self.spatial_relationships :", self.spatial_relationships)
        # print("self.contacting_relationships :", self.contacting_relationships)
        # print("self.sr_classes :", self.sr_classes, len(self.sr_classes))
        # print("self.noun_sr_classes :", self.noun_sr_classes, len(self.noun_sr_classes))
        # print("self.rel_sr_classes :", self.rel_sr_classes, len(self.rel_sr_classes))

        print('-------loading annotations---------slowly-----------')

        if filter_small_box:
            with open(self.data_path + 'ag_ssg_combined_person.pkl', 'rb') as f:
                person_bbox = pickle.load(f)
            f.close()
            with open(self.data_path+'ssg_dataset.pkl', 'rb') as f:
                object_bbox = pickle.load(f)
            f.close()
        else:
            with open(self.data_path + 'ag_ssg_combined_person.pkl', 'rb') as f:
                person_bbox = pickle.load(f)
            f.close()
            with open(self.data_path+'ssg_dataset.pkl', 'rb') as f:
                object_bbox = pickle.load(f)  # sr.pkl
            f.close()

        if datasize == 'mini':
            small_person = {}
            small_object = {}
            for i in list(person_bbox.keys())[:80000]:
                small_person[i] = person_bbox[i]
                small_object[i] = object_bbox[i]
            person_bbox = small_person
            object_bbox = small_object

        #### collect valid frames
        video_dict = {}
        for i in object_bbox.keys():
            if object_bbox[i][0]['metadata']['set'] == mode: #train or testing?
                frame_valid = False
                for j in object_bbox[i]: # the frame is valid if there is visible bbox
                    if j['visible']:
                        frame_valid = True
                if frame_valid:
                    video_name, frame_num = i.split('/')
                    if video_name in video_dict.keys():
                        video_dict[video_name].append(i)
                    else:
                        video_dict[video_name] = [i]

        frames_to_remove = ["004QE.mp4/000217.png", "004QE.mp4/000264.png", "004QE.mp4/000276.png", "004QE.mp4/000312.png", "00NN7.mp4/000820.png"] # these frames do not have person SR annotations
        for key, value in video_dict.items():
            video_dict[key] = [v for v in value if v not in frames_to_remove]

        self.video_list = []
        self.video_size = []
        self.gt_annotations = []
        self.non_gt_human_nums = 0
        self.non_heatmap_nums = 0
        self.non_person_video = 0
        self.one_frame_video = 0
        self.valid_nums = 0

        '''
        filter_nonperson_box_frame = True (default): according to the stanford method, remove the frames without person box both for training and testing
        filter_nonperson_box_frame = False: still use the frames without person box, FasterRCNN may find the person
        '''

        videos_exclude=['5G9SV.mp4', '651VO.mp4', 'FFYL6.mp4', '1C6P3.mp4', '1K0SU.mp4', 'WF7TY.mp4', '4JOAD.mp4', '83XF0.mp4', 'A4VK8.mp4', '7RXMM.mp4', 'AHLVF.mp4', 'UCDL4.mp4','0UBYY.mp4', '10ND1.mp4', 'XNXW6.mp4', 'F75LG.mp4', 'Y1HGC.mp4', '00607.mp4'] # '01KML.mp4', '028CE.mp4', '069GJ.mp4' (issues in sr.json)

        videos_500 = ['001YG.mp4', '004QE.mp4', '00607.mp4', '00HFP.mp4', '00MFE.mp4', '00N38.mp4', '00NN7.mp4', '00T1E.mp4', '00T4B.mp4', '00X3U.mp4', '00YZL.mp4', '00ZCA.mp4', '013SD.mp4', '015XE.mp4', '01K8X.mp4', '01KM1.mp4', '01KML.mp4' '01O27.mp4', '01THT.mp4', '01ZWG.mp4','024PD.mp4', '028CE.mp4', '02CYP.mp4', '02DPI.mp4', '02GMI.mp4', '02SK4.mp4', '02SKC.mp4', '02V54.mp4', '02XLP.mp4', '038WZ.mp4', '03AA8.mp4', '03D66.mp4', '03EW0.mp4', '03M0K.mp4', '03OQS.mp4', '03PRW.mp4', '03TL7.mp4', '03XSP.mp4', '04LAX.mp4', '04MTP.mp4', '05124.mp4', '1DYYP.mp4', 'CGNBJ.mp4', 'BOC1T.mp4']

        for i in video_dict.keys():
            video = []
            if ((i in videos_500) and (i not in videos_exclude)): # ((i in videos_500) and (i not in videos_exclude)) # testing dataset
                gt_annotation_video = []
                for j in video_dict[i]:
                    if filter_nonperson_box_frame:
                        if person_bbox[j]['bbox'].shape[0] == 0:
                            self.non_gt_human_nums += 1
                            continue
                        else:
                            video.append(j)
                            self.valid_nums += 1

                    gt_annotation_frame = []
                    for k in object_bbox[j]:

                        if k['visible'] and k['contacting_relationship']!=['other_relationship']:
                            assert k['bbox'] != None, 'warning! The object is visible without bbox'
                            k['nouns'] = k['class']
                            k['class'] = self.object_classes.index(k['class'])

                            k['bbox'] = np.array([k['bbox'][0], k['bbox'][1], k['bbox'][0]+k['bbox'][2], k['bbox'][1]+k['bbox'][3]]) # from xywh to xyxy
                            k['attention_relationship'] = torch.tensor([self.attention_relationships.index(r) for r in k['attention_relationship']], dtype=torch.long)
                            k['spatial_relationship'] = torch.tensor([self.spatial_relationships.index(r) for r in k['spatial_relationship']], dtype=torch.long)
                            k['contacting_relationship'] = torch.tensor([self.contacting_relationships.index(r) for r in k['contacting_relationship']], dtype=torch.long)

                            noun_roles=[]
                            noun_role_values=[]
                            relation_roles=[]
                            relation_role_values=[]
                            attributes = k.get("attributes", {})
                            roles = attributes.keys()
                            vals = attributes.values()
                            noun_roles.extend(roles)
                            noun_role_values.extend(vals)
                            noun_role_values = [self.noun_sr_val.index(r) for r in noun_role_values]

                            # Skip roles 'state' and 'purpose' as the dataset contains these roles only for a subset of the annotations.
                            if ('state' in noun_roles):
                                index_of_state = noun_roles.index('state')
                                noun_roles.pop(index_of_state)
                                noun_role_values.pop(index_of_state)

                            if ('purpose' in noun_roles):
                                index_of_purpose = noun_roles.index('purpose')
                                noun_roles.pop(index_of_purpose)
                                noun_role_values.pop(index_of_purpose)

                            k['noun_roles'] = noun_roles
                            k['noun_role_values'] = noun_role_values

                            available_rels = []
                            contact_rel = k.get("contacting_relationship_semantic_role_frame", {})

                            for dict in contact_rel:
                                rel_dict = dict.get("contacting_relationship")
                                if rel_dict == None:
                                    continue
                                else:
                                    available_rels.append(rel_dict)
                                    frame_dict=dict.get("frame", {})
                                    r_roles = []
                                    r_vals = []
                                    roles = frame_dict.keys()
                                    vals = frame_dict.values()
                                    r_roles.extend(roles)
                                    r_vals.extend(vals)
                                    r_vals = [self.rel_sr_val.index(r) for r in r_vals]
                                    relation_roles.append(r_roles)
                                    relation_role_values.append(r_vals)
                            k['relationships'] =  available_rels
                            k['relation_roles'] = relation_roles
                            k['relation_role_values']  = relation_role_values
                            k['contacting_relationship'] = torch.tensor([self.contacting_relationships.index(r) for r in available_rels], dtype=torch.long)
                            person = person_bbox[j]
                            gt_annotation_frame.append(k)

                    if gt_annotation_frame != []:

                        gt_annotation_frame.append({'person_bbox': person_bbox[j]['bbox']})

                        person_roles = []
                        person_role_values = []
                        atts = person_bbox[j]['attributes']
                        person_roles.extend(atts.keys())
                        person_role_values.extend(atts.values())
                        person_role_values = [self.noun_sr_val.index(r) for r in person_role_values]
                        gt_annotation_frame.append({'person_roles': person_roles})
                        gt_annotation_frame.append({'person_role_values': person_role_values})

                        gt_annotation_video.append(gt_annotation_frame)
                    else:
                        print("Removed {} as it has one contacting relationship and it is 'other relationship'".format(j))
                        video.remove(j)
            else:
                continue

            if len(video) > 2:
                self.video_list.append(video)
                self.video_size.append(person_bbox[j]['bbox_size'])
                self.gt_annotations.append(gt_annotation_video)
            elif len(video) == 1:
                self.one_frame_video += 1
            else:
                self.non_person_video += 1

        print('x'*60)
        if filter_nonperson_box_frame:
            print('There are {} videos and {} valid frames'.format(len(self.video_list), self.valid_nums))
            print('{} videos are invalid (no person), remove them'.format(self.non_person_video))
            print('{} videos are invalid (only one frame), remove them'.format(self.one_frame_video))
            print('{} frames have no human bbox in GT, remove them!'.format(self.non_gt_human_nums))
        else:
            print('There are {} videos and {} valid frames'.format(len(self.video_list), self.valid_nums))
            print('{} frames have no human bbox in GT'.format(self.non_gt_human_nums))
            print('Removed {} of them without joint heatmaps which means FasterRCNN also cannot find the human'.format(non_heatmap_nums))
        print('x' * 60)

    def __getitem__(self, index):
        frame_names = self.video_list[index]
        processed_ims = []
        im_scales = []
        raw_images_pil = []
        raw_images_np = []

        # Define window hyperparameter (e.g., 3 or 5)
        # Using a fallback if not explicitly added to args yet
        window_size = getattr(args, 'temporal_window', 5)
        half_w = window_size // 2

        for idx, name in enumerate(frame_names):
            ImageFile.LOAD_TRUNCATED_IMAGES = True

            # 1. Capture the Anchor Frame info for visual prompt cropping alignment
            img_path = os.path.join(self.frames_path, name)
            if not os.path.exists(img_path):
                img_path = img_path.replace(".png", ".jpg")

            anchor_img = Image.open(img_path).convert("RGB")
            raw_images_pil.append(anchor_img)
            raw_images_np.append(name)

            # 2. LOCAL TEMPORAL WINDOW LOADING (Step A)
            # Find context frames centered around 'idx' and clamp to boundaries
            context_frames_processed = []

            for offset in range(-half_w, half_w + 1):
                context_idx = max(0, min(len(frame_names) - 1, idx + offset))
                context_name = frame_names[context_idx]

                c_img_path = os.path.join(self.frames_path, context_name)
                if not os.path.exists(c_img_path):
                    c_img_path = c_img_path.replace(".png", ".jpg")

                c_img = Image.open(c_img_path).convert("RGB")

                # Apply OpenCLIP preprocessing transform
                im = self.preprocess(c_img)
                im = np.array(im)

                # Convert color space: RGB -> BGR and transpose dimensions
                im = im[:, :, ::-1]
                im = np.transpose(im, [1, 2, 0])

                # Format via utils helper (force standard 336x336 token dimensions for L4 VRAM protection)
                im, im_scale = prep_im_for_blob(im, [[[0.48145466, 0.4578275, 0.40821073]]], 336, 336)
                context_frames_processed.append(im)

            # Assemble the local temporal sequence for this frame index
            # Resulting array shape: (Window_Size, H, W, 3)
            local_blob = im_list_to_blob(context_frames_processed)

            # Permute to PyTorch standard layout: (Window_Size, 3, H, W)
            local_tensor = torch.from_numpy(local_blob).permute(0, 3, 1, 2)

            # processed_ims now safely holds list of [Window_Size, 3, H, W] tensors
            processed_ims.append(local_tensor)
            im_scales.append(1.0) # Scale is uniform since we force 336x336 resize configurations

        # 3. Stack all frames inside the video track together
        # Intermediate Shape: (Num_Frames, Window_Size, 3, 336, 336) -> e.g., (19, 3, 3, 336, 336)
        img_tensor = torch.stack(processed_ims, dim=0)

        # ==========================================================
        # CRITICAL POC FIX: Flatten Time Window into a 4D CLIP Batch
        # New Shape: (Num_Frames * Window_Size, 3, 336, 336) -> e.g., (57, 3, 336, 336)
        # ==========================================================
        img_tensor = img_tensor.view(-1, 3, 336, 336)

        # Structure uniform layout variables matching your validation cells
        # Note: im_info, gt_boxes, and num_boxes must scale to match the new flat dimension!
        total_windowed_frames = img_tensor.shape[0]

        im_info = torch.tensor([[336, 336, 1.0]], dtype=torch.float32).repeat(total_windowed_frames, 1)
        gt_boxes = torch.zeros([total_windowed_frames, 1, 5])
        num_boxes = torch.zeros([total_windowed_frames], dtype=torch.int64)

        return img_tensor, im_info, gt_boxes, num_boxes, index, raw_images_pil, raw_images_np

    def __len__(self):
        return len(self.video_list)

def cuda_collate_fn(batch):
    """
    don't need to zip the tensor

    """
    return batch[0]
# Out:
# Writing dataset.py

# %%
import sys
# Clear cached references to your local files
if 'config' in sys.modules: del sys.modules['config']
if 'dataset' in sys.modules: del sys.modules['dataset']

# %%
from dataset import AG

print("dataset import successful")
# Out:
# dataset import successful

# %% [markdown]
# # feature_extraction.py

# %%
# %%writefile feature_extraction.py
import os
import gc
import numpy as np
np.set_printoptions(precision=4)
import torch
import torch.nn.functional as F
import clip
import open_clip
from utils import get_visually_prompted_features, get_visually_prompted_features_person
from config import parse_args
args = parse_args()

class FeatureExtractor:
    def organize_input(self, im_info, gt_annotation):
        bbox_num = 0
        im_idx = []
        pair = []
        a_rel = []
        s_rel = []
        c_rel = []
        rel_sr = []
        noun_sr = []
        noun_sr_values = []
        rel_sr_values = []
        nouns=[]
        relationships = []
        person_roles = []
        person_role_values = []
        video_frames = []
        person_box = []

        for i in gt_annotation:
            bbox_num += len(i)

        FINAL_BBOXES = torch.zeros([bbox_num, 5], dtype=torch.float32).to(args.device)
        FINAL_LABELS = torch.zeros([bbox_num], dtype=torch.int64).to(args.device)
        FINAL_SCORES = torch.ones([bbox_num], dtype=torch.float32).to(args.device)
        HUMAN_IDX = torch.zeros([len(gt_annotation), 1], dtype=torch.int64).to(args.device)
        bbox_idx = 0

        for i, j in enumerate(gt_annotation):
            for m in j:
                if 'person_roles' in m.keys():
                    person_roles.append(m['person_roles'])
                elif 'person_role_values' in m.keys():
                    person_role_values.append(m['person_role_values'])
                elif 'person_box' in m.keys():
                    person_box.append(m['person_box'])
                    FINAL_BBOXES[bbox_idx, 1:] = torch.from_numpy(m['person_box'][0])
                    FINAL_BBOXES[bbox_idx, 0] = i
                    FINAL_LABELS[bbox_idx] = 1
                    HUMAN_IDX[i] = bbox_idx
                    bbox_idx += 1
                elif 'bbox' in m.keys():
                    FINAL_BBOXES[bbox_idx, 1:] = torch.from_numpy(m['bbox'])
                    FINAL_BBOXES[bbox_idx, 0] = i
                    FINAL_LABELS[bbox_idx] = m['class'] if 'class' in m.keys() else 0
                    im_idx.append(i)
                    pair.append([int(HUMAN_IDX[i]), bbox_idx])
                    a_rel.append(m['attention_relationship'].tolist() if 'attention_relationship' in m.keys() else [])
                    s_rel.append(m['spatial_relationship'].tolist() if 'spatial_relationship' in m.keys() else [])
                    c_rel.append(m['contacting_relationship'].tolist() if 'contacting_relationship' in m.keys() else [])
                    noun_sr.append(m['noun_roles'] if 'noun_roles' in m.keys() else [])
                    noun_sr_values.append(m['noun_role_values'] if 'noun_role_values' in m.keys() else [])
                    nouns.append(m['nouns'] if 'nouns' in m.keys() else "object")
                    rel_sr.append(m['relation_roles'] if 'relation_roles' in m.keys() else [])
                    rel_sr_values.append(m['relation_role_values'] if 'relation_role_values' in m.keys() else [])
                    relationships.append(m['relationships'] if 'relationships' in m.keys() else [])
                    bbox_idx += 1

        FINAL_BBOXES = FINAL_BBOXES[:bbox_idx]
        FINAL_LABELS = FINAL_LABELS[:bbox_idx]
        FINAL_SCORES = FINAL_SCORES[:bbox_idx]
        pair = torch.tensor(pair).to(args.device)
        im_idx = torch.tensor(im_idx, dtype=torch.float).to(args.device)
        FINAL_BBOXES[:, 1:] = FINAL_BBOXES[:, 1:] / im_info[0, 2]

        entry = {
            'boxes': FINAL_BBOXES, 'labels': FINAL_LABELS, 'scores': FINAL_SCORES,
            'im_idx': im_idx, 'pair_idx': pair, 'human_idx': HUMAN_IDX,
            'attention_gt': a_rel, 'spatial_gt': s_rel, 'contacting_gt': c_rel,
            'noun_sr': noun_sr, 'noun_sr_values': noun_sr_values, 'relation_sr': rel_sr,
            'relation_sr_values': rel_sr_values, 'relationships': relationships, 'nouns': nouns,
            'person_roles': person_roles, 'person_role_values': person_role_values, 'person_box': person_box
        }
        return entry

    def get_features(self, im_info, gt_annotation, raw_images_pil, model, preprocess, incomnet_model=None):
        entry = self.organize_input(im_info, gt_annotation)
        max_dim_0 = 7
        gt_padding_value = 365
        window_size = getattr(args, 'temporal_window', 5)

        #### Create object SR features
        noun_frame_lengths = []
        n_roles = []
        v_frame_lengths = []
        v_roles = []
        class_names = entry['nouns']
        noun_roles = entry['noun_sr']
        noun_role_values = entry['noun_sr_values']

        noun_frame_lengths.extend([len(sublist) for sublist in noun_role_values])
        n_roles.extend(frame for frame in noun_roles)

        frame_lengths = [len(sublist) for sublist in noun_role_values]
        obj_sr_mask = [[1] * length + [0] * (max_dim_0 - length) for length in frame_lengths]
        obj_sr_mask = torch.stack([torch.tensor(sublist) for sublist in obj_sr_mask]).cpu()

        boxes = entry['boxes']
        pair_idx = entry['pair_idx']
        im_idx = entry['im_idx']

        obj_box_tensor = torch.cat((im_idx[:, None], boxes[:, 1:5][pair_idx[:, 1]]), 1)
        obj_box_tensor = torch.floor(obj_box_tensor).type(torch.int64)

        image_features = get_visually_prompted_features(raw_images_pil, obj_box_tensor, model, preprocess)

        with torch.no_grad():
            class_input = clip.tokenize(class_names).to(args.device)
            class_features = model.encode_text(class_input)
            obj_role_features = []
            for item in noun_roles:
                role_input = clip.tokenize(item).to(args.device)
                role_inputs = model.encode_text(role_input)
                obj_role_features.append(role_inputs)

        obj_role_features = [F.pad(tensor, (0, 0, 0, max_dim_0 - tensor.shape[0])) for tensor in obj_role_features]

        obj_sr_features = []
        for img, cls, obj_roles in zip(image_features, class_features, obj_role_features):
            obj_roles1 = list(torch.unbind(obj_roles, dim=0))
            obj_roles1.insert(0, img)
            obj_roles1.insert(1, cls)
            obj_sr_features.append(torch.stack(obj_roles1))

        obj_sr_features = torch.stack(obj_sr_features).cpu().to(torch.float32)

        obj_sr_gt = entry['noun_sr_values']
        obj_sr_gt = [sublist + [gt_padding_value] * (7 - len(sublist)) if len(sublist) < 7 else sublist[:7] for sublist in obj_sr_gt]
        obj_sr_gt = torch.stack([torch.tensor(sublist) for sublist in obj_sr_gt])

        #### Create verb predicate features
        union_box_tensor = torch.cat((im_idx[:, None],
                                      torch.min(boxes[:, 1:3][pair_idx[:, 0]], boxes[:, 1:3][pair_idx[:, 1]]),
                                      torch.max(boxes[:, 3:5][pair_idx[:, 0]], boxes[:, 3:5][pair_idx[:, 1]])), 1)
        union_box_tensor = torch.floor(union_box_tensor).type(torch.int64)

        verb_image_features = get_visually_prompted_features(raw_images_pil, union_box_tensor, model, preprocess)
        verb_img_features = verb_image_features.cpu().to(torch.float32)
        verb_cls_features = class_features.cpu().to(torch.float32)

        verb_gt = [sublist[0] for sublist in entry['contacting_gt']]
        verb_gt = torch.tensor(verb_gt, dtype=torch.long)

        #### Create verb predicate SR features
        r_roles = entry['relation_sr']
        rel_role_values = entry['relation_sr_values']
        v_frame_lengths.extend([len(sublist[0]) for sublist in rel_role_values])
        v_roles.extend(frame[0] for frame in r_roles)

        verb_sr_frame_lengths = [len(sublist[0]) for sublist in rel_role_values]
        verb_sr_mask = [[1] * length + [0] * (max_dim_0 - length) for length in verb_sr_frame_lengths]
        verb_sr_mask = torch.stack([torch.tensor(sublist) for sublist in verb_sr_mask]).cpu()

        verb_sr_image_features = get_visually_prompted_features(raw_images_pil, union_box_tensor, model, preprocess)

        with torch.no_grad():
            rel_role_features = []
            for frames in r_roles:
                role_input = clip.tokenize(frames[0]).to(args.device)
                role_inputs = model.encode_text(role_input)
                rel_role_features.append(role_inputs)
        rel_role_features = [F.pad(tensor, (0, 0, 0, max_dim_0 - tensor.shape[0])) for tensor in rel_role_features]

        verb_sr_features = []
        for img, cls, verb_roles in zip(verb_sr_image_features, class_features, rel_role_features):
            verb_roles1 = list(torch.unbind(verb_roles, dim=0))
            verb_roles1.insert(0, img)
            verb_roles1.insert(1, cls)
            verb_sr_features.append(torch.stack(verb_roles1))

        verb_sr_features = torch.stack(verb_sr_features).cpu().to(torch.float32)

        verb_sr_gt = [sublist[0] + [gt_padding_value] * (7 - len(sublist[0])) if len(sublist[0]) < 7 else sublist[0][:7] for sublist in rel_role_values]
        verb_sr_gt = torch.stack([torch.tensor(sublist) for sublist in verb_sr_gt])

        # ==========================================
        # STEP 4: VECTORIZED TEMPORAL ATTENTION INJECTION
        # ==========================================
        if incomnet_model is not None and hasattr(incomnet_model, 'motion_mixer'):
            # Send arrays to device for mixing calculation
            obj_sr_features = obj_sr_features.to(args.device)
            verb_img_features = verb_img_features.to(args.device)
            verb_cls_features = verb_cls_features.to(args.device)
            verb_sr_features = verb_sr_features.to(args.device)

            # Mix Object Semantic Roles
            # Shape transition: [Num_Pairs * Window, Tokens, Dim] -> Isolate slots vectorially
            N_total, Tokens, Dim = obj_sr_features.shape
            obj_sr_features = obj_sr_features.transpose(0, 1).reshape(Tokens * (N_total // window_size) * window_size, Dim)
            obj_sr_features = incomnet_model.motion_mixer(obj_sr_features, window_size=window_size)
            obj_sr_features = obj_sr_features.view(Tokens, -1, Dim).transpose(0, 1)

            # Mix Verb Visual Cues
            verb_img_features = incomnet_model.motion_mixer(verb_img_features, window_size=window_size)
            verb_cls_features = incomnet_model.motion_mixer(verb_cls_features, window_size=window_size)

            # Mix Verb Semantic Roles
            verb_sr_features = verb_sr_features.transpose(0, 1).reshape(Tokens * (N_total // window_size) * window_size, Dim)
            verb_sr_features = incomnet_model.motion_mixer(verb_sr_features, window_size=window_size)
            verb_sr_features = verb_sr_features.view(Tokens, -1, Dim).transpose(0, 1)

            # Collapse masks and targets to match the single downsampled middle frames
            obj_sr_mask = obj_sr_mask[::window_size]
            obj_sr_gt = obj_sr_gt[::window_size]
            verb_gt = verb_gt[::window_size]
            verb_sr_mask = verb_sr_mask[::window_size]
            verb_sr_gt = verb_sr_gt[::window_size]

            # Update sequence lengths lists for correct metric evaluations
            noun_frame_lengths = noun_frame_lengths[::window_size]
            v_frame_lengths = v_frame_lengths[::window_size]
            n_roles = n_roles[::window_size]
            v_roles = v_roles[::window_size]

        features = {
            'obj_sr_features': obj_sr_features.to(args.device),
            'obj_sr_mask': obj_sr_mask.to(args.device),
            'obj_sr_gt': obj_sr_gt.to(args.device),
            'verb_img_features': verb_img_features.to(args.device),
            'verb_cls_features': verb_cls_features.to(args.device),
            'verb_gt': verb_gt.to(args.device),
            'verb_sr_features': verb_sr_features.to(args.device),
            'verb_sr_mask': verb_sr_mask.to(args.device),
            'verb_sr_gt': verb_sr_gt.to(args.device),
            'noun_frame_lengths': noun_frame_lengths, 'n_roles': n_roles,
            'v_frame_lengths': v_frame_lengths, 'v_roles': v_roles
        }
        return features

    def get_person_features(self, im_info, gt_annotation, raw_images_pil, model, preprocess):
        entry = self.organize_input(im_info, gt_annotation)
        person_roles = entry['person_roles']
        person_role_values = entry['person_role_values']
        person_cls = ["person" for _ in range(len(person_role_values))]
        person_frame_lengths = []
        p_roles = []

        person_frame_lengths.extend([len(sublist) for sublist in person_role_values])
        p_roles.extend(frame for frame in person_roles)

        person_sr_gt = torch.stack([torch.tensor(sublist) for sublist in person_role_values])
        person_box_tensor = torch.tensor(entry['person_box']).squeeze()

        image_features = get_visually_prompted_features_person(raw_images_pil, person_box_tensor, model, preprocess)
        with torch.no_grad():
            class_input = clip.tokenize(person_cls).to(args.device)
            class_features = model.encode_text(class_input)
            person_role_features = []
            for item in person_roles:
                role_input = clip.tokenize(item).to(args.device)
                role_inputs = model.encode_text(role_input)
                person_role_features.append(role_inputs)

        person_sr_features = []
        for img, cls, person_roles in zip(image_features, class_features, person_role_features):
            person_roles = list(torch.unbind(person_roles, dim=0))
            person_roles.insert(0, img)
            person_roles.insert(1, cls)
            person_sr_features.append(torch.stack(person_roles))

        person_sr_features = torch.stack(person_sr_features).to(torch.float32)

        person_features = {
            'person_sr_features': person_sr_features.to(args.device),
            'person_sr_gt': person_sr_gt.to(args.device),
            'person_frame_lengths': person_frame_lengths, 'p_roles': p_roles
        }
        return person_features
# Out:
# Writing feature_extraction.py

# %%
import sys
for mod in ['config', 'dataset', 'feature_extraction']:
    if mod in sys.modules:
        del sys.modules[mod]
print("Module cache refreshed! Ready to re-run.")
# Out:
# Module cache refreshed! Ready to re-run.

# %%
from feature_extraction import FeatureExtractor

print("feature extractor import successful")
# Out:
# feature extractor import successful

# %% [markdown]
# # model.py

# %%
# %%writefile model.py
import torch
import torch.nn as nn
from typing import Optional
from torch import Tensor, Generator
import numpy as np
from config import parse_args
args = parse_args()

def getPositionEncoding(seq_len, d):
    n=10000
    P = torch.zeros((seq_len, d))
    for k in range(seq_len):
        for i in np.arange(int(d/2)):
            denominator = np.power(n, 2*i/d)
            P[k, 2*i] = np.sin(k/denominator)
            P[k, 2*i+1] = np.cos(k/denominator)
    return P

def drop_path(x, drop_prob: float = 0.0, training: bool = False):
    if drop_prob == 0.0 or not training:
        return x
    keep_prob = 1 - drop_prob
    shape = (x.shape[0],) + (1,) * (x.ndim - 1)
    mask = keep_prob + torch.rand(shape, dtype=x.dtype, device=x.device)
    mask.floor_()
    output = x.div(keep_prob) * mask
    return output

class DropPath(nn.Module):
    def __init__(self, drop_prob=None):
        super(DropPath, self).__init__()
        self.drop_prob = drop_prob
    def forward(self, x):
        return drop_path(x, self.drop_prob, self.training)

class Mlp(nn.Module):
    def __init__(self, in_features, hidden_features=None, out_features=None, act_layer=nn.GELU, drop=0.0):
        super().__init__()
        self.drop_rate = drop
        out_features = out_features or in_features
        hidden_features = hidden_features or in_features
        self.fc1 = nn.Linear(in_features, hidden_features)
        self.act = act_layer()
        self.fc2 = nn.Linear(hidden_features, out_features)
        if self.drop_rate > 0.0:
            self.drop = nn.Dropout(self.drop_rate)
    def forward(self, x):
        x = self.fc1(x)
        x = self.act(x)
        if self.drop_rate > 0.0:
            x = self.drop(x)
        x = self.fc2(x)
        if self.drop_rate > 0.0:
            x = self.drop(x)
        return x

class CrossAttention(nn.Module):
    def __init__(self, dim, num_heads=8, qkv_bias=False):
        super().__init__()
        self.num_heads = num_heads
        head_dim = dim // num_heads
        self.scale = head_dim ** -0.5
        self.head_dim = head_dim
        self.q = nn.Linear(dim, dim, bias=qkv_bias)
        self.kv = nn.Linear(dim, dim*2, bias=qkv_bias)
        self.proj = nn.Linear(dim, dim)
    def forward(self, x, y, mask = None):
        B1, N1, C = x.shape
        B2, N2, C = y.shape
        q = self.q(x).reshape(B1, N1, 1, self.num_heads, C // self.num_heads).permute(2, 0, 3, 1, 4)
        kv = self.kv(y).reshape(B2, N2, 2, self.num_heads, C // self.num_heads).permute(2, 0, 3, 1, 4)
        k, v = kv[0], kv[1]
        attn = (q @ k.transpose(-2, -1)) * self.scale
        attn = attn.softmax(dim=-1)
        x = (attn @ v).transpose(1, 2).reshape(B1, N1, C)
        x = self.proj(x)
        if mask is not None:
            if B1 > 1:
                x = mask*x
            else:
                x = mask.unsqueeze(1).float()*x
            return x, y, attn
        else:
            return x, y, attn

class CrossAttentionBlock(nn.Module):
    def __init__(self, dim, num_heads=None, mlp_ratio=4.0, qkv_bias=False, drop_rate=0.0, drop_path=0.2, act_layer=nn.GELU, norm_layer=nn.LayerNorm):
        super().__init__()
        self.dim = dim
        self.norm1 = norm_layer(dim)
        self.norm2 = norm_layer(dim)
        self.attn = CrossAttention(dim, num_heads=num_heads, qkv_bias=qkv_bias)
        self.drop_path = DropPath(drop_path) if drop_path > 0.0 else nn.Identity()
        self.norm3 = norm_layer(dim)
        mlp_hidden_dim = int(dim * mlp_ratio)
        self.mlp = Mlp(in_features=dim, hidden_features=mlp_hidden_dim, out_features=dim, act_layer=act_layer, drop=drop_rate)
    def forward(self, x, y, mask = None):
        x_block, y, attn = self.attn(self.norm1(x), self.norm2(y), mask=mask)
        x_norm = self.norm3(x_block)
        x_mlp = self.mlp(x_norm)
        x = x + self.drop_path(x_mlp)
        return x, y, attn

class MultiheadAttentionLayer(nn.Module):
    def __init__(self, embed_dim, num_heads, dropout = 0.1, batch_first = True):
        super(MultiheadAttentionLayer, self).__init__()
        self.multihead_attention = nn.MultiheadAttention(embed_dim=embed_dim, num_heads=num_heads, dropout=dropout, batch_first=batch_first)
        self.layer_norm = nn.LayerNorm(embed_dim)
    def forward(self, query, key, value, key_padding_mask = None, need_weights = True, attn_mask = None):
        attn_output, attn_weights = self.multihead_attention(query, key, value, key_padding_mask=key_padding_mask, need_weights=need_weights, attn_mask=attn_mask)
        output = self.layer_norm(attn_output)
        return output, attn_weights


# ==========================================
# NEW: TEMPORAL MOTION MIXER MODULE
# ==========================================
class TemporalMotionMixer(nn.Module):
    def __init__(self, embed_dim=768, num_heads=4):
        super().__init__()
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=embed_dim,
            nhead=num_heads,
            dim_feedforward=1024,
            batch_first=True
        )
        self.temporal_transformer = nn.TransformerEncoder(encoder_layer, num_layers=2)

    def forward(self, x, window_size=5):
        # Input shape from feature intercept: (Total_Pairs * Window_Size, Embed_Dim)
        # Reshape to isolate time dimension: (Total_Pairs, Window_Size, Embed_Dim)
        total_slots = x.size(0)
        batch_pairs = total_slots // window_size

        x = x.view(batch_pairs, window_size, -1)
        x = self.temporal_transformer(x)

        # Pull middle frame index to align seamlessly with bounding box tracks
        anchor_idx = window_size // 2
        return x[:, anchor_idx, :]


class InComNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.num_ans_classes = [364, 17, 125]
        num_layers = 4
        num_heads = 4

        if args.clip_model == 'ViT-B/32':
            self.proj_dim = 512
        elif args.clip_model == 'ViT_L_14_336' or args.clip_model == 'ViT_L_14_336_sft':
            self.proj_dim = 768

        # Instantiate Temporal Mixer
        self.motion_mixer = TemporalMotionMixer(embed_dim=self.proj_dim)

        # obj SR
        self.obj_sr_q_proj = nn.Linear(self.proj_dim, self.proj_dim)
        self.obj_sr_kv_proj = nn.Linear(self.proj_dim, self.proj_dim)
        self.obj_sr_output_proj = nn.Linear(self.proj_dim, self.proj_dim)
        self.obj_sr_classifier = nn.Linear(self.proj_dim, self.num_ans_classes[0])
        self.obj_sr_q = nn.Parameter(torch.zeros(1, 7, self.proj_dim))
        self.obj_sr_q.data.normal_(mean=0.0, std=0.02)
        self.obj_sr_pos_emb = getPositionEncoding(7, self.proj_dim)
        obj_sr_attention_layer = MultiheadAttentionLayer(embed_dim=self.proj_dim, num_heads=num_heads, dropout=0.1, batch_first=True)
        self.obj_sr_atts = nn.ModuleList([obj_sr_attention_layer for i in range(num_layers)])

        # verb
        self.verb_q_proj = nn.Linear(self.proj_dim, self.proj_dim)
        self.verb_kv_proj = nn.Linear(self.proj_dim, self.proj_dim)
        self.verb_output_proj = nn.Linear(self.proj_dim, self.proj_dim)
        self.verb_classifier = nn.Linear(self.proj_dim, self.num_ans_classes[1])
        self.verb_cls = nn.Parameter(torch.randn(1, 1, self.proj_dim))
        self.verb_q = nn.Parameter(torch.zeros(1, 1, self.proj_dim))
        self.verb_q.data.normal_(mean=0.0, std=0.02)
        verb_attention_layer = MultiheadAttentionLayer(embed_dim=self.proj_dim, num_heads=num_heads, dropout=0.1, batch_first=True)
        self.verb_atts = nn.ModuleList([verb_attention_layer for i in range(num_layers)])

        # verb SR
        self.verb_sr_q_proj = nn.Linear(self.proj_dim, self.proj_dim)
        self.verb_sr_kv_proj = nn.Linear(self.proj_dim, self.proj_dim)
        self.verb_sr_output_proj = nn.Linear(self.proj_dim, self.proj_dim)
        self.verb_sr_classifier = nn.Linear(self.proj_dim, self.num_ans_classes[2])
        self.verb_sr_q = nn.Parameter(torch.zeros(1, 7, self.proj_dim))
        self.verb_sr_q.data.normal_(mean=0.0, std=0.02)
        self.verb_sr_pos_emb = getPositionEncoding(7, self.proj_dim)
        verb_sr_attention_layer = MultiheadAttentionLayer(embed_dim=self.proj_dim, num_heads=num_heads, dropout=0.1, batch_first=True)
        self.verb_sr_atts = nn.ModuleList([verb_sr_attention_layer for i in range(num_layers)])

    def forward(self, obj_sr_flag, verb_flag, verb_sr_flag, obj_sr_frame, obj_sr_mask, verb, verb_mask, verb_sr_frame, verb_sr_mask):
        #### Object SR
        if (obj_sr_flag and not verb_flag and not verb_sr_flag):
            obj_sr_kv = obj_sr_frame
            obj_sr_kv = self.obj_sr_kv_proj(obj_sr_kv)
            obj_sr_q = self.obj_sr_q.repeat(obj_sr_frame.size(0), 1, 1)
            self.obj_sr_pos_emb = self.obj_sr_pos_emb.to(args.device)
            obj_sr_q = obj_sr_q + self.obj_sr_pos_emb
            if obj_sr_mask is not None:
                obj_sr_mask = obj_sr_mask.unsqueeze(-1).repeat(1, 1, self.proj_dim)
            for layer in self.obj_sr_atts:
                obj_sr_q, obj_sr_attn = layer(obj_sr_q, obj_sr_kv, obj_sr_kv)
            obj_sr_q = obj_sr_q*obj_sr_mask
            obj_sr_q = self.obj_sr_output_proj(obj_sr_q)
            obj_sr_logits = self.obj_sr_classifier(obj_sr_q)
            return obj_sr_logits, obj_sr_q

        #### Verb predicate
        if (not obj_sr_flag and verb_flag and not verb_sr_flag):
            verb_kv = verb
            verb_kv = self.verb_kv_proj(verb_kv)
            verb_q = self.verb_q.repeat(verb.size(0), 1, 1)
            verb_mask = None
            for layer in self.verb_atts:
                verb_q, verb_attn = layer(verb_q, verb_kv, verb_kv)
            verb_q = self.verb_output_proj(verb_q)
            verb_logits = self.verb_classifier(verb_q)
            return verb_logits, verb_q

        #### Verb predicate SR
        if (not obj_sr_flag and not verb_flag and verb_sr_flag):
            verb_sr_kv = verb_sr_frame
            verb_sr_kv = self.verb_sr_kv_proj(verb_sr_kv)
            verb_sr_q = self.verb_sr_q.repeat(verb_sr_frame.size(0), 1, 1)
            self.verb_sr_pos_emb = self.verb_sr_pos_emb.to(args.device)
            verb_sr_q = verb_sr_q + self.verb_sr_pos_emb
            if verb_sr_mask is not None:
                verb_sr_mask = verb_sr_mask.unsqueeze(-1).repeat(1, 1, self.proj_dim)
            for layer in self.verb_sr_atts:
                verb_sr_q, verb_sr_attn = layer(verb_sr_q, verb_sr_kv, verb_sr_kv)
            verb_sr_q = verb_sr_q*verb_sr_mask
            verb_sr_q = self.verb_sr_output_proj(verb_sr_q)
            verb_sr_logits = self.verb_sr_classifier(verb_sr_q)
            return verb_sr_logits, verb_sr_q

class InComNetPerson(nn.Module):
    def __init__(self):
        super().__init__()
        self.num_ans_classes = [364, 17, 125]
        num_layers = 4
        num_heads = 4
        if args.clip_model == 'ViT-B/32':
            self.proj_dim = 512
        elif args.clip_model == 'ViT_L_14_336' or args.clip_model == 'ViT_L_14_336_sft':
            self.proj_dim = 768
        self.pos_emb = torch.nn.Parameter(torch.randn(7, self.proj_dim))
        self.person_sr_kv_proj = nn.Linear(self.proj_dim, self.proj_dim)
        self.person_sr_output_proj = nn.Linear(self.proj_dim, self.proj_dim)
        self.person_sr_classifier = nn.Linear(self.proj_dim, self.num_ans_classes[0])
        self.person_sr_q = nn.Parameter(torch.zeros(1, 5, self.proj_dim))
        self.person_sr_q.data.normal_(mean=0.0, std=0.02)
        self.person_sr_q_pos_emb = getPositionEncoding(5, self.proj_dim)
        person_sr_attention_layer = MultiheadAttentionLayer(embed_dim=self.proj_dim, num_heads=num_heads, dropout=0.1, batch_first=True)
        self.person_sr_atts = nn.ModuleList([person_sr_attention_layer for i in range(num_layers)])

    def forward(self, person_sr_feat):
        person_sr_kv = self.person_sr_kv_proj(person_sr_feat)
        person_sr_q = self.person_sr_q.repeat(person_sr_feat.size(0), 1, 1)
        person_sr_q = person_sr_q + self.person_sr_q_pos_emb.to(args.device)
        for layer in self.person_sr_atts:
            person_sr_q, person_sr_attn = layer(person_sr_q, person_sr_kv, person_sr_kv)
        person_sr_q = self.person_sr_output_proj(person_sr_q)
        person_sr_logits = self.person_sr_classifier(person_sr_q)
        return person_sr_logits, person_sr_q
# Out:
# Writing model.py

# %% [markdown]
# # Verification till model

# %%
from model import InComNet
from model import InComNetPerson

print("model import successful")
# Out:
# model import successful

# %% [markdown]
# Verify required data files

# %%
import os

DATA_PATH = "/content/drive/MyDrive/project/SSG/data"

files = [
    "object_classes.txt",
    "relationship_classes.txt",
    "roles.txt",
    "noun_role_values.txt",
    "relation_role_values.txt",
    "ag_ssg_combined_person.pkl",
    "ssg_dataset.pkl"
]

for f in files:
    print(f, os.path.exists(os.path.join(DATA_PATH, f)))
# Out:
# object_classes.txt True
# relationship_classes.txt True
# roles.txt True
# noun_role_values.txt True
# relation_role_values.txt True
# ag_ssg_combined_person.pkl True
# ssg_dataset.pkl True

# %% [markdown]
# Create AG dataset

# %%
import torch
import open_clip

model_name = "ViT-L-14-336"

print("Initializing OpenCLIP framework architecture...")
# 1. Pass an empty string to pretrained to create the structure without baseline weights
model, _, preprocess = open_clip.create_model_and_transforms(
    model_name=model_name,
    pretrained=""
)

# 2. Map your fine-tuned weights directly into the GPU memory
print(f"Loading custom fine-tuned weights from checkpoint...")
checkpoint = torch.load(CLIP_CKPT, map_location="cuda:0")

if isinstance(checkpoint, dict) and "state_dict" in checkpoint:
    state_dict = checkpoint["state_dict"]
elif isinstance(checkpoint, dict) and "model" in checkpoint:
    state_dict = checkpoint["model"]
else:
    state_dict = checkpoint

# Clean DDP prefixes if present
if any(k.startswith('module.') for k in state_dict.keys()):
    state_dict = {k.replace('module.', ''): v for k, v in state_dict.items()}

# 3. Load the weights, push to GPU, and set to evaluation mode
model.load_state_dict(state_dict)
model = model.to("cuda:0")
model.eval()

print("SUCCESS: Model ready and mounted on GPU for feature extraction!")
# Out:
# Initializing OpenCLIP framework architecture...
# Loading custom fine-tuned weights from checkpoint...
# SUCCESS: Model ready and mounted on GPU for feature extraction!

# %%
from dataset import AG

dataset = AG(
    mode="train",
    datasize="large",
    data_path="/content/drive/MyDrive/project/SSG/data/",
    frame_path="/content/drive/MyDrive/project/SSG/data/frames/",
    filter_nonperson_box_frame=True,
    filter_small_box=False,
    preprocess=preprocess
)

print(len(dataset))
# Out:
# -------loading annotations---------slowly-----------
# Removed CGNBJ.mp4/000959.png as it has one contacting relationship and it is 'other relationship'
# Removed 004QE.mp4/000273.png as it has one contacting relationship and it is 'other relationship'
# Removed 004QE.mp4/000343.png as it has one contacting relationship and it is 'other relationship'
# Removed BOC1T.mp4/000055.png as it has one contacting relationship and it is 'other relationship'
# Removed BOC1T.mp4/000379.png as it has one contacting relationship and it is 'other relationship'
# Removed BOC1T.mp4/000271.png as it has one contacting relationship and it is 'other relationship'
# Removed BOC1T.mp4/000497.png as it has one contacting relationship and it is 'other relationship'
# Removed 05124.mp4/000603.png as it has one contacting relationship and it is 'other relationship'
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# There are 30 videos and 632 valid frames
# 2 videos are invalid (no person), remove them
# 0 videos are invalid (only one frame), remove them
# 68 frames have no human bbox in GT, remove them!
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# 30

# %% [markdown]
# Verify dataset[0]

# %%
sample = dataset[0]

print(type(sample))
print(len(sample))
# Out:
# <class 'tuple'>
# 7

# %%
from pathlib import Path

video_dir = Path("/content/drive/MyDrive/project/SSG/data/frames/013SD.mp4")

print(video_dir.exists())

files = sorted(list(video_dir.iterdir()))[:5]
for f in files:
    print(f.name)
# Out:
# True
# 000010.jpg
# 000012.jpg
# 000027.jpg
# 000035.jpg
# 000044.jpg

# %%
img_tensor, im_info, gt_boxes, num_boxes, idx, raw_images_pil, raw_images_np = sample

print("img_tensor:", img_tensor.shape)
print("im_info:", im_info.shape)
print("gt_boxes:", gt_boxes.shape)
print("num_boxes:", num_boxes.shape)
print("idx:", idx)
print("num frames:", len(raw_images_pil))
# Out:
# img_tensor: torch.Size([57, 3, 336, 336])
# im_info: torch.Size([57, 3])
# gt_boxes: torch.Size([57, 1, 5])
# num_boxes: torch.Size([57])
# idx: 0
# num frames: 19

# %% [markdown]
# Load  fine-tuned checkpoint:

# %% [markdown]
# # Clear Module
# if needed

# %%
import sys
for mod in ['config', 'dataset', 'feature_extraction', 'utils']:
    if mod in sys.modules: del sys.modules[mod]
print("Module cache refreshed!")
# Out:
# Module cache refreshed!

# %%
import torch
import config
import utils
from feature_extraction import FeatureExtractor

# 1. Double check device registration maps to your NVIDIA L4
args = config.parse_args()
device = 'cuda:0' if torch.cuda.is_available() else 'cpu'
args.device = device

if hasattr(utils, 'args'):
    utils.args.device = device

# 2. Instantiate your extractor
extractor = FeatureExtractor()
print("Running feature extraction pass...")

# 3. Call get_features using the 'model' variable initialized in cell [24]
features = extractor.get_features(
    im_info=sample[1],
    gt_annotation=dataset.gt_annotations[sample[4]],
    raw_images_pil=sample[5],  # Your list of 19 PIL images from sample
    model=model,               # Your successfully loaded GPU checkpoint model
    preprocess=preprocess      # Your active validation transform
)

print("\nFeatures extracted successfully!")
print(f"Output shape/type: {type(features)}")
# Out:
# Running feature extraction pass...
#
# Features extracted successfully!
# Output shape/type: <class 'dict'>

# %% [markdown]
# Sanity Check

# %%
for k, v in features.items():
    if torch.is_tensor(v):
        print(k, v.shape, v.device)
    else:
        print(k, type(v), len(v))
# Out:
# obj_sr_features torch.Size([21, 9, 768]) cuda:0
# obj_sr_mask torch.Size([21, 7]) cuda:0
# obj_sr_gt torch.Size([21, 7]) cuda:0
# verb_img_features torch.Size([21, 768]) cuda:0
# verb_cls_features torch.Size([21, 768]) cuda:0
# verb_gt torch.Size([21]) cuda:0
# verb_sr_features torch.Size([21, 9, 768]) cuda:0
# verb_sr_mask torch.Size([21, 7]) cuda:0
# verb_sr_gt torch.Size([21, 7]) cuda:0
# noun_frame_lengths <class 'list'> 21
# n_roles <class 'list'> 21
# v_frame_lengths <class 'list'> 21
# v_roles <class 'list'> 21

# %% [markdown]
# validating the network forward pass

# %%
from model import InComNet

net = InComNet().cuda()
net.eval()

obj_logits, obj_q = net(
    True, False, False,
    features["obj_sr_features"],
    features["obj_sr_mask"],
    None, None,
    None, None
)

print("obj_logits:", obj_logits.shape)
print("obj_q:", obj_q.shape)
# Out:
# obj_logits: torch.Size([21, 7, 364])
# obj_q: torch.Size([21, 7, 768])

# %% [markdown]
# validate the verb branch:

# %%
verb_feat = torch.cat(
    [
        features["verb_img_features"].unsqueeze(1),
        features["verb_cls_features"].unsqueeze(1),
        obj_q
    ],
    dim=1
)

verb_logits, verb_q = net(
    False, True, False,
    None, None,
    verb_feat, None,
    None, None
)

print("verb_logits:", verb_logits.shape)
print("verb_q:", verb_q.shape)
# Out:
# verb_logits: torch.Size([21, 1, 17])
# verb_q: torch.Size([21, 1, 768])

# %% [markdown]
# validate verb SR:

# %%
verb_sr_feat = torch.cat(
    [
        verb_q,
        features["verb_sr_features"]
    ],
    dim=1
)

verb_sr_logits, verb_sr_q = net(
    False, False, True,
    None, None,
    None, None,
    verb_sr_feat,
    features["verb_sr_mask"]
)

print("verb_sr_logits:", verb_sr_logits.shape)
print("verb_sr_q:", verb_sr_q.shape)
# Out:
# verb_sr_logits: torch.Size([21, 7, 125])
# verb_sr_q: torch.Size([21, 7, 768])

# %% [markdown]
# **Validation Result**
#
# **Dataset**
#
# ✓ object_classes.txt
#
# ✓ relationship_classes.txt
#
# ✓ roles.txt
#
# ✓ ag_ssg_combined_person.pkl
#
# ✓ ssg_dataset.pkl
#
# ✓ frame paths fixed
#
# ✓ test dataset loads
#
# **CLIP**
#
# ✓ ViT-L-14-336 architecture
# ✓ Fine-tuned checkpoint loads
# ✓ Image encoder works
# ✓ Text encoder works
# ✓ Visual prompting works
# ✓ 768-dimensional embeddings
#
# **Feature Extraction**
#
# ✓ Object SR features
#
# ✓ Verb features
#
# ✓ Verb SR features
#
# ✓ Masks
#
# ✓ Ground-truth tensors
#
# ✓ All tensors on cuda:0
#
# **InComNet**
#
# ✓ Object SR branch
#
# ✓ Verb branch
#
# ✓ Verb SR branch
#
# ✓ Tensor dimensions match
#
# ✓ Forward pass succeeds
#
#
# **Pipeline Till Now**
#
# Action Genome
#
#       ↓
#
# SSG annotations
#
#       ↓
#
# CLIP feature extraction
#
#       ↓
#
# InComNet feature construction
#
#       ↓
#
# InComNet forward pass

# %% [markdown]
# # **Training Part**

# %% [markdown]
# Single training

# %%
from model import InComNet
import torch.nn as nn

net = InComNet().cuda()

criterion = nn.CrossEntropyLoss(
    ignore_index=365,
    reduction='none'
)

optimizer = torch.optim.Adamax(
    net.parameters(),
    lr=1e-3
)

# %% [markdown]
# First Object SR loss:

# %%
obj_logits, obj_q = net(
    True, False, False,
    features["obj_sr_features"],
    features["obj_sr_mask"],
    None, None,
    None, None
)

obj_logits = obj_logits.view(-1, 364)
obj_gt = features["obj_sr_gt"].view(-1)

obj_loss = criterion(obj_logits, obj_gt)

print(obj_loss.mean())
# Out:
# tensor(4.1902, device='cuda:0', grad_fn=<MeanBackward0>)

# %%
obj_loss.mean().backward()
optimizer.step()

# %%
args.data_path
args.frame_path
args.clip_sft_path
args.device
args.save_path
# Out:
# '/content/drive/MyDrive/project/SSG/incomnet_trained_models'

# %%
args.data_path = "/content/drive/MyDrive/project/SSG/data/"
args.frame_path = "/content/drive/MyDrive/project/SSG/data/frames/"
args.clip_sft_path = CLIP_CKPT
args.device = "cuda:0"
# args.save_path = "/content/drive/MyDrive/project/SSG/incomnet_ckpts"

# %%
args.datasize = "mini"
args.nepochs = 1

# %% [markdown]
# # **Train.py**

# %%
# %%writefile train.py

import time
import os
import copy

import torch
import torch.nn as nn
from torch.optim.lr_scheduler import ExponentialLR
import numpy as np
np.set_printoptions(precision=3)
import wandb
import json

import clip
import open_clip

from model import InComNet
from feature_extraction import FeatureExtractor
from dataset import AG, cuda_collate_fn
from evaluation import EvaluateInComNet
from config import parse_args

import warnings
warnings.filterwarnings('ignore')

def train(args):

    torch.manual_seed(args.seed)

    if not os.path.exists(args.save_path):
        os.mkdir(args.save_path)

    # Automatically identify if we are testing a tiny set first
    is_test_run = getattr(args, 'datasize', 'large') == 'mini' or getattr(args, 'nepochs', 30) == 1
    if is_test_run:
        print("\n🚀 [FAST DEV RUN] Activated! Truncating training loops to 2 batches to test integrity.")

    # =========================================================================
    # ADDED: PIPELINE PROVENANCE LOGGING
    # =========================================================================
    print("\n" + "=" * 60)
    print("📋 ACTIVE PIPELINE RUNTIME LOGS")
    print("=" * 60)
    print(f"📊 DATASET PROFILE : {getattr(args, 'datasize', 'NOT SPECIFIED').upper()} dataset split")
    print(f"🛠️ EXTRACTION MODE : {getattr(args, 'mode', 'NOT SPECIFIED')}")

    # Track the fine-tuning checkpoint path
    sft_path = getattr(args, 'clip_sft_path', None)
    if args.clip_model == 'ViT_L_14_336_sft' and sft_path:
        print(f"💾 CLIP CHECKPOINT : {sft_path}")
    else:
        print(f"💾 CLIP CHECKPOINT : Using baseline OpenAI weights ({args.clip_model})")
    print("=" * 60 + "\n")
    # =========================================================================

    #### Initialize wandb
    if args.wandb:
        run = wandb.init(
            mode='online',
            project="InComNet",
            name="InComNet-ViT-L-14-336-sft",
            config={
                "learning_rate": args.lr,
                "epochs": args.nepochs,
            },
        )

    #### Choose CLIP model
    if args.clip_model == 'ViT_B_32':
        model, preprocess = clip.load('ViT-B/32', args.device)
    elif args.clip_model == 'ViT_L_14_336':
        model, preprocess = clip.load('ViT-L/14@336px', args.device)
    elif args.clip_model == 'ViT_L_14_336_sft':
        model_name = "ViT-L-14-336"
        model, _, preprocess = open_clip.create_model_and_transforms(model_name = model_name, pretrained = args.clip_sft_path)
    model.to(args.device)

    AG_dataset_train = AG(mode="train", datasize=args.datasize, data_path=args.data_path, frame_path=args.frame_path, filter_nonperson_box_frame=True,
                        filter_small_box=False if args.mode == 'predcls' else True, preprocess = preprocess)
    dataloader_train = torch.utils.data.DataLoader(AG_dataset_train, shuffle=False, num_workers=4,
                                                collate_fn=cuda_collate_fn, pin_memory=False)
    AG_dataset_test = AG(mode="test", datasize=args.datasize, data_path=args.data_path, frame_path=args.frame_path, filter_nonperson_box_frame=True,
                        filter_small_box=False if args.mode == 'predcls' else True, preprocess = preprocess)
    dataloader_test = torch.utils.data.DataLoader(AG_dataset_test, shuffle=False, num_workers=4,
                                                collate_fn=cuda_collate_fn, pin_memory=False)

    #### Load InComNet model
    incomnet_model = InComNet()
    incomnet_model.to(args.device)
    num_params = sum(p.numel() for p in incomnet_model.parameters())

    evaluation = EvaluateInComNet()
    feat_extractor = FeatureExtractor()

    criterion = nn.CrossEntropyLoss(ignore_index=365, reduction='none')
    optimizer = torch.optim.Adamax(incomnet_model.parameters(), lr=args.lr)
    scheduler = ExponentialLR(optimizer, gamma=0.9)

    best_val_acc = -1e8
    grand_loss = []

    for epoch in range(int(args.nepochs)):
        b = 0
        tr = []

        for data in dataloader_train:
            # Quick bypass: break training loop after 2 batches if running a mini test pass
            if is_test_run and b >= 2:
                print(f"Stopping epoch training early at batch {b} for test verification.")
                break

            objsr_loss = []
            vrb_loss = []
            vrbsr_loss = []
            start = time.time()

            incomnet_model.train()

            im_info = copy.deepcopy(data[1])
            gt_annotation = AG_dataset_train.gt_annotations[data[4]]
            raw_images_pil = copy.deepcopy(data[5])

            train_features = feat_extractor.get_features(im_info, gt_annotation, raw_images_pil, model, preprocess)
            obj_sr_features = train_features['obj_sr_features']
            obj_sr_mask = train_features['obj_sr_mask']
            obj_sr_gt = train_features['obj_sr_gt']
            verb_img_features = train_features['verb_img_features']
            verb_cls_features = train_features['verb_cls_features']
            verb_gt = train_features['verb_gt']
            verb_sr_features = train_features['verb_sr_features']
            verb_sr_mask = train_features['verb_sr_mask']
            verb_sr_gt = train_features['verb_sr_gt']
            noun_frame_lengths = train_features['noun_frame_lengths']
            n_roles = train_features['n_roles']
            v_frame_lengths = train_features['v_frame_lengths']
            v_roles = train_features['v_roles']

            loss = 0
            obj_sr_loss = 0
            verb_loss = 0
            verb_sr_loss = 0

            for i in range(10):
                if i == 0:
                    # obj SR
                    obj_sr_flag, verb_flag, verb_sr_flag = True, False, False
                    obj_sr_logits, obj_sr_q = incomnet_model(obj_sr_flag, verb_flag, verb_sr_flag, obj_sr_features, obj_sr_mask, verb=None, verb_mask=None, verb_sr_frame=None, verb_sr_mask = None)
                    obj_sr_logits = obj_sr_logits.view(-1, 364)
                    obj_sr_gt = obj_sr_gt.view(-1)
                    obj_sr_loss = criterion(obj_sr_logits, obj_sr_gt)

                elif i >= 1:
                    obj_sr_flag, verb_flag, verb_sr_flag = True, False, False
                    obj_sr2_features = torch.cat([verb_q, obj_sr_features], dim=1)
                    obj_sr_logits, obj_sr_q = incomnet_model(obj_sr_flag, verb_flag, verb_sr_flag, obj_sr2_features, obj_sr_mask, verb=None, verb_mask=None, verb_sr_frame=None, verb_sr_mask = None)
                    obj_sr_logits = obj_sr_logits.view(-1, 364)
                    obj_sr_gt = obj_sr_gt.view(-1)
                    obj_sr_loss = criterion(obj_sr_logits, obj_sr_gt)

                # verb
                obj_sr_flag, verb_flag, verb_sr_flag = False, True, False
                verb_feat = torch.cat([verb_img_features.unsqueeze(1), verb_cls_features.unsqueeze(1), obj_sr_q], dim=1)
                verb_logits, verb_q = incomnet_model(obj_sr_flag, verb_flag, verb_sr_flag, obj_sr_features, obj_sr_mask, verb_feat, verb_mask=None, verb_sr_frame=None, verb_sr_mask=None)
                verb_logits = verb_logits.squeeze()

                # Reshaping fallback if batch has a single spatial pair
                if verb_logits.dim() == 1:
                    verb_logits = verb_logits.unsqueeze(0)
                verb_loss = criterion(verb_logits, verb_gt)

                # verb SR
                obj_sr_flag, verb_flag, verb_sr_flag = False, False, True
                verb_sr_feat = torch.cat([verb_q, verb_sr_features], dim=1)
                verb_mask = None
                verb_sr_logits, verb_sr_q = incomnet_model(obj_sr_flag, verb_flag, verb_sr_flag, obj_sr_features, obj_sr_mask, verb_feat, verb_mask, verb_sr_feat, verb_sr_mask)
                verb_sr_logits = verb_sr_logits.view(-1, 125)
                verb_sr_gt = verb_sr_gt.view(-1)
                verb_sr_loss = criterion(verb_sr_logits, verb_sr_gt)

                iter_loss = torch.mean(obj_sr_loss) + torch.mean(verb_loss) + torch.mean(verb_sr_loss)
                loss += iter_loss

                objsr_loss.append(torch.mean(obj_sr_loss).item())
                vrb_loss.append(torch.mean(verb_loss).item())
                vrbsr_loss.append(torch.mean(verb_sr_loss).item())

            optimizer.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(incomnet_model.parameters(), max_norm=5, norm_type=2)
            optimizer.step()

            tr.append(loss.item())

            time_per_batch = (time.time() - start)
            current_lr = optimizer.param_groups[0]['lr']

            if args.wandb:
                run.log({"loss": loss, "objsr_loss": np.mean(objsr_loss), "vrb_loss": np.mean(vrb_loss), "vrbsr_loss":np.mean(vrbsr_loss)})

            log_dict = {}
            log_dict['epoch'] = epoch
            log_dict['batch'] = b
            log_dict['learning_rate'] = current_lr
            log_dict['mean_loss'] = loss
            log_dict['obj_SR_loss'] = np.mean(objsr_loss)
            log_dict['verb_loss'] = np.mean(vrb_loss)
            log_dict['verb_SR_loss'] = np.mean(vrbsr_loss)

            # Print status instantly for early validation testing
            formatted = (
                        f"epoch : {log_dict['epoch']}  batch : {log_dict['batch']}  "
                        f"learning rate : {log_dict['learning_rate']:.4f}, "
                        f"loss : {log_dict['mean_loss']:.3f}, "
                        f"obj SR loss : {log_dict['obj_SR_loss']:.3f}, "
                        f"verb loss : {log_dict['verb_loss']:.3f}, "
                        f"verb SR loss : {log_dict['verb_SR_loss']:.3f}"
                    )
            print(formatted)

            b += 1
            start = time.time()

        incomnet_model.eval()
        start = time.time()

        obj_sr_pred_list, obj_sr_gt_list, verb_pred_list, verb_gt_list, verb_sr_pred_list, verb_sr_gt_list, obj_frame_lengths, obj_roles, verb_frame_lengths, verb_roles = [], [], [], [], [], [], [], [], [], []

        test_b = 0
        for data_test in dataloader_test:
            # Quick bypass: break evaluation loop after 2 batches if testing framework pipeline
            if is_test_run and test_b >= 2:
                print(f"Stopping evaluation early at batch {test_b} for testing cycle closure.")
                break

            im_info = copy.deepcopy(data_test[1])
            gt_annotation = AG_dataset_test.gt_annotations[data_test[4]]
            raw_images_pil_test = copy.deepcopy(data_test[5])

            test_features = feat_extractor.get_features(im_info, gt_annotation, raw_images_pil_test, model, preprocess)
            obj_sr_features = test_features['obj_sr_features']
            obj_sr_mask = test_features['obj_sr_mask']
            obj_sr_gt = test_features['obj_sr_gt']
            verb_img_features = test_features['verb_img_features']
            verb_cls_features = test_features['verb_cls_features']
            verb_gt = test_features['verb_gt']
            verb_sr_features = test_features['verb_sr_features']
            verb_sr_mask = test_features['verb_sr_mask']
            verb_sr_gt = test_features['verb_sr_gt']
            noun_frame_lengths = test_features['noun_frame_lengths']
            n_roles = test_features['n_roles']
            v_frame_lengths = test_features['v_frame_lengths']
            v_roles = test_features['v_roles']

            obj_frame_lengths.extend(noun_frame_lengths)
            obj_roles.extend(n_roles)
            verb_frame_lengths.extend(v_frame_lengths)
            verb_roles.extend(v_roles)

            for i in range(args.iterations):
                if i == 0:
                    obj_sr_flag, verb_flag, verb_sr_flag = True, False, False
                    obj_sr_logits, obj_sr_q = incomnet_model(obj_sr_flag, verb_flag, verb_sr_flag, obj_sr_features, obj_sr_mask, verb=None, verb_mask=None, verb_sr_frame=None, verb_sr_mask = None)

                elif i >= 1:
                    obj_sr_flag, verb_flag, verb_sr_flag = True, False, False
                    obj_sr2_features = torch.cat([verb_q, obj_sr_features], dim=1)
                    obj_sr_logits, obj_sr_q = incomnet_model(obj_sr_flag, verb_flag, verb_sr_flag, obj_sr2_features, obj_sr_mask, verb=None, verb_mask=None, verb_sr_frame=None, verb_sr_mask = None)

                # verb
                obj_sr_flag, verb_flag, verb_sr_flag = False, True, False
                verb_feat = torch.cat([verb_img_features.unsqueeze(1), verb_cls_features.unsqueeze(1), obj_sr_q], dim=1)
                verb_logits, verb_q = incomnet_model(obj_sr_flag, verb_flag, verb_sr_flag, obj_sr_features, obj_sr_mask, verb_feat, verb_mask=None, verb_sr_frame=None, verb_sr_mask=None)

                # verb SR
                obj_sr_flag, verb_flag, verb_sr_flag = False, False, True
                verb_sr_feat = torch.cat([verb_q, verb_sr_features], dim=1)
                verb_mask = None
                verb_sr_logits, verb_sr_q = incomnet_model(obj_sr_flag, verb_flag, verb_sr_flag, obj_sr_features, obj_sr_mask, verb_feat, verb_mask, verb_sr_feat, verb_sr_mask)

            obj_sr_logits = obj_sr_logits.view(-1, 364)
            obj_sr_gt = obj_sr_gt.view(-1)
            pred_obj_sr_labels = torch.argmax(obj_sr_logits, dim=1)
            obj_sr_pred_list.extend(pred_obj_sr_labels.tolist())
            obj_sr_gt_list.extend(obj_sr_gt.tolist())

            verb_logits = verb_logits.squeeze()
            if verb_logits.dim() == 1:
                verb_logits = verb_logits.unsqueeze(0)
            pred_verb_labels = torch.argmax(verb_logits, dim=1)
            verb_pred_list.extend(pred_verb_labels.tolist())
            verb_gt_list.extend(verb_gt.tolist())

            verb_sr_logits = verb_sr_logits.view(-1, 125)
            verb_sr_gt = verb_sr_gt.view(-1)
            pred_verb_sr_labels = torch.argmax(verb_sr_logits, dim=1)
            verb_sr_pred_list.extend(pred_verb_sr_labels.tolist())
            verb_sr_gt_list.extend(verb_sr_gt.tolist())
            test_b += 1

        obj_result, verb_result, verb_sr_result = evaluation.evaluate(obj_sr_gt_list, obj_sr_pred_list, obj_frame_lengths, obj_roles, verb_gt_list, verb_pred_list, verb_sr_gt_list, verb_sr_pred_list, verb_frame_lengths, verb_roles)

        print("\nObject SR result:")
        for key, value in obj_result.items():
            print(f"{key}: {value}")

        print("\nVerb result:")
        for key, value in verb_result.items():
            print(f"{key}: {value}")

        print("\nVerb SR result:")
        for key, value in verb_sr_result.items():
            print(f"{key}: {value}")

        val_acc = obj_result['Value'] + verb_result['Accuracy'] + verb_sr_result['Value']

        print("avg epoch performance : ",  val_acc)
        print("*" * 100)
        scheduler.step()

        if val_acc > best_val_acc:
            print("val_acc is: ", epoch, val_acc)
            torch.save({"state_dict": incomnet_model.state_dict()}, os.path.join(args.save_path, f"incomnet_epoch_{epoch}.tar"))
            print("save the checkpoint after {} epochs".format(epoch))
            best_val_acc = val_acc

        with open("log_incomnet.txt", "a") as f:
            f.write(f"epoch_{epoch} Object SR: ")
            f.write(json.dumps(obj_result) + "\n")
        with open("log_incomnet.txt", "a") as f:
            f.write(f"epoch_{epoch} Verb predicate: ")
            f.write(json.dumps(verb_result) + "\n")
        with open("log_incomnet.txt", "a") as f:
            f.write(f"epoch_{epoch} Verb predicate SR: ")
            f.write(json.dumps(verb_sr_result) + "\n")


if __name__ == "__main__":
    torch.cuda.empty_cache()
    t1 = time.time()

    #### Configurations
    args = parse_args()

    print("############### Configurations ###############")
    for key, value in vars(args).items():
        print(f"{key}: {value}")
    print("##############################################")

    train(args)
# Out:
# Writing train.py

# %% [markdown]
# A Small fix in data set.py

# %%
import sys

# 1. Read your existing dataset.py file into memory
with open("/content/dataset.py", "r") as f:
    lines = f.readlines()

# 2. Modify line 130 to safely check if the key exists before indexing
updated_content = ""
for line in lines:
    if "small_object[i] = object_bbox[i]" in line:
        # Wrap the assignment in a safe 'if key in dictionary' condition
        indent = line =="" or line.split("small_object")[0]
        updated_content += f"{indent}if i in object_bbox:\n{indent}    small_object[i] = object_bbox[i]\n"
    else:
        updated_content += line

# 3. Save the corrected dataset code back to the file
with open("/content/dataset.py", "w") as f:
    f.write(updated_content)

print("SUCCESS: dataset.py successfully updated with safe key lookups!")
# Out:
# SUCCESS: dataset.py successfully updated with safe key lookups!

# %%
# 1. Clear old module versions from memory cache
import sys
for mod in ['config', 'dataset', 'feature_extraction', 'train', 'model']:
    if mod in sys.modules:
        del sys.modules[mod]

# 2. Re-run your miniature verification test pass
# !python train.py \
    --data_path "/content/drive/MyDrive/project/SSG/data/" \
    --frame_path "/content/drive/MyDrive/project/SSG/data/frames/" \
    --clip_sft_path "/content/drive/MyDrive/project/SSG/open_clip_backups/checkpoints/epoch_3.pt" \
    --save_path "/content/drive/MyDrive/project/SSG/incomnet_ckpts" \
    --device "cuda:0" \
    --datasize "mini" \
    --nepochs 1
# Out:
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# ############### Configurations ###############
# optimizer: adamax
# lr: 0.001
# nepochs: 1.0
# mode: predcls
# iterations: 10
# clip_model: ViT_L_14_336_sft
# clip_sft_path: /content/drive/MyDrive/project/SSG/open_clip_backups/checkpoints/epoch_3.pt
# data_path: /content/drive/MyDrive/project/SSG/data/
# frame_path: /content/drive/MyDrive/project/SSG/data/frames/
# datasize: mini
# save_path: /content/drive/MyDrive/project/SSG/incomnet_ckpts
# model_path: /content/drive/MyDrive/project/SSG/incomnet_trained_models
# ckpt: /content/drive/MyDrive/project/SSG/incomnet_trained_models/incomnet-224_epoch_0.tar
# ckpt_person: /content/drive/MyDrive/project/SSG/incomnet_trained_models/incomnet-224_person_epoch_0.tar
# top1: True
# seed: 2222
# device: cuda:0
# wandb: False
# temporal_window: 3
# ##############################################
#
# 🚀 [FAST DEV RUN] Activated! Truncating training loops to 2 batches to test integrity.
#
# ============================================================
# 📋 ACTIVE PIPELINE RUNTIME LOGS
# ============================================================
# 📊 DATASET PROFILE : MINI dataset split
# 🛠️ EXTRACTION MODE : predcls
# 💾 CLIP CHECKPOINT : /content/drive/MyDrive/project/SSG/open_clip_backups/checkpoints/epoch_3.pt
# ============================================================
#
# -------loading annotations---------slowly-----------
# Removed 004QE.mp4/000273.png as it has one contacting relationship and it is 'other relationship'
# Removed 004QE.mp4/000343.png as it has one contacting relationship and it is 'other relationship'
# Removed 05124.mp4/000603.png as it has one contacting relationship and it is 'other relationship'
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# There are 29 videos and 623 valid frames
# 1 videos are invalid (no person), remove them
# 0 videos are invalid (only one frame), remove them
# 67 frames have no human bbox in GT, remove them!
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# -------loading annotations---------slowly-----------
# Removed 00T1E.mp4/000240.png as it has one contacting relationship and it is 'other relationship'
# Removed 03PRW.mp4/000240.png as it has one contacting relationship and it is 'other relationship'
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# There are 4 videos and 126 valid frames
# 1 videos are invalid (no person), remove them
# 0 videos are invalid (only one frame), remove them
# 68 frames have no human bbox in GT, remove them!
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# epoch : 0  batch : 0  learning rate : 0.0010, loss : 88.482, obj SR loss : 3.937, verb loss : 2.901, verb SR loss : 2.010
# epoch : 0  batch : 1  learning rate : 0.0010, loss : 86.765, obj SR loss : 3.414, verb loss : 2.479, verb SR loss : 2.784
# Stopping epoch training early at batch 2 for test verification.
# Stopping evaluation early at batch 2 for testing cycle closure.
#
# Object SR result:
# Accuracy: 7.792207792207792
# mR: 5.88235294117647
# mP: 0.45836516424751717
# F1: 0.8504606661941885
# Value: 32.87671232876712
# Value-two: 0.0
# value-all: 0.0
# role_based_accuracy: 14.285714285714286
# role_based_mP: 14.285714285714286
# role_based_mR: 14.285714285714286
# role_based_f1: 14.285714285714286
#
# Verb result:
# Accuracy: 35.61643835616438
# mR: 16.666666666666664
# mP: 5.93607305936073
# F1: 8.754208754208754
#
# Verb SR result:
# Accuracy: 10.869565217391305
# mR: 10.0
# mP: 1.0869565217391304
# F1: 1.9607843137254901
# Value: 34.24657534246575
# Value-two: 0.0
# value-all: 0.0
# role_based_accuracy: 19.230769230769234
# role_based_mP: 10.0
# role_based_mR: 9.615384615384617
# role_based_f1: 9.80392156862745
# avg epoch performance :  102.73972602739724
# ****************************************************************************************************
# val_acc is:  0 102.73972602739724
# save the checkpoint after 0 epochs

# %% [markdown]
# Full Training

# %%
# 1. Clear the module runtime cache one last time
import sys
for mod in ['config', 'dataset', 'feature_extraction', 'train', 'model']:
    if mod in sys.modules:
        del sys.modules[mod]

# 2. Create the deep nested directories safely
# !mkdir -p "/content/drive/MyDrive/project/SSG/temporal/11Jul"

# 2. Kick off the full, deep training cycle
# !python train.py \
    --data_path "/content/drive/MyDrive/project/SSG/data/" \
    --frame_path "/content/drive/MyDrive/project/SSG/data/frames/" \
    --clip_sft_path "/content/drive/MyDrive/project/SSG/open_clip_backups/checkpoints/epoch_3.pt" \
    --save_path "/content/drive/MyDrive/project/SSG/temporal/11Jul" \
    --device "cuda:0" \
    --datasize "large" \
    --nepochs 30
# Out:
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# ############### Configurations ###############
# optimizer: adamax
# lr: 0.001
# nepochs: 30.0
# mode: predcls
# iterations: 10
# clip_model: ViT_L_14_336_sft
# clip_sft_path: /content/drive/MyDrive/project/SSG/open_clip_backups/checkpoints/epoch_3.pt
# data_path: /content/drive/MyDrive/project/SSG/data/
# frame_path: /content/drive/MyDrive/project/SSG/data/frames/
# datasize: large
# save_path: /content/drive/MyDrive/project/SSG/temporal/11Jul
# model_path: /content/drive/MyDrive/project/SSG/incomnet_trained_models
# ckpt: /content/drive/MyDrive/project/SSG/incomnet_trained_models/incomnet-224_epoch_0.tar
# ckpt_person: /content/drive/MyDrive/project/SSG/incomnet_trained_models/incomnet-224_person_epoch_0.tar
# top1: True
# seed: 2222
# device: cuda:0
# wandb: False
# temporal_window: 3
# ##############################################
#
# ============================================================
# 📋 ACTIVE PIPELINE RUNTIME LOGS
# ============================================================
# 📊 DATASET PROFILE : LARGE dataset split
# 🛠️ EXTRACTION MODE : predcls
# 💾 CLIP CHECKPOINT : /content/drive/MyDrive/project/SSG/open_clip_backups/checkpoints/epoch_3.pt
# ============================================================
#
# -------loading annotations---------slowly-----------
# Removed CGNBJ.mp4/000959.png as it has one contacting relationship and it is 'other relationship'
# Removed 004QE.mp4/000273.png as it has one contacting relationship and it is 'other relationship'
# Removed 004QE.mp4/000343.png as it has one contacting relationship and it is 'other relationship'
# Removed BOC1T.mp4/000055.png as it has one contacting relationship and it is 'other relationship'
# Removed BOC1T.mp4/000379.png as it has one contacting relationship and it is 'other relationship'
# Removed BOC1T.mp4/000271.png as it has one contacting relationship and it is 'other relationship'
# Removed BOC1T.mp4/000497.png as it has one contacting relationship and it is 'other relationship'
# Removed 05124.mp4/000603.png as it has one contacting relationship and it is 'other relationship'
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# There are 30 videos and 632 valid frames
# 2 videos are invalid (no person), remove them
# 0 videos are invalid (only one frame), remove them
# 68 frames have no human bbox in GT, remove them!
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# -------loading annotations---------slowly-----------
# Removed 03PRW.mp4/000240.png as it has one contacting relationship and it is 'other relationship'
# Removed 00T1E.mp4/000240.png as it has one contacting relationship and it is 'other relationship'
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# There are 4 videos and 126 valid frames
# 1 videos are invalid (no person), remove them
# 0 videos are invalid (only one frame), remove them
# 68 frames have no human bbox in GT, remove them!
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# epoch : 0  batch : 0  learning rate : 0.0010, loss : 89.390, obj SR loss : 4.313, verb loss : 2.881, verb SR loss : 1.745
# epoch : 0  batch : 1  learning rate : 0.0010, loss : 99.946, obj SR loss : 3.736, verb loss : 3.973, verb SR loss : 2.286
# epoch : 0  batch : 2  learning rate : 0.0010, loss : 148.468, obj SR loss : 3.954, verb loss : 8.881, verb SR loss : 2.012
# epoch : 0  batch : 3  learning rate : 0.0010, loss : 85.149, obj SR loss : 2.407, verb loss : 3.973, verb SR loss : 2.135
# epoch : 0  batch : 4  learning rate : 0.0010, loss : 79.761, obj SR loss : 3.483, verb loss : 2.932, verb SR loss : 1.560
# epoch : 0  batch : 5  learning rate : 0.0010, loss : 88.094, obj SR loss : 2.764, verb loss : 4.842, verb SR loss : 1.203
# epoch : 0  batch : 6  learning rate : 0.0010, loss : 46.512, obj SR loss : 2.387, verb loss : 1.230, verb SR loss : 1.034
# epoch : 0  batch : 7  learning rate : 0.0010, loss : 74.226, obj SR loss : 2.946, verb loss : 2.799, verb SR loss : 1.678
# epoch : 0  batch : 8  learning rate : 0.0010, loss : 72.817, obj SR loss : 3.360, verb loss : 2.639, verb SR loss : 1.283
# epoch : 0  batch : 9  learning rate : 0.0010, loss : 63.652, obj SR loss : 3.407, verb loss : 0.502, verb SR loss : 2.456
# epoch : 0  batch : 10  learning rate : 0.0010, loss : 67.311, obj SR loss : 2.973, verb loss : 1.842, verb SR loss : 1.916
# epoch : 0  batch : 11  learning rate : 0.0010, loss : 86.546, obj SR loss : 3.412, verb loss : 3.694, verb SR loss : 1.549
# epoch : 0  batch : 12  learning rate : 0.0010, loss : 64.087, obj SR loss : 2.004, verb loss : 3.091, verb SR loss : 1.314
# epoch : 0  batch : 13  learning rate : 0.0010, loss : 73.322, obj SR loss : 2.107, verb loss : 3.704, verb SR loss : 1.521
# epoch : 0  batch : 14  learning rate : 0.0010, loss : 75.543, obj SR loss : 3.097, verb loss : 2.525, verb SR loss : 1.932
# epoch : 0  batch : 15  learning rate : 0.0010, loss : 75.514, obj SR loss : 4.280, verb loss : 1.631, verb SR loss : 1.640
# epoch : 0  batch : 16  learning rate : 0.0010, loss : 66.367, obj SR loss : 2.806, verb loss : 2.066, verb SR loss : 1.765
# epoch : 0  batch : 17  learning rate : 0.0010, loss : 78.652, obj SR loss : 3.155, verb loss : 3.486, verb SR loss : 1.224
# epoch : 0  batch : 18  learning rate : 0.0010, loss : 64.759, obj SR loss : 3.251, verb loss : 0.973, verb SR loss : 2.252
# epoch : 0  batch : 19  learning rate : 0.0010, loss : 102.396, obj SR loss : 5.249, verb loss : 3.475, verb SR loss : 1.516
# epoch : 0  batch : 20  learning rate : 0.0010, loss : 87.162, obj SR loss : 3.526, verb loss : 3.632, verb SR loss : 1.558
# epoch : 0  batch : 21  learning rate : 0.0010, loss : 64.001, obj SR loss : 3.819, verb loss : 1.236, verb SR loss : 1.345
# epoch : 0  batch : 22  learning rate : 0.0010, loss : 76.663, obj SR loss : 2.827, verb loss : 2.911, verb SR loss : 1.928
# epoch : 0  batch : 23  learning rate : 0.0010, loss : 59.462, obj SR loss : 2.645, verb loss : 1.960, verb SR loss : 1.342
# epoch : 0  batch : 24  learning rate : 0.0010, loss : 97.069, obj SR loss : 2.323, verb loss : 5.082, verb SR loss : 2.302
# epoch : 0  batch : 25  learning rate : 0.0010, loss : 68.923, obj SR loss : 3.154, verb loss : 2.411, verb SR loss : 1.328
# epoch : 0  batch : 26  learning rate : 0.0010, loss : 82.064, obj SR loss : 2.622, verb loss : 3.571, verb SR loss : 2.013
# epoch : 0  batch : 27  learning rate : 0.0010, loss : 60.735, obj SR loss : 2.707, verb loss : 1.672, verb SR loss : 1.695
# epoch : 0  batch : 28  learning rate : 0.0010, loss : 56.916, obj SR loss : 2.634, verb loss : 1.152, verb SR loss : 1.905
# epoch : 0  batch : 29  learning rate : 0.0010, loss : 62.944, obj SR loss : 3.458, verb loss : 1.328, verb SR loss : 1.508
#
# Object SR result:
# Accuracy: 0.0
# mR: 0.0
# mP: 0.0
# F1: 0.0
# Value: 0.0
# Value-two: 0.0
# value-all: 0.0
# role_based_accuracy: 0.0
# role_based_mP: 0.0
# role_based_mR: 0.0
# role_based_f1: 0.0
#
# Verb result:
# Accuracy: 17.842323651452283
# mR: 11.11111111111111
# mP: 1.98248040571692
# F1: 3.3646322378716746
#
# Verb SR result:
# Accuracy: 33.99153737658674
# mR: 5.263157894736842
# mP: 1.7890282829782496
# F1: 2.6703601108033244
# Value: 17.842323651452283
# Value-two: 0.0
# value-all: 0.0
# role_based_accuracy: 1.9824804057169203
# role_based_mP: 0.9912402028584602
# role_based_mR: 5.555555555555555
# role_based_f1: 1.682316118935837
# avg epoch performance :  35.684647302904565
# ****************************************************************************************************
# val_acc is:  0 35.684647302904565
# save the checkpoint after 0 epochs
# epoch : 1  batch : 0  learning rate : 0.0009, loss : 74.021, obj SR loss : 3.841, verb loss : 2.397, verb SR loss : 1.164
# epoch : 1  batch : 1  learning rate : 0.0009, loss : 69.535, obj SR loss : 2.863, verb loss : 2.344, verb SR loss : 1.747
# epoch : 1  batch : 2  learning rate : 0.0009, loss : 68.183, obj SR loss : 3.338, verb loss : 2.098, verb SR loss : 1.383
# epoch : 1  batch : 3  learning rate : 0.0009, loss : 73.713, obj SR loss : 2.437, verb loss : 3.541, verb SR loss : 1.393
# epoch : 1  batch : 4  learning rate : 0.0009, loss : 71.488, obj SR loss : 3.160, verb loss : 2.282, verb SR loss : 1.707
# epoch : 1  batch : 5  learning rate : 0.0009, loss : 81.985, obj SR loss : 2.680, verb loss : 4.033, verb SR loss : 1.486
# epoch : 1  batch : 6  learning rate : 0.0009, loss : 47.755, obj SR loss : 2.257, verb loss : 1.486, verb SR loss : 1.032
# epoch : 1  batch : 7  learning rate : 0.0009, loss : 63.626, obj SR loss : 2.879, verb loss : 1.737, verb SR loss : 1.747
# epoch : 1  batch : 8  learning rate : 0.0009, loss : 43.237, obj SR loss : 2.755, verb loss : 0.679, verb SR loss : 0.889
# epoch : 1  batch : 9  learning rate : 0.0009, loss : 69.029, obj SR loss : 2.231, verb loss : 3.001, verb SR loss : 1.671
# epoch : 1  batch : 10  learning rate : 0.0009, loss : 56.272, obj SR loss : 2.292, verb loss : 1.732, verb SR loss : 1.603
# epoch : 1  batch : 11  learning rate : 0.0009, loss : 83.485, obj SR loss : 2.742, verb loss : 4.137, verb SR loss : 1.470
# epoch : 1  batch : 12  learning rate : 0.0009, loss : 47.112, obj SR loss : 2.009, verb loss : 1.615, verb SR loss : 1.087
# epoch : 1  batch : 13  learning rate : 0.0009, loss : 56.407, obj SR loss : 2.303, verb loss : 1.844, verb SR loss : 1.494
# epoch : 1  batch : 14  learning rate : 0.0009, loss : 64.947, obj SR loss : 2.770, verb loss : 1.818, verb SR loss : 1.907
# epoch : 1  batch : 15  learning rate : 0.0009, loss : 66.659, obj SR loss : 4.005, verb loss : 0.914, verb SR loss : 1.747
# epoch : 1  batch : 16  learning rate : 0.0009, loss : 58.269, obj SR loss : 2.739, verb loss : 1.698, verb SR loss : 1.390
# epoch : 1  batch : 17  learning rate : 0.0009, loss : 75.603, obj SR loss : 2.680, verb loss : 3.729, verb SR loss : 1.152
# epoch : 1  batch : 18  learning rate : 0.0009, loss : 58.970, obj SR loss : 2.918, verb loss : 0.836, verb SR loss : 2.143
# epoch : 1  batch : 19  learning rate : 0.0009, loss : 85.288, obj SR loss : 3.932, verb loss : 2.973, verb SR loss : 1.624
# epoch : 1  batch : 20  learning rate : 0.0009, loss : 82.793, obj SR loss : 3.010, verb loss : 3.730, verb SR loss : 1.540
# epoch : 1  batch : 21  learning rate : 0.0009, loss : 65.325, obj SR loss : 3.691, verb loss : 1.533, verb SR loss : 1.308
# epoch : 1  batch : 22  learning rate : 0.0009, loss : 81.766, obj SR loss : 2.541, verb loss : 3.734, verb SR loss : 1.902
# epoch : 1  batch : 23  learning rate : 0.0009, loss : 59.808, obj SR loss : 2.508, verb loss : 2.235, verb SR loss : 1.237
# epoch : 1  batch : 24  learning rate : 0.0009, loss : 77.845, obj SR loss : 2.048, verb loss : 3.518, verb SR loss : 2.218
# epoch : 1  batch : 25  learning rate : 0.0009, loss : 56.179, obj SR loss : 2.979, verb loss : 1.424, verb SR loss : 1.215
# epoch : 1  batch : 26  learning rate : 0.0009, loss : 69.575, obj SR loss : 2.555, verb loss : 2.400, verb SR loss : 2.002
# epoch : 1  batch : 27  learning rate : 0.0009, loss : 51.638, obj SR loss : 2.172, verb loss : 1.467, verb SR loss : 1.524
# epoch : 1  batch : 28  learning rate : 0.0009, loss : 57.959, obj SR loss : 2.289, verb loss : 1.548, verb SR loss : 1.959
# epoch : 1  batch : 29  learning rate : 0.0009, loss : 64.909, obj SR loss : 3.365, verb loss : 1.705, verb SR loss : 1.421
#
# Object SR result:
# Accuracy: 0.0
# mR: 0.0
# mP: 0.0
# F1: 0.0
# Value: 0.0
# Value-two: 0.0
# value-all: 0.0
# role_based_accuracy: 0.0
# role_based_mP: 0.0
# role_based_mR: 0.0
# role_based_f1: 0.0
#
# Verb result:
# Accuracy: 17.842323651452283
# mR: 11.11111111111111
# mP: 1.98248040571692
# F1: 3.3646322378716746
#
# Verb SR result:
# Accuracy: 33.99153737658674
# mR: 5.263157894736842
# mP: 1.7890282829782496
# F1: 2.6703601108033244
# Value: 17.842323651452283
# Value-two: 0.0
# value-all: 0.0
# role_based_accuracy: 1.9824804057169203
# role_based_mP: 0.9912402028584602
# role_based_mR: 5.555555555555555
# role_based_f1: 1.682316118935837
# avg epoch performance :  35.684647302904565
# ****************************************************************************************************
# epoch : 2  batch : 0  learning rate : 0.0008, loss : 67.876, obj SR loss : 4.082, verb loss : 1.360, verb SR loss : 1.345
# epoch : 2  batch : 1  learning rate : 0.0008, loss : 65.989, obj SR loss : 3.142, verb loss : 1.731, verb SR loss : 1.726
# epoch : 2  batch : 2  learning rate : 0.0008, loss : 63.530, obj SR loss : 3.507, verb loss : 1.547, verb SR loss : 1.299
# epoch : 2  batch : 3  learning rate : 0.0008, loss : 59.924, obj SR loss : 2.417, verb loss : 2.338, verb SR loss : 1.237
# epoch : 2  batch : 4  learning rate : 0.0008, loss : 61.217, obj SR loss : 3.031, verb loss : 1.670, verb SR loss : 1.420
# epoch : 2  batch : 5  learning rate : 0.0008, loss : 72.817, obj SR loss : 2.728, verb loss : 3.179, verb SR loss : 1.375
# epoch : 2  batch : 6  learning rate : 0.0008, loss : 43.806, obj SR loss : 2.210, verb loss : 1.215, verb SR loss : 0.956
# epoch : 2  batch : 7  learning rate : 0.0008, loss : 56.073, obj SR loss : 2.884, verb loss : 1.191, verb SR loss : 1.532
# epoch : 2  batch : 8  learning rate : 0.0008, loss : 34.365, obj SR loss : 2.072, verb loss : 0.417, verb SR loss : 0.948
# epoch : 2  batch : 9  learning rate : 0.0008, loss : 54.778, obj SR loss : 1.955, verb loss : 1.690, verb SR loss : 1.833
# epoch : 2  batch : 10  learning rate : 0.0008, loss : 53.999, obj SR loss : 2.276, verb loss : 1.607, verb SR loss : 1.516
# epoch : 2  batch : 11  learning rate : 0.0008, loss : 71.342, obj SR loss : 2.775, verb loss : 2.944, verb SR loss : 1.415
# epoch : 2  batch : 12  learning rate : 0.0008, loss : 47.617, obj SR loss : 2.096, verb loss : 1.533, verb SR loss : 1.133
# epoch : 2  batch : 13  learning rate : 0.0008, loss : 56.301, obj SR loss : 2.185, verb loss : 1.980, verb SR loss : 1.465
# epoch : 2  batch : 14  learning rate : 0.0008, loss : 64.447, obj SR loss : 2.563, verb loss : 1.866, verb SR loss : 2.016
# epoch : 2  batch : 15  learning rate : 0.0008, loss : 66.686, obj SR loss : 3.592, verb loss : 1.299, verb SR loss : 1.777
# epoch : 2  batch : 16  learning rate : 0.0008, loss : 54.127, obj SR loss : 2.543, verb loss : 1.450, verb SR loss : 1.420
# epoch : 2  batch : 17  learning rate : 0.0008, loss : 59.814, obj SR loss : 2.565, verb loss : 2.344, verb SR loss : 1.072
# epoch : 2  batch : 18  learning rate : 0.0008, loss : 53.306, obj SR loss : 2.623, verb loss : 0.822, verb SR loss : 1.886
# epoch : 2  batch : 19  learning rate : 0.0008, loss : 76.970, obj SR loss : 3.918, verb loss : 2.411, verb SR loss : 1.368
# epoch : 2  batch : 20  learning rate : 0.0008, loss : 72.368, obj SR loss : 2.976, verb loss : 3.025, verb SR loss : 1.237
# epoch : 2  batch : 21  learning rate : 0.0008, loss : 63.039, obj SR loss : 3.396, verb loss : 1.840, verb SR loss : 1.069
# epoch : 2  batch : 22  learning rate : 0.0008, loss : 74.651, obj SR loss : 2.633, verb loss : 3.044, verb SR loss : 1.788
# epoch : 2  batch : 23  learning rate : 0.0008, loss : 54.985, obj SR loss : 2.483, verb loss : 1.750, verb SR loss : 1.266
# epoch : 2  batch : 24  learning rate : 0.0008, loss : 73.062, obj SR loss : 2.224, verb loss : 3.067, verb SR loss : 2.016
# epoch : 2  batch : 25  learning rate : 0.0008, loss : 57.020, obj SR loss : 3.125, verb loss : 1.241, verb SR loss : 1.336
# epoch : 2  batch : 26  learning rate : 0.0008, loss : 58.554, obj SR loss : 2.456, verb loss : 1.668, verb SR loss : 1.732
# epoch : 2  batch : 27  learning rate : 0.0008, loss : 52.417, obj SR loss : 2.409, verb loss : 1.331, verb SR loss : 1.502
# epoch : 2  batch : 28  learning rate : 0.0008, loss : 51.651, obj SR loss : 2.183, verb loss : 1.314, verb SR loss : 1.667
# epoch : 2  batch : 29  learning rate : 0.0008, loss : 62.283, obj SR loss : 2.963, verb loss : 1.777, verb SR loss : 1.488
#
# Object SR result:
# Accuracy: 6.28997867803838
# mR: 3.0303030303030303
# mP: 0.1906054144860115
# F1: 0.3586517127138993
# Value: 24.481327800829874
# Value-two: 0.0
# value-all: 0.0
# role_based_accuracy: 14.788535807832103
# role_based_mP: 5.553708018876862
# role_based_mR: 11.856661856661857
# role_based_f1: 7.209285143169442
#
# Verb result:
# Accuracy: 45.22821576763486
# mR: 19.758751040161172
# mP: 12.846560846560845
# F1: 15.051755053249291
#
# Verb SR result:
# Accuracy: 33.99153737658674
# mR: 5.263157894736842
# mP: 1.7890282829782496
# F1: 2.6703601108033244
# Value: 45.22821576763486
# Value-two: 0.0
# value-all: 0.0
# role_based_accuracy: 5.025357307514984
# role_based_mP: 2.512678653757492
# role_based_mR: 5.555555555555555
# role_based_f1: 3.4603174603174605
# avg epoch performance :  114.93775933609959
# ****************************************************************************************************
# val_acc is:  2 114.93775933609959
# save the checkpoint after 2 epochs
# epoch : 3  batch : 0  learning rate : 0.0007, loss : 54.269, obj SR loss : 3.386, verb loss : 0.888, verb SR loss : 1.153
# epoch : 3  batch : 1  learning rate : 0.0007, loss : 57.023, obj SR loss : 2.688, verb loss : 1.500, verb SR loss : 1.515
# epoch : 3  batch : 2  learning rate : 0.0007, loss : 55.379, obj SR loss : 3.015, verb loss : 1.289, verb SR loss : 1.234
# epoch : 3  batch : 3  learning rate : 0.0007, loss : 52.278, obj SR loss : 2.171, verb loss : 1.879, verb SR loss : 1.178
# epoch : 3  batch : 4  learning rate : 0.0007, loss : 49.623, obj SR loss : 2.810, verb loss : 0.882, verb SR loss : 1.270
# epoch : 3  batch : 5  learning rate : 0.0007, loss : 60.150, obj SR loss : 2.420, verb loss : 2.275, verb SR loss : 1.319
# epoch : 3  batch : 6  learning rate : 0.0007, loss : 38.184, obj SR loss : 2.012, verb loss : 0.856, verb SR loss : 0.950
# epoch : 3  batch : 7  learning rate : 0.0007, loss : 49.326, obj SR loss : 2.554, verb loss : 0.909, verb SR loss : 1.469
# epoch : 3  batch : 8  learning rate : 0.0007, loss : 31.174, obj SR loss : 1.993, verb loss : 0.264, verb SR loss : 0.860
# epoch : 3  batch : 9  learning rate : 0.0007, loss : 38.216, obj SR loss : 1.644, verb loss : 0.635, verb SR loss : 1.542
# epoch : 3  batch : 10  learning rate : 0.0007, loss : 45.927, obj SR loss : 2.154, verb loss : 0.995, verb SR loss : 1.444
# epoch : 3  batch : 11  learning rate : 0.0007, loss : 64.218, obj SR loss : 2.601, verb loss : 2.565, verb SR loss : 1.256
# epoch : 3  batch : 12  learning rate : 0.0007, loss : 47.941, obj SR loss : 2.003, verb loss : 1.639, verb SR loss : 1.152
# epoch : 3  batch : 13  learning rate : 0.0007, loss : 67.117, obj SR loss : 2.249, verb loss : 3.082, verb SR loss : 1.381
# epoch : 3  batch : 14  learning rate : 0.0007, loss : 54.821, obj SR loss : 2.247, verb loss : 1.496, verb SR loss : 1.739
# epoch : 3  batch : 15  learning rate : 0.0007, loss : 61.645, obj SR loss : 3.647, verb loss : 0.862, verb SR loss : 1.655
# epoch : 3  batch : 16  learning rate : 0.0007, loss : 55.440, obj SR loss : 2.433, verb loss : 1.783, verb SR loss : 1.328
# epoch : 3  batch : 17  learning rate : 0.0007, loss : 52.341, obj SR loss : 2.618, verb loss : 1.551, verb SR loss : 1.066
# epoch : 3  batch : 18  learning rate : 0.0007, loss : 50.308, obj SR loss : 2.543, verb loss : 0.737, verb SR loss : 1.751
# epoch : 3  batch : 19  learning rate : 0.0007, loss : 64.746, obj SR loss : 3.727, verb loss : 1.455, verb SR loss : 1.293
# epoch : 3  batch : 20  learning rate : 0.0007, loss : 63.004, obj SR loss : 2.856, verb loss : 2.207, verb SR loss : 1.237
# epoch : 3  batch : 21  learning rate : 0.0007, loss : 53.613, obj SR loss : 3.203, verb loss : 1.102, verb SR loss : 1.056
# epoch : 3  batch : 22  learning rate : 0.0007, loss : 63.713, obj SR loss : 2.562, verb loss : 2.082, verb SR loss : 1.727
# epoch : 3  batch : 23  learning rate : 0.0007, loss : 47.071, obj SR loss : 2.324, verb loss : 1.199, verb SR loss : 1.184
# epoch : 3  batch : 24  learning rate : 0.0007, loss : 65.720, obj SR loss : 2.066, verb loss : 2.548, verb SR loss : 1.958
# epoch : 3  batch : 25  learning rate : 0.0007, loss : 54.835, obj SR loss : 2.754, verb loss : 1.460, verb SR loss : 1.269
# epoch : 3  batch : 26  learning rate : 0.0007, loss : 60.708, obj SR loss : 2.407, verb loss : 1.948, verb SR loss : 1.715
# epoch : 3  batch : 27  learning rate : 0.0007, loss : 52.626, obj SR loss : 2.241, verb loss : 1.516, verb SR loss : 1.506
# epoch : 3  batch : 28  learning rate : 0.0007, loss : 47.957, obj SR loss : 2.145, verb loss : 0.958, verb SR loss : 1.692
# epoch : 3  batch : 29  learning rate : 0.0007, loss : 58.867, obj SR loss : 2.979, verb loss : 1.377, verb SR loss : 1.530
#
# Object SR result:
# Accuracy: 6.28997867803838
# mR: 3.0303030303030303
# mP: 0.1906054144860115
# F1: 0.3586517127138993
# Value: 24.481327800829874
# Value-two: 0.0
# value-all: 0.0
# role_based_accuracy: 14.788535807832103
# role_based_mP: 5.553708018876862
# role_based_mR: 11.856661856661857
# role_based_f1: 7.209285143169442
#
# Verb result:
# Accuracy: 40.66390041493776
# mR: 24.42504498007494
# mP: 14.632721301686818
# F1: 18.019348835552705
#
# Verb SR result:
# Accuracy: 33.99153737658674
# mR: 5.263157894736842
# mP: 1.7890282829782496
# F1: 2.6703601108033244
# Value: 40.66390041493776
# Value-two: 0.0
# value-all: 0.0
# role_based_accuracy: 4.5182111572153065
# role_based_mP: 2.2591055786076533
# role_based_mR: 5.555555555555555
# role_based_f1: 3.212061619141265
# avg epoch performance :  105.80912863070539
# ****************************************************************************************************
# epoch : 4  batch : 0  learning rate : 0.0007, loss : 48.947, obj SR loss : 3.073, verb loss : 0.909, verb SR loss : 0.912
# epoch : 4  batch : 1  learning rate : 0.0007, loss : 50.794, obj SR loss : 2.539, verb loss : 1.107, verb SR loss : 1.433
# epoch : 4  batch : 2  learning rate : 0.0007, loss : 48.666, obj SR loss : 2.958, verb loss : 0.804, verb SR loss : 1.105
# epoch : 4  batch : 3  learning rate : 0.0007, loss : 40.687, obj SR loss : 2.044, verb loss : 0.925, verb SR loss : 1.100
# epoch : 4  batch : 4  learning rate : 0.0007, loss : 46.905, obj SR loss : 2.615, verb loss : 0.934, verb SR loss : 1.141
# epoch : 4  batch : 5  learning rate : 0.0007, loss : 54.072, obj SR loss : 2.406, verb loss : 1.754, verb SR loss : 1.247
# epoch : 4  batch : 6  learning rate : 0.0007, loss : 32.293, obj SR loss : 1.973, verb loss : 0.411, verb SR loss : 0.845
# epoch : 4  batch : 7  learning rate : 0.0007, loss : 47.461, obj SR loss : 2.513, verb loss : 0.815, verb SR loss : 1.418
# epoch : 4  batch : 8  learning rate : 0.0007, loss : 28.201, obj SR loss : 1.960, verb loss : 0.072, verb SR loss : 0.788
# epoch : 4  batch : 9  learning rate : 0.0007, loss : 36.160, obj SR loss : 1.656, verb loss : 0.472, verb SR loss : 1.488
# epoch : 4  batch : 10  learning rate : 0.0007, loss : 51.446, obj SR loss : 2.120, verb loss : 1.663, verb SR loss : 1.362
# epoch : 4  batch : 11  learning rate : 0.0007, loss : 64.351, obj SR loss : 2.596, verb loss : 2.572, verb SR loss : 1.267
# epoch : 4  batch : 12  learning rate : 0.0007, loss : 46.400, obj SR loss : 1.976, verb loss : 1.578, verb SR loss : 1.087
# epoch : 4  batch : 13  learning rate : 0.0007, loss : 55.438, obj SR loss : 2.249, verb loss : 1.870, verb SR loss : 1.425
# epoch : 4  batch : 14  learning rate : 0.0007, loss : 52.557, obj SR loss : 2.196, verb loss : 1.443, verb SR loss : 1.617
# epoch : 4  batch : 15  learning rate : 0.0007, loss : 69.905, obj SR loss : 3.702, verb loss : 1.594, verb SR loss : 1.695
# epoch : 4  batch : 16  learning rate : 0.0007, loss : 46.116, obj SR loss : 2.397, verb loss : 0.923, verb SR loss : 1.292
# epoch : 4  batch : 17  learning rate : 0.0007, loss : 54.268, obj SR loss : 2.692, verb loss : 1.656, verb SR loss : 1.079
# epoch : 4  batch : 18  learning rate : 0.0007, loss : 50.945, obj SR loss : 2.552, verb loss : 0.852, verb SR loss : 1.690
# epoch : 4  batch : 19  learning rate : 0.0007, loss : 63.631, obj SR loss : 3.795, verb loss : 1.300, verb SR loss : 1.268
# epoch : 4  batch : 20  learning rate : 0.0007, loss : 57.733, obj SR loss : 2.876, verb loss : 1.722, verb SR loss : 1.176
# epoch : 4  batch : 21  learning rate : 0.0007, loss : 52.031, obj SR loss : 3.244, verb loss : 0.930, verb SR loss : 1.029
# epoch : 4  batch : 22  learning rate : 0.0007, loss : 60.692, obj SR loss : 2.657, verb loss : 1.731, verb SR loss : 1.681
# epoch : 4  batch : 23  learning rate : 0.0007, loss : 43.368, obj SR loss : 2.335, verb loss : 0.954, verb SR loss : 1.048
# epoch : 4  batch : 24  learning rate : 0.0007, loss : 57.600, obj SR loss : 2.113, verb loss : 1.703, verb SR loss : 1.944
# epoch : 4  batch : 25  learning rate : 0.0007, loss : 55.323, obj SR loss : 2.715, verb loss : 1.602, verb SR loss : 1.216
# epoch : 4  batch : 26  learning rate : 0.0007, loss : 51.977, obj SR loss : 2.529, verb loss : 1.038, verb SR loss : 1.631
# epoch : 4  batch : 27  learning rate : 0.0007, loss : 46.479, obj SR loss : 2.132, verb loss : 1.057, verb SR loss : 1.459
# epoch : 4  batch : 28  learning rate : 0.0007, loss : 48.512, obj SR loss : 2.059, verb loss : 1.152, verb SR loss : 1.640
# epoch : 4  batch : 29  learning rate : 0.0007, loss : 56.777, obj SR loss : 2.827, verb loss : 1.390, verb SR loss : 1.461
#
# Object SR result:
# Accuracy: 3.9445628997867805
# mR: 1.844466600199402
# mP: 0.13303609952538473
# F1: 0.24817224495271312
# Value: 15.352697095435685
# Value-two: 0.0
# value-all: 0.0
# role_based_accuracy: 6.899345804820959
# role_based_mP: 2.4190626580807457
# role_based_mR: 5.0
# role_based_f1: 2.8454448124728158
#
# Verb result:
# Accuracy: 38.589211618257266
# mR: 24.50692916195801
# mP: 19.33927613237958
# F1: 19.43745143745144
#
# Verb SR result:
# Accuracy: 33.99153737658674
# mR: 5.263157894736842
# mP: 1.7890282829782496
# F1: 2.6703601108033244
# Value: 38.589211618257266
# Value-two: 0.0
# value-all: 0.0
# role_based_accuracy: 4.287690179806363
# role_based_mP: 2.1438450899031816
# role_based_mR: 5.555555555555555
# role_based_f1: 3.0938123752495006
# avg epoch performance :  92.53112033195022
# ****************************************************************************************************
# epoch : 5  batch : 0  learning rate : 0.0006, loss : 46.891, obj SR loss : 3.220, verb loss : 0.727, verb SR loss : 0.742
# epoch : 5  batch : 1  learning rate : 0.0006, loss : 49.087, obj SR loss : 2.625, verb loss : 0.933, verb SR loss : 1.351
# epoch : 5  batch : 2  learning rate : 0.0006, loss : 48.310, obj SR loss : 2.935, verb loss : 0.888, verb SR loss : 1.008
# epoch : 5  batch : 3  learning rate : 0.0006, loss : 45.563, obj SR loss : 2.007, verb loss : 1.532, verb SR loss : 1.017
# epoch : 5  batch : 4  learning rate : 0.0006, loss : 43.155, obj SR loss : 2.659, verb loss : 0.578, verb SR loss : 1.078
# epoch : 5  batch : 5  learning rate : 0.0006, loss : 49.636, obj SR loss : 2.402, verb loss : 1.369, verb SR loss : 1.194
# epoch : 5  batch : 6  learning rate : 0.0006, loss : 31.804, obj SR loss : 1.911, verb loss : 0.511, verb SR loss : 0.759
# epoch : 5  batch : 7  learning rate : 0.0006, loss : 47.629, obj SR loss : 2.535, verb loss : 0.870, verb SR loss : 1.358
# epoch : 5  batch : 8  learning rate : 0.0006, loss : 27.525, obj SR loss : 1.947, verb loss : 0.145, verb SR loss : 0.661
# epoch : 5  batch : 9  learning rate : 0.0006, loss : 34.710, obj SR loss : 1.684, verb loss : 0.356, verb SR loss : 1.432
# epoch : 5  batch : 10  learning rate : 0.0006, loss : 46.545, obj SR loss : 2.104, verb loss : 1.118, verb SR loss : 1.433
# epoch : 5  batch : 11  learning rate : 0.0006, loss : 47.513, obj SR loss : 2.535, verb loss : 0.999, verb SR loss : 1.217
# epoch : 5  batch : 12  learning rate : 0.0006, loss : 45.397, obj SR loss : 1.909, verb loss : 1.558, verb SR loss : 1.072
# epoch : 5  batch : 13  learning rate : 0.0006, loss : 60.310, obj SR loss : 2.144, verb loss : 2.583, verb SR loss : 1.304
# epoch : 5  batch : 14  learning rate : 0.0006, loss : 49.729, obj SR loss : 2.188, verb loss : 1.163, verb SR loss : 1.621
# epoch : 5  batch : 15  learning rate : 0.0006, loss : 55.377, obj SR loss : 3.474, verb loss : 0.490, verb SR loss : 1.575
# epoch : 5  batch : 16  learning rate : 0.0006, loss : 43.564, obj SR loss : 2.400, verb loss : 0.719, verb SR loss : 1.237
# epoch : 5  batch : 17  learning rate : 0.0006, loss : 45.812, obj SR loss : 2.525, verb loss : 1.114, verb SR loss : 0.941
# epoch : 5  batch : 18  learning rate : 0.0006, loss : 47.437, obj SR loss : 2.556, verb loss : 0.499, verb SR loss : 1.689
# epoch : 5  batch : 19  learning rate : 0.0006, loss : 58.830, obj SR loss : 3.489, verb loss : 1.201, verb SR loss : 1.192
# epoch : 5  batch : 20  learning rate : 0.0006, loss : 52.922, obj SR loss : 2.796, verb loss : 1.332, verb SR loss : 1.164
# epoch : 5  batch : 21  learning rate : 0.0006, loss : 47.880, obj SR loss : 3.171, verb loss : 0.649, verb SR loss : 0.968
# epoch : 5  batch : 22  learning rate : 0.0006, loss : 48.635, obj SR loss : 2.420, verb loss : 0.873, verb SR loss : 1.570
# epoch : 5  batch : 23  learning rate : 0.0006, loss : 36.132, obj SR loss : 2.288, verb loss : 0.313, verb SR loss : 1.012
# epoch : 5  batch : 24  learning rate : 0.0006, loss : 48.866, obj SR loss : 1.966, verb loss : 1.091, verb SR loss : 1.830
# epoch : 5  batch : 25  learning rate : 0.0006, loss : 47.169, obj SR loss : 2.756, verb loss : 0.767, verb SR loss : 1.193
# epoch : 5  batch : 26  learning rate : 0.0006, loss : 48.656, obj SR loss : 2.437, verb loss : 0.803, verb SR loss : 1.626
# epoch : 5  batch : 27  learning rate : 0.0006, loss : 51.916, obj SR loss : 2.236, verb loss : 1.590, verb SR loss : 1.366
# epoch : 5  batch : 28  learning rate : 0.0006, loss : 40.108, obj SR loss : 2.019, verb loss : 0.414, verb SR loss : 1.577
# epoch : 5  batch : 29  learning rate : 0.0006, loss : 53.213, obj SR loss : 2.906, verb loss : 0.971, verb SR loss : 1.444
#
# Object SR result:
# Accuracy: 6.28997867803838
# mR: 3.0303030303030303
# mP: 0.1906054144860115
# F1: 0.3586517127138993
# Value: 24.481327800829874
# Value-two: 0.0
# value-all: 0.0
# role_based_accuracy: 14.788535807832103
# role_based_mP: 5.553708018876862
# role_based_mR: 11.856661856661857
# role_based_f1: 7.209285143169442
#
# Verb result:
# Accuracy: 40.66390041493776
# mR: 28.09797684662001
# mP: 17.12967450754091
# F1: 20.391602776426623
#
# Verb SR result:
# Accuracy: 33.99153737658674
# mR: 10.438960471718717
# mP: 4.410991816202418
# F1: 6.1571125265392785
# Value: 40.66390041493776
# Value-two: 0.0
# value-all: 0.0
# role_based_accuracy: 4.6922173143562524
# role_based_mP: 2.2992989797969052
# role_based_mR: 4.558404558404558
# role_based_f1: 2.9331972615554704
# avg epoch performance :  105.80912863070539
# ****************************************************************************************************
# epoch : 6  batch : 0  learning rate : 0.0005, loss : 46.254, obj SR loss : 3.232, verb loss : 0.648, verb SR loss : 0.745
# epoch : 6  batch : 1  learning rate : 0.0005, loss : 48.387, obj SR loss : 2.572, verb loss : 0.893, verb SR loss : 1.374
# epoch : 6  batch : 2  learning rate : 0.0005, loss : 45.470, obj SR loss : 3.050, verb loss : 0.512, verb SR loss : 0.985
# epoch : 6  batch : 3  learning rate : 0.0005, loss : 41.193, obj SR loss : 1.977, verb loss : 1.131, verb SR loss : 1.011
# epoch : 6  batch : 4  learning rate : 0.0005, loss : 42.228, obj SR loss : 2.665, verb loss : 0.515, verb SR loss : 1.043
# epoch : 6  batch : 5  learning rate : 0.0005, loss : 46.506, obj SR loss : 2.444, verb loss : 1.009, verb SR loss : 1.198
# epoch : 6  batch : 6  learning rate : 0.0005, loss : 29.753, obj SR loss : 1.958, verb loss : 0.331, verb SR loss : 0.686
# epoch : 6  batch : 7  learning rate : 0.0005, loss : 43.677, obj SR loss : 2.528, verb loss : 0.528, verb SR loss : 1.312
# epoch : 6  batch : 8  learning rate : 0.0005, loss : 25.290, obj SR loss : 1.903, verb loss : 0.074, verb SR loss : 0.552
# epoch : 6  batch : 9  learning rate : 0.0005, loss : 33.249, obj SR loss : 1.634, verb loss : 0.349, verb SR loss : 1.342
# epoch : 6  batch : 10  learning rate : 0.0005, loss : 43.684, obj SR loss : 2.051, verb loss : 0.963, verb SR loss : 1.354
# epoch : 6  batch : 11  learning rate : 0.0005, loss : 43.789, obj SR loss : 2.480, verb loss : 0.704, verb SR loss : 1.195
# epoch : 6  batch : 12  learning rate : 0.0005, loss : 42.405, obj SR loss : 1.913, verb loss : 1.283, verb SR loss : 1.044
# epoch : 6  batch : 13  learning rate : 0.0005, loss : 50.939, obj SR loss : 2.189, verb loss : 1.564, verb SR loss : 1.341
# epoch : 6  batch : 14  learning rate : 0.0005, loss : 48.445, obj SR loss : 2.185, verb loss : 1.085, verb SR loss : 1.575
# epoch : 6  batch : 15  learning rate : 0.0005, loss : 57.122, obj SR loss : 3.514, verb loss : 0.601, verb SR loss : 1.598
# epoch : 6  batch : 16  learning rate : 0.0005, loss : 40.800, obj SR loss : 2.390, verb loss : 0.471, verb SR loss : 1.219
# epoch : 6  batch : 17  learning rate : 0.0005, loss : 39.426, obj SR loss : 2.521, verb loss : 0.494, verb SR loss : 0.927
# epoch : 6  batch : 18  learning rate : 0.0005, loss : 45.662, obj SR loss : 2.519, verb loss : 0.450, verb SR loss : 1.598
# epoch : 6  batch : 19  learning rate : 0.0005, loss : 57.742, obj SR loss : 3.566, verb loss : 1.081, verb SR loss : 1.127
# epoch : 6  batch : 20  learning rate : 0.0005, loss : 50.655, obj SR loss : 2.788, verb loss : 1.192, verb SR loss : 1.086
# epoch : 6  batch : 21  learning rate : 0.0005, loss : 50.203, obj SR loss : 3.106, verb loss : 0.994, verb SR loss : 0.920
# epoch : 6  batch : 22  learning rate : 0.0005, loss : 45.986, obj SR loss : 2.413, verb loss : 0.715, verb SR loss : 1.471
# epoch : 6  batch : 23  learning rate : 0.0005, loss : 34.199, obj SR loss : 2.296, verb loss : 0.125, verb SR loss : 0.999
# epoch : 6  batch : 24  learning rate : 0.0005, loss : 51.669, obj SR loss : 1.989, verb loss : 1.446, verb SR loss : 1.732
# epoch : 6  batch : 25  learning rate : 0.0005, loss : 44.913, obj SR loss : 2.736, verb loss : 0.614, verb SR loss : 1.141
# epoch : 6  batch : 26  learning rate : 0.0005, loss : 47.174, obj SR loss : 2.422, verb loss : 0.694, verb SR loss : 1.601
# epoch : 6  batch : 27  learning rate : 0.0005, loss : 51.680, obj SR loss : 2.125, verb loss : 1.654, verb SR loss : 1.389
# epoch : 6  batch : 28  learning rate : 0.0005, loss : 38.886, obj SR loss : 2.012, verb loss : 0.329, verb SR loss : 1.547
# epoch : 6  batch : 29  learning rate : 0.0005, loss : 50.991, obj SR loss : 2.839, verb loss : 0.887, verb SR loss : 1.373
#
# Object SR result:
# Accuracy: 6.28997867803838
# mR: 3.0303030303030303
# mP: 0.1906054144860115
# F1: 0.3586517127138993
# Value: 24.481327800829874
# Value-two: 0.0
# value-all: 0.0
# role_based_accuracy: 14.788535807832103
# role_based_mP: 5.553708018876862
# role_based_mR: 11.856661856661857
# role_based_f1: 7.209285143169442
#
# Verb result:
# Accuracy: 40.24896265560166
# mR: 27.126122230152593
# mP: 22.73686868686869
# F1: 20.686700186070833
#
# Verb SR result:
# Accuracy: 33.99153737658674
# mR: 7.643070331430237
# mP: 3.1753817282265633
# F1: 4.481274159200318
# Value: 40.24896265560166
# Value-two: 0.0
# value-all: 0.0
# role_based_accuracy: 9.354862920432735
# role_based_mP: 2.6584008430481463
# role_based_mR: 6.481481481481481
# role_based_f1: 3.705964817075928
# avg epoch performance :  104.97925311203319
# ****************************************************************************************************
# epoch : 7  batch : 0  learning rate : 0.0005, loss : 45.088, obj SR loss : 3.124, verb loss : 0.676, verb SR loss : 0.709
# epoch : 7  batch : 1  learning rate : 0.0005, loss : 46.868, obj SR loss : 2.545, verb loss : 0.803, verb SR loss : 1.339
# epoch : 7  batch : 2  learning rate : 0.0005, loss : 43.862, obj SR loss : 2.959, verb loss : 0.487, verb SR loss : 0.940
# epoch : 7  batch : 3  learning rate : 0.0005, loss : 39.281, obj SR loss : 1.985, verb loss : 0.956, verb SR loss : 0.987
# epoch : 7  batch : 4  learning rate : 0.0005, loss : 42.037, obj SR loss : 2.619, verb loss : 0.604, verb SR loss : 0.981
# epoch : 7  batch : 5  learning rate : 0.0005, loss : 46.090, obj SR loss : 2.339, verb loss : 1.097, verb SR loss : 1.173
# epoch : 7  batch : 6  learning rate : 0.0005, loss : 29.339, obj SR loss : 1.895, verb loss : 0.392, verb SR loss : 0.647
# epoch : 7  batch : 7  learning rate : 0.0005, loss : 43.051, obj SR loss : 2.460, verb loss : 0.565, verb SR loss : 1.280
# epoch : 7  batch : 8  learning rate : 0.0005, loss : 23.799, obj SR loss : 1.823, verb loss : 0.037, verb SR loss : 0.520
# epoch : 7  batch : 9  learning rate : 0.0005, loss : 30.533, obj SR loss : 1.556, verb loss : 0.301, verb SR loss : 1.197
# epoch : 7  batch : 10  learning rate : 0.0005, loss : 44.739, obj SR loss : 2.040, verb loss : 1.088, verb SR loss : 1.345
# epoch : 7  batch : 11  learning rate : 0.0005, loss : 41.462, obj SR loss : 2.463, verb loss : 0.533, verb SR loss : 1.150
# epoch : 7  batch : 12  learning rate : 0.0005, loss : 42.074, obj SR loss : 1.962, verb loss : 1.207, verb SR loss : 1.038
# epoch : 7  batch : 13  learning rate : 0.0005, loss : 49.591, obj SR loss : 2.201, verb loss : 1.482, verb SR loss : 1.276
# epoch : 7  batch : 14  learning rate : 0.0005, loss : 44.194, obj SR loss : 2.015, verb loss : 0.937, verb SR loss : 1.468
# epoch : 7  batch : 15  learning rate : 0.0005, loss : 56.103, obj SR loss : 3.430, verb loss : 0.630, verb SR loss : 1.550
# epoch : 7  batch : 16  learning rate : 0.0005, loss : 37.553, obj SR loss : 2.303, verb loss : 0.292, verb SR loss : 1.160
# epoch : 7  batch : 17  learning rate : 0.0005, loss : 38.390, obj SR loss : 2.487, verb loss : 0.494, verb SR loss : 0.858
# epoch : 7  batch : 18  learning rate : 0.0005, loss : 43.850, obj SR loss : 2.425, verb loss : 0.437, verb SR loss : 1.523
# epoch : 7  batch : 19  learning rate : 0.0005, loss : 54.745, obj SR loss : 3.478, verb loss : 0.914, verb SR loss : 1.083
# epoch : 7  batch : 20  learning rate : 0.0005, loss : 45.536, obj SR loss : 2.675, verb loss : 0.884, verb SR loss : 0.995
# epoch : 7  batch : 21  learning rate : 0.0005, loss : 47.940, obj SR loss : 3.173, verb loss : 0.741, verb SR loss : 0.880
# epoch : 7  batch : 22  learning rate : 0.0005, loss : 43.309, obj SR loss : 2.329, verb loss : 0.636, verb SR loss : 1.366
# epoch : 7  batch : 23  learning rate : 0.0005, loss : 31.823, obj SR loss : 2.190, verb loss : 0.115, verb SR loss : 0.877
# epoch : 7  batch : 24  learning rate : 0.0005, loss : 50.202, obj SR loss : 2.012, verb loss : 1.234, verb SR loss : 1.774
# epoch : 7  batch : 25  learning rate : 0.0005, loss : 44.221, obj SR loss : 2.616, verb loss : 0.696, verb SR loss : 1.111
# epoch : 7  batch : 26  learning rate : 0.0005, loss : 44.047, obj SR loss : 2.367, verb loss : 0.496, verb SR loss : 1.543
# epoch : 7  batch : 27  learning rate : 0.0005, loss : 45.588, obj SR loss : 2.105, verb loss : 1.078, verb SR loss : 1.376
# epoch : 7  batch : 28  learning rate : 0.0005, loss : 39.341, obj SR loss : 2.004, verb loss : 0.435, verb SR loss : 1.496
# epoch : 7  batch : 29  learning rate : 0.0005, loss : 49.577, obj SR loss : 2.752, verb loss : 0.856, verb SR loss : 1.350
#
# Object SR result:
# Accuracy: 6.28997867803838
# mR: 3.0303030303030303
# mP: 0.1906054144860115
# F1: 0.3586517127138993
# Value: 24.481327800829874
# Value-two: 0.0
# value-all: 0.0
# role_based_accuracy: 14.788535807832103
# role_based_mP: 5.553708018876862
# role_based_mR: 11.856661856661857
# role_based_f1: 7.209285143169442
#
# Verb result:
# Accuracy: 37.75933609958506
# mR: 26.882699068842232
# mP: 16.844620709282363
# F1: 19.379444365135377
#
# Verb SR result:
# Accuracy: 33.99153737658674
# mR: 7.643070331430237
# mP: 3.1753817282265633
# F1: 4.481274159200318
# Value: 37.75933609958506
# Value-two: 0.0
# value-all: 0.0
# role_based_accuracy: 9.078237747542001
# role_based_mP: 2.5661924520845685
# role_based_mR: 6.481481481481481
# role_based_f1: 3.5959210392867345
# avg epoch performance :  100.0
# ****************************************************************************************************
# epoch : 8  batch : 0  learning rate : 0.0004, loss : 41.710, obj SR loss : 3.011, verb loss : 0.516, verb SR loss : 0.643
# epoch : 8  batch : 1  learning rate : 0.0004, loss : 46.544, obj SR loss : 2.479, verb loss : 0.863, verb SR loss : 1.312
# epoch : 8  batch : 2  learning rate : 0.0004, loss : 40.788, obj SR loss : 2.852, verb loss : 0.339, verb SR loss : 0.889
# epoch : 8  batch : 3  learning rate : 0.0004, loss : 33.719, obj SR loss : 1.846, verb loss : 0.662, verb SR loss : 0.865
# epoch : 8  batch : 4  learning rate : 0.0004, loss : 39.270, obj SR loss : 2.469, verb loss : 0.561, verb SR loss : 0.897
# epoch : 8  batch : 5  learning rate : 0.0004, loss : 42.644, obj SR loss : 2.291, verb loss : 0.828, verb SR loss : 1.145
# epoch : 8  batch : 6  learning rate : 0.0004, loss : 27.539, obj SR loss : 1.820, verb loss : 0.345, verb SR loss : 0.589
# epoch : 8  batch : 7  learning rate : 0.0004, loss : 43.237, obj SR loss : 2.409, verb loss : 0.694, verb SR loss : 1.221
# epoch : 8  batch : 8  learning rate : 0.0004, loss : 22.995, obj SR loss : 1.753, verb loss : 0.058, verb SR loss : 0.489
# epoch : 8  batch : 9  learning rate : 0.0004, loss : 30.098, obj SR loss : 1.468, verb loss : 0.379, verb SR loss : 1.162
# epoch : 8  batch : 10  learning rate : 0.0004, loss : 43.797, obj SR loss : 2.051, verb loss : 0.998, verb SR loss : 1.331
# epoch : 8  batch : 11  learning rate : 0.0004, loss : 38.304, obj SR loss : 2.334, verb loss : 0.422, verb SR loss : 1.074
# epoch : 8  batch : 12  learning rate : 0.0004, loss : 41.099, obj SR loss : 1.884, verb loss : 1.234, verb SR loss : 0.991
# epoch : 8  batch : 13  learning rate : 0.0004, loss : 45.348, obj SR loss : 2.183, verb loss : 1.116, verb SR loss : 1.235
# epoch : 8  batch : 14  learning rate : 0.0004, loss : 42.000, obj SR loss : 1.895, verb loss : 0.873, verb SR loss : 1.432
# epoch : 8  batch : 15  learning rate : 0.0004, loss : 51.410, obj SR loss : 3.415, verb loss : 0.270, verb SR loss : 1.456
# epoch : 8  batch : 16  learning rate : 0.0004, loss : 36.707, obj SR loss : 2.235, verb loss : 0.332, verb SR loss : 1.104
# epoch : 8  batch : 17  learning rate : 0.0004, loss : 36.368, obj SR loss : 2.421, verb loss : 0.479, verb SR loss : 0.737
# epoch : 8  batch : 18  learning rate : 0.0004, loss : 42.767, obj SR loss : 2.379, verb loss : 0.401, verb SR loss : 1.498
# epoch : 8  batch : 19  learning rate : 0.0004, loss : 52.035, obj SR loss : 3.324, verb loss : 0.873, verb SR loss : 1.007
# epoch : 8  batch : 20  learning rate : 0.0004, loss : 41.864, obj SR loss : 2.612, verb loss : 0.659, verb SR loss : 0.915
# epoch : 8  batch : 21  learning rate : 0.0004, loss : 43.889, obj SR loss : 3.158, verb loss : 0.547, verb SR loss : 0.683
# epoch : 8  batch : 22  learning rate : 0.0004, loss : 40.576, obj SR loss : 2.150, verb loss : 0.640, verb SR loss : 1.268
# epoch : 8  batch : 23  learning rate : 0.0004, loss : 31.230, obj SR loss : 2.125, verb loss : 0.240, verb SR loss : 0.758
# epoch : 8  batch : 24  learning rate : 0.0004, loss : 50.905, obj SR loss : 1.988, verb loss : 1.377, verb SR loss : 1.725
# epoch : 8  batch : 25  learning rate : 0.0004, loss : 42.073, obj SR loss : 2.576, verb loss : 0.552, verb SR loss : 1.079
# epoch : 8  batch : 26  learning rate : 0.0004, loss : 41.880, obj SR loss : 2.268, verb loss : 0.465, verb SR loss : 1.455
# epoch : 8  batch : 27  learning rate : 0.0004, loss : 42.939, obj SR loss : 2.154, verb loss : 0.880, verb SR loss : 1.260
# epoch : 8  batch : 28  learning rate : 0.0004, loss : 36.764, obj SR loss : 2.001, verb loss : 0.239, verb SR loss : 1.436
# epoch : 8  batch : 29  learning rate : 0.0004, loss : 52.205, obj SR loss : 2.705, verb loss : 1.169, verb SR loss : 1.346
#
# Object SR result:
# Accuracy: 8.742004264392325
# mR: 5.630814380075319
# mP: 1.7037254003022428
# F1: 2.262019557146101
# Value: 34.024896265560166
# Value-two: 0.0
# value-all: 0.0
# role_based_accuracy: 15.29627303756103
# role_based_mP: 7.864551021655654
# role_based_mR: 11.583073763139254
# role_based_f1: 8.329928866885586
#
# Verb result:
# Accuracy: 33.60995850622407
# mR: 24.10090034497115
# mP: 17.6513986013986
# F1: 15.834988049273763
#
# Verb SR result:
# Accuracy: 28.208744710860366
# mR: 12.64780207780863
# mP: 5.88458396545688
# F1: 7.983188542969498
# Value: 29.87551867219917
# Value-two: 0.0
# value-all: 0.0
# role_based_accuracy: 9.8623203518722
# role_based_mP: 3.128169663439373
# role_based_mR: 5.7936507936507935
# role_based_f1: 3.713802127780623
# avg epoch performance :  97.51037344398341
# ****************************************************************************************************
# epoch : 9  batch : 0  learning rate : 0.0004, loss : 39.339, obj SR loss : 2.785, verb loss : 0.585, verb SR loss : 0.565
# epoch : 9  batch : 1  learning rate : 0.0004, loss : 43.796, obj SR loss : 2.380, verb loss : 0.729, verb SR loss : 1.271
# epoch : 9  batch : 2  learning rate : 0.0004, loss : 40.106, obj SR loss : 2.823, verb loss : 0.321, verb SR loss : 0.866
# epoch : 9  batch : 3  learning rate : 0.0004, loss : 31.737, obj SR loss : 1.715, verb loss : 0.712, verb SR loss : 0.747
# epoch : 9  batch : 4  learning rate : 0.0004, loss : 36.234, obj SR loss : 2.353, verb loss : 0.472, verb SR loss : 0.798
# epoch : 9  batch : 5  learning rate : 0.0004, loss : 39.320, obj SR loss : 2.174, verb loss : 0.747, verb SR loss : 1.011
# epoch : 9  batch : 6  learning rate : 0.0004, loss : 25.156, obj SR loss : 1.714, verb loss : 0.274, verb SR loss : 0.527
# epoch : 9  batch : 7  learning rate : 0.0004, loss : 39.238, obj SR loss : 2.356, verb loss : 0.385, verb SR loss : 1.182
# epoch : 9  batch : 8  learning rate : 0.0004, loss : 21.018, obj SR loss : 1.616, verb loss : 0.058, verb SR loss : 0.428
# epoch : 9  batch : 9  learning rate : 0.0004, loss : 27.235, obj SR loss : 1.347, verb loss : 0.255, verb SR loss : 1.121
# epoch : 9  batch : 10  learning rate : 0.0004, loss : 45.065, obj SR loss : 2.009, verb loss : 1.246, verb SR loss : 1.251
# epoch : 9  batch : 11  learning rate : 0.0004, loss : 38.906, obj SR loss : 2.242, verb loss : 0.696, verb SR loss : 0.953
# epoch : 9  batch : 12  learning rate : 0.0004, loss : 37.957, obj SR loss : 1.741, verb loss : 1.158, verb SR loss : 0.896
# epoch : 9  batch : 13  learning rate : 0.0004, loss : 43.275, obj SR loss : 2.129, verb loss : 1.028, verb SR loss : 1.171
# epoch : 9  batch : 14  learning rate : 0.0004, loss : 37.945, obj SR loss : 1.637, verb loss : 0.804, verb SR loss : 1.353
# epoch : 9  batch : 15  learning rate : 0.0004, loss : 50.965, obj SR loss : 3.276, verb loss : 0.443, verb SR loss : 1.377
# epoch : 9  batch : 16  learning rate : 0.0004, loss : 33.788, obj SR loss : 2.102, verb loss : 0.261, verb SR loss : 1.016
# epoch : 9  batch : 17  learning rate : 0.0004, loss : 33.382, obj SR loss : 2.296, verb loss : 0.387, verb SR loss : 0.654
# epoch : 9  batch : 18  learning rate : 0.0004, loss : 41.487, obj SR loss : 2.289, verb loss : 0.471, verb SR loss : 1.389
# epoch : 9  batch : 19  learning rate : 0.0004, loss : 50.135, obj SR loss : 3.162, verb loss : 0.949, verb SR loss : 0.902
# epoch : 9  batch : 20  learning rate : 0.0004, loss : 41.205, obj SR loss : 2.642, verb loss : 0.633, verb SR loss : 0.846
# epoch : 9  batch : 21  learning rate : 0.0004, loss : 48.250, obj SR loss : 2.985, verb loss : 1.147, verb SR loss : 0.693
# epoch : 9  batch : 22  learning rate : 0.0004, loss : 38.771, obj SR loss : 2.025, verb loss : 0.707, verb SR loss : 1.145
# epoch : 9  batch : 23  learning rate : 0.0004, loss : 29.088, obj SR loss : 2.114, verb loss : 0.070, verb SR loss : 0.725
# epoch : 9  batch : 24  learning rate : 0.0004, loss : 45.322, obj SR loss : 1.954, verb loss : 0.979, verb SR loss : 1.598
# epoch : 9  batch : 25  learning rate : 0.0004, loss : 40.631, obj SR loss : 2.559, verb loss : 0.532, verb SR loss : 0.972
# epoch : 9  batch : 26  learning rate : 0.0004, loss : 39.001, obj SR loss : 2.177, verb loss : 0.415, verb SR loss : 1.308
# epoch : 9  batch : 27  learning rate : 0.0004, loss : 42.832, obj SR loss : 2.089, verb loss : 1.037, verb SR loss : 1.158
# epoch : 9  batch : 28  learning rate : 0.0004, loss : 35.320, obj SR loss : 1.923, verb loss : 0.304, verb SR loss : 1.306
# epoch : 9  batch : 29  learning rate : 0.0004, loss : 48.634, obj SR loss : 2.643, verb loss : 0.891, verb SR loss : 1.330
#
# Object SR result:
# Accuracy: 8.528784648187633
# mR: 5.72112816890113
# mP: 1.238451008608034
# F1: 1.905102032979271
# Value: 33.19502074688796
# Value-two: 0.0
# value-all: 0.0
# role_based_accuracy: 16.108416173355618
# role_based_mP: 7.047295630204144
# role_based_mR: 12.123194160082692
# role_based_f1: 8.416218344743362
#
# Verb result:
# ...
# epoch : 26  batch : 26  learning rate : 0.0001, loss : 22.741, obj SR loss : 1.486, verb loss : 0.172, verb SR loss : 0.616
# epoch : 26  batch : 27  learning rate : 0.0001, loss : 23.875, obj SR loss : 1.103, verb loss : 0.873, verb SR loss : 0.412
# epoch : 26  batch : 28  learning rate : 0.0001, loss : 14.109, obj SR loss : 0.873, verb loss : 0.033, verb SR loss : 0.505
# epoch : 26  batch : 29  learning rate : 0.0001, loss : 23.429, obj SR loss : 1.656, verb loss : 0.200, verb SR loss : 0.487
# idx:  60 [41, 26] [41, 26]
# idx:  62 [41, 26] [41, 26]
# idx:  78 [41, 85] [41, 85]
# idx:  79 [41, 85] [41, 85]
# idx:  80 [41, 85] [41, 85]
# idx:  81 [41, 85] [41, 85]
#
# Object SR result:
# Accuracy: 9.914712153518124
# mR: 6.505478186782165
# mP: 2.4873635528168783
# F1: 2.7330057124614795
# Value: 38.17427385892116
# Value-two: 0.4149377593360996
# value-all: 0.0
# role_based_accuracy: 13.521015671030675
# role_based_mP: 11.514800177080879
# role_based_mR: 9.476223984256114
# role_based_f1: 7.931883199356205
#
# Verb result:
# Accuracy: 34.024896265560166
# mR: 24.737907422827572
# mP: 16.18633540372671
# F1: 15.955552898030776
#
# Verb SR result:
# Accuracy: 47.39069111424541
# mR: 25.783945901592958
# mP: 24.293604293604297
# F1: 20.615626301642394
# Value: 34.024896265560166
# Value-two: 24.481327800829874
# value-all: 2.4896265560165975
# role_based_accuracy: 10.180531502834528
# role_based_mP: 5.813520943954654
# role_based_mR: 12.79333955804544
# role_based_f1: 7.256841775546625
# avg epoch performance :  106.22406639004149
# ****************************************************************************************************
# epoch : 27  batch : 0  learning rate : 0.0001, loss : 20.519, obj SR loss : 1.717, verb loss : 0.145, verb SR loss : 0.190
# epoch : 27  batch : 1  learning rate : 0.0001, loss : 28.059, obj SR loss : 1.810, verb loss : 0.506, verb SR loss : 0.490
# epoch : 27  batch : 2  learning rate : 0.0001, loss : 24.476, obj SR loss : 2.032, verb loss : 0.116, verb SR loss : 0.299
# epoch : 27  batch : 3  learning rate : 0.0001, loss : 18.501, obj SR loss : 1.109, verb loss : 0.526, verb SR loss : 0.216
# epoch : 27  batch : 4  learning rate : 0.0001, loss : 20.571, obj SR loss : 1.527, verb loss : 0.276, verb SR loss : 0.255
# epoch : 27  batch : 5  learning rate : 0.0001, loss : 20.070, obj SR loss : 1.223, verb loss : 0.446, verb SR loss : 0.338
# epoch : 27  batch : 6  learning rate : 0.0001, loss : 12.796, obj SR loss : 0.975, verb loss : 0.159, verb SR loss : 0.146
# epoch : 27  batch : 7  learning rate : 0.0001, loss : 19.855, obj SR loss : 1.352, verb loss : 0.271, verb SR loss : 0.362
# epoch : 27  batch : 8  learning rate : 0.0001, loss : 7.487, obj SR loss : 0.655, verb loss : 0.003, verb SR loss : 0.091
# epoch : 27  batch : 9  learning rate : 0.0001, loss : 11.988, obj SR loss : 0.658, verb loss : 0.040, verb SR loss : 0.501
# epoch : 27  batch : 10  learning rate : 0.0001, loss : 22.966, obj SR loss : 1.279, verb loss : 0.623, verb SR loss : 0.394
# epoch : 27  batch : 11  learning rate : 0.0001, loss : 15.395, obj SR loss : 1.166, verb loss : 0.097, verb SR loss : 0.276
# epoch : 27  batch : 12  learning rate : 0.0001, loss : 22.505, obj SR loss : 1.247, verb loss : 0.657, verb SR loss : 0.346
# epoch : 27  batch : 13  learning rate : 0.0001, loss : 17.636, obj SR loss : 1.113, verb loss : 0.318, verb SR loss : 0.332
# epoch : 27  batch : 14  learning rate : 0.0001, loss : 21.845, obj SR loss : 1.064, verb loss : 0.466, verb SR loss : 0.654
# epoch : 27  batch : 15  learning rate : 0.0001, loss : 28.305, obj SR loss : 1.972, verb loss : 0.243, verb SR loss : 0.615
# epoch : 27  batch : 16  learning rate : 0.0001, loss : 17.266, obj SR loss : 1.253, verb loss : 0.111, verb SR loss : 0.363
# epoch : 27  batch : 17  learning rate : 0.0001, loss : 18.094, obj SR loss : 1.571, verb loss : 0.106, verb SR loss : 0.133
# epoch : 27  batch : 18  learning rate : 0.0001, loss : 21.461, obj SR loss : 1.373, verb loss : 0.179, verb SR loss : 0.594
# epoch : 27  batch : 19  learning rate : 0.0001, loss : 26.559, obj SR loss : 1.889, verb loss : 0.464, verb SR loss : 0.302
# epoch : 27  batch : 20  learning rate : 0.0001, loss : 19.486, obj SR loss : 1.500, verb loss : 0.221, verb SR loss : 0.228
# epoch : 27  batch : 21  learning rate : 0.0001, loss : 16.966, obj SR loss : 1.433, verb loss : 0.058, verb SR loss : 0.205
# epoch : 27  batch : 22  learning rate : 0.0001, loss : 15.025, obj SR loss : 0.946, verb loss : 0.242, verb SR loss : 0.315
# epoch : 27  batch : 23  learning rate : 0.0001, loss : 13.010, obj SR loss : 1.030, verb loss : 0.006, verb SR loss : 0.264
# epoch : 27  batch : 24  learning rate : 0.0001, loss : 17.817, obj SR loss : 0.954, verb loss : 0.378, verb SR loss : 0.450
# epoch : 27  batch : 25  learning rate : 0.0001, loss : 19.990, obj SR loss : 1.490, verb loss : 0.192, verb SR loss : 0.318
# epoch : 27  batch : 26  learning rate : 0.0001, loss : 22.348, obj SR loss : 1.473, verb loss : 0.161, verb SR loss : 0.600
# epoch : 27  batch : 27  learning rate : 0.0001, loss : 22.542, obj SR loss : 1.107, verb loss : 0.734, verb SR loss : 0.414
# epoch : 27  batch : 28  learning rate : 0.0001, loss : 13.408, obj SR loss : 0.837, verb loss : 0.026, verb SR loss : 0.478
# epoch : 27  batch : 29  learning rate : 0.0001, loss : 22.989, obj SR loss : 1.643, verb loss : 0.174, verb SR loss : 0.482
# idx:  59 [41, 26] [41, 26]
# idx:  61 [41, 26] [41, 26]
# idx:  77 [41, 85] [41, 85]
# idx:  78 [41, 85] [41, 85]
# idx:  79 [41, 85] [41, 85]
# idx:  80 [41, 85] [41, 85]
#
# Object SR result:
# Accuracy: 10.44776119402985
# mR: 6.739034008360853
# mP: 3.6292256628678867
# F1: 2.8649497260981627
# Value: 40.24896265560166
# Value-two: 0.4149377593360996
# value-all: 0.0
# role_based_accuracy: 14.87340047317818
# role_based_mP: 12.731797805327218
# role_based_mR: 9.775765753674627
# role_based_f1: 8.291306257425926
#
# Verb result:
# Accuracy: 33.60995850622407
# mR: 24.581657422827572
# mP: 16.028440666884602
# F1: 15.754749685179368
#
# Verb SR result:
# Accuracy: 47.39069111424541
# mR: 24.662904775436743
# mP: 23.281001768714432
# F1: 19.773324666778795
# Value: 33.60995850622407
# Value-two: 24.481327800829874
# value-all: 2.4896265560165975
# role_based_accuracy: 10.13442730735274
# role_based_mP: 5.790468846213758
# role_based_mR: 12.79333955804544
# role_based_f1: 7.231095397666716
# avg epoch performance :  107.4688796680498
# ****************************************************************************************************
# epoch : 28  batch : 0  learning rate : 0.0001, loss : 19.896, obj SR loss : 1.687, verb loss : 0.116, verb SR loss : 0.187
# epoch : 28  batch : 1  learning rate : 0.0001, loss : 28.594, obj SR loss : 1.825, verb loss : 0.535, verb SR loss : 0.500
# epoch : 28  batch : 2  learning rate : 0.0001, loss : 23.878, obj SR loss : 1.993, verb loss : 0.120, verb SR loss : 0.275
# epoch : 28  batch : 3  learning rate : 0.0001, loss : 18.406, obj SR loss : 1.100, verb loss : 0.531, verb SR loss : 0.210
# epoch : 28  batch : 4  learning rate : 0.0001, loss : 20.379, obj SR loss : 1.519, verb loss : 0.268, verb SR loss : 0.252
# epoch : 28  batch : 5  learning rate : 0.0001, loss : 19.911, obj SR loss : 1.208, verb loss : 0.456, verb SR loss : 0.327
# epoch : 28  batch : 6  learning rate : 0.0001, loss : 12.774, obj SR loss : 0.968, verb loss : 0.165, verb SR loss : 0.144
# epoch : 28  batch : 7  learning rate : 0.0001, loss : 19.518, obj SR loss : 1.322, verb loss : 0.272, verb SR loss : 0.358
# epoch : 28  batch : 8  learning rate : 0.0001, loss : 7.379, obj SR loss : 0.645, verb loss : 0.002, verb SR loss : 0.090
# epoch : 28  batch : 9  learning rate : 0.0001, loss : 11.877, obj SR loss : 0.632, verb loss : 0.036, verb SR loss : 0.519
# epoch : 28  batch : 10  learning rate : 0.0001, loss : 22.791, obj SR loss : 1.253, verb loss : 0.635, verb SR loss : 0.391
# epoch : 28  batch : 11  learning rate : 0.0001, loss : 15.483, obj SR loss : 1.154, verb loss : 0.125, verb SR loss : 0.269
# epoch : 28  batch : 12  learning rate : 0.0001, loss : 21.997, obj SR loss : 1.220, verb loss : 0.642, verb SR loss : 0.338
# epoch : 28  batch : 13  learning rate : 0.0001, loss : 17.212, obj SR loss : 1.100, verb loss : 0.303, verb SR loss : 0.319
# epoch : 28  batch : 14  learning rate : 0.0001, loss : 21.343, obj SR loss : 1.050, verb loss : 0.436, verb SR loss : 0.648
# epoch : 28  batch : 15  learning rate : 0.0001, loss : 27.959, obj SR loss : 1.973, verb loss : 0.207, verb SR loss : 0.616
# epoch : 28  batch : 16  learning rate : 0.0001, loss : 17.132, obj SR loss : 1.247, verb loss : 0.108, verb SR loss : 0.359
# epoch : 28  batch : 17  learning rate : 0.0001, loss : 17.849, obj SR loss : 1.565, verb loss : 0.091, verb SR loss : 0.128
# epoch : 28  batch : 18  learning rate : 0.0001, loss : 22.792, obj SR loss : 1.369, verb loss : 0.322, verb SR loss : 0.588
# epoch : 28  batch : 19  learning rate : 0.0001, loss : 25.547, obj SR loss : 1.881, verb loss : 0.380, verb SR loss : 0.293
# epoch : 28  batch : 20  learning rate : 0.0001, loss : 19.096, obj SR loss : 1.474, verb loss : 0.207, verb SR loss : 0.229
# epoch : 28  batch : 21  learning rate : 0.0001, loss : 17.138, obj SR loss : 1.441, verb loss : 0.066, verb SR loss : 0.206
# epoch : 28  batch : 22  learning rate : 0.0001, loss : 14.736, obj SR loss : 0.927, verb loss : 0.236, verb SR loss : 0.311
# epoch : 28  batch : 23  learning rate : 0.0001, loss : 12.914, obj SR loss : 1.016, verb loss : 0.015, verb SR loss : 0.260
# epoch : 28  batch : 24  learning rate : 0.0001, loss : 16.920, obj SR loss : 0.919, verb loss : 0.322, verb SR loss : 0.451
# epoch : 28  batch : 25  learning rate : 0.0001, loss : 20.396, obj SR loss : 1.497, verb loss : 0.229, verb SR loss : 0.313
# epoch : 28  batch : 26  learning rate : 0.0001, loss : 22.473, obj SR loss : 1.480, verb loss : 0.152, verb SR loss : 0.615
# epoch : 28  batch : 27  learning rate : 0.0001, loss : 22.696, obj SR loss : 1.120, verb loss : 0.748, verb SR loss : 0.402
# epoch : 28  batch : 28  learning rate : 0.0001, loss : 13.316, obj SR loss : 0.828, verb loss : 0.015, verb SR loss : 0.488
# epoch : 28  batch : 29  learning rate : 0.0001, loss : 22.496, obj SR loss : 1.633, verb loss : 0.158, verb SR loss : 0.459
# idx:  56 [41, 26] [41, 26]
# idx:  58 [41, 26] [41, 26]
# idx:  72 [41, 85] [41, 85]
# idx:  73 [41, 85] [41, 85]
# idx:  74 [41, 85] [41, 85]
# idx:  75 [41, 85] [41, 85]
#
# Object SR result:
# Accuracy: 11.620469083155651
# mR: 7.346329127934613
# mP: 2.7048627936640384
# F1: 2.902344977890515
# Value: 44.81327800829876
# Value-two: 0.4149377593360996
# value-all: 0.0
# role_based_accuracy: 18.52386833113622
# role_based_mP: 13.348081823959017
# role_based_mR: 11.898839948538743
# role_based_f1: 9.819783616030294
#
# Verb result:
# Accuracy: 31.535269709543567
# mR: 23.800407422827572
# mP: 15.654520917678813
# F1: 14.746562894400641
#
# Verb SR result:
# Accuracy: 47.672778561354015
# mR: 25.224103167837182
# mP: 23.097610753991464
# F1: 20.11173935451381
# Value: 31.535269709543567
# Value-two: 24.481327800829874
# value-all: 2.4896265560165975
# role_based_accuracy: 9.930737425664994
# role_based_mP: 5.657634661364161
# role_based_mR: 12.763105242096838
# role_based_f1: 7.092153800439652
# avg epoch performance :  107.88381742738589
# ****************************************************************************************************
# epoch : 29  batch : 0  learning rate : 0.0000, loss : 19.834, obj SR loss : 1.672, verb loss : 0.134, verb SR loss : 0.178
# epoch : 29  batch : 1  learning rate : 0.0000, loss : 27.728, obj SR loss : 1.821, verb loss : 0.462, verb SR loss : 0.490
# epoch : 29  batch : 2  learning rate : 0.0000, loss : 23.453, obj SR loss : 1.961, verb loss : 0.114, verb SR loss : 0.270
# epoch : 29  batch : 3  learning rate : 0.0000, loss : 17.894, obj SR loss : 1.078, verb loss : 0.510, verb SR loss : 0.201
# epoch : 29  batch : 4  learning rate : 0.0000, loss : 20.044, obj SR loss : 1.503, verb loss : 0.251, verb SR loss : 0.250
# epoch : 29  batch : 5  learning rate : 0.0000, loss : 19.453, obj SR loss : 1.198, verb loss : 0.435, verb SR loss : 0.312
# epoch : 29  batch : 6  learning rate : 0.0000, loss : 12.376, obj SR loss : 0.947, verb loss : 0.156, verb SR loss : 0.135
# epoch : 29  batch : 7  learning rate : 0.0000, loss : 19.500, obj SR loss : 1.316, verb loss : 0.282, verb SR loss : 0.352
# epoch : 29  batch : 8  learning rate : 0.0000, loss : 7.089, obj SR loss : 0.617, verb loss : 0.002, verb SR loss : 0.090
# epoch : 29  batch : 9  learning rate : 0.0000, loss : 12.313, obj SR loss : 0.640, verb loss : 0.087, verb SR loss : 0.505
# epoch : 29  batch : 10  learning rate : 0.0000, loss : 22.567, obj SR loss : 1.239, verb loss : 0.632, verb SR loss : 0.386
# epoch : 29  batch : 11  learning rate : 0.0000, loss : 15.281, obj SR loss : 1.151, verb loss : 0.093, verb SR loss : 0.284
# epoch : 29  batch : 12  learning rate : 0.0000, loss : 21.678, obj SR loss : 1.200, verb loss : 0.631, verb SR loss : 0.337
# epoch : 29  batch : 13  learning rate : 0.0000, loss : 17.122, obj SR loss : 1.090, verb loss : 0.309, verb SR loss : 0.313
# epoch : 29  batch : 14  learning rate : 0.0000, loss : 21.184, obj SR loss : 1.034, verb loss : 0.440, verb SR loss : 0.644
# epoch : 29  batch : 15  learning rate : 0.0000, loss : 27.354, obj SR loss : 1.949, verb loss : 0.199, verb SR loss : 0.587
# epoch : 29  batch : 16  learning rate : 0.0000, loss : 16.900, obj SR loss : 1.224, verb loss : 0.100, verb SR loss : 0.365
# epoch : 29  batch : 17  learning rate : 0.0000, loss : 18.399, obj SR loss : 1.587, verb loss : 0.120, verb SR loss : 0.133
# epoch : 29  batch : 18  learning rate : 0.0000, loss : 21.545, obj SR loss : 1.389, verb loss : 0.173, verb SR loss : 0.593
# epoch : 29  batch : 19  learning rate : 0.0000, loss : 25.716, obj SR loss : 1.868, verb loss : 0.414, verb SR loss : 0.290
# epoch : 29  batch : 20  learning rate : 0.0000, loss : 19.186, obj SR loss : 1.481, verb loss : 0.219, verb SR loss : 0.220
# epoch : 29  batch : 21  learning rate : 0.0000, loss : 16.801, obj SR loss : 1.405, verb loss : 0.068, verb SR loss : 0.207
# epoch : 29  batch : 22  learning rate : 0.0000, loss : 14.777, obj SR loss : 0.926, verb loss : 0.241, verb SR loss : 0.311
# epoch : 29  batch : 23  learning rate : 0.0000, loss : 12.480, obj SR loss : 0.997, verb loss : 0.007, verb SR loss : 0.244
# epoch : 29  batch : 24  learning rate : 0.0000, loss : 17.407, obj SR loss : 0.917, verb loss : 0.377, verb SR loss : 0.447
# epoch : 29  batch : 25  learning rate : 0.0000, loss : 19.642, obj SR loss : 1.469, verb loss : 0.193, verb SR loss : 0.302
# epoch : 29  batch : 26  learning rate : 0.0000, loss : 21.926, obj SR loss : 1.448, verb loss : 0.135, verb SR loss : 0.609
# epoch : 29  batch : 27  learning rate : 0.0000, loss : 21.215, obj SR loss : 1.096, verb loss : 0.638, verb SR loss : 0.387
# epoch : 29  batch : 28  learning rate : 0.0000, loss : 12.866, obj SR loss : 0.803, verb loss : 0.016, verb SR loss : 0.467
# epoch : 29  batch : 29  learning rate : 0.0000, loss : 22.207, obj SR loss : 1.612, verb loss : 0.149, verb SR loss : 0.460
# idx:  57 [41, 26] [41, 26]
# idx:  59 [41, 26] [41, 26]
# idx:  73 [41, 85] [41, 85]
# idx:  74 [41, 85] [41, 85]
# idx:  75 [41, 85] [41, 85]
# idx:  76 [41, 85] [41, 85]
#
# Object SR result:
# Accuracy: 11.513859275053305
# mR: 7.253234916592735
# mP: 2.6946246758499144
# F1: 2.9754574642877882
# Value: 44.398340248962654
# Value-two: 0.4149377593360996
# value-all: 0.0
# role_based_accuracy: 17.586056321437177
# role_based_mP: 13.202203827203826
# role_based_mR: 11.476037628146063
# role_based_f1: 9.629023525054452
#
# Verb result:
# Accuracy: 31.950207468879665
# mR: 23.956657422827572
# mP: 15.673200673200672
# F1: 14.870918555129082
#
# Verb SR result:
# Accuracy: 47.39069111424541
# mR: 24.712594216430535
# mP: 23.107784604014594
# F1: 19.81891586335272
# Value: 31.950207468879665
# Value-two: 24.481327800829874
# value-all: 2.4896265560165975
# role_based_accuracy: 9.976841621146782
# role_based_mP: 5.680686759105056
# role_based_mR: 12.763105242096838
# role_based_f1: 7.118717475000469
# avg epoch performance :  108.29875518672199
# ****************************************************************************************************

# %% [markdown]
# # **Test**

# %%
# %%writefile test.py
import time
import os
import copy
import torch
import numpy as np
np.set_printoptions(precision=3)

import clip
import open_clip

from model import InComNet
from feature_extraction import FeatureExtractor
from dataset import AG, cuda_collate_fn
from evaluation import EvaluateInComNet
from config import parse_args

import warnings
warnings.filterwarnings('ignore')

def test(args):
    # Match evaluation configuration to full paper benchmarks
    args.datasize = "large"

    if args.clip_model == 'ViT_L_14_336_sft':
        model_name = "ViT-L-14-336"
        model, _, preprocess = open_clip.create_model_and_transforms(model_name=model_name, pretrained=args.clip_sft_path)
    else:
        model, preprocess = clip.load('ViT-L/14@336px', args.device)
    model.to(args.device)
    model.eval()

    # Load full dataset validation set explicitly
    AG_dataset_test = AG(mode="test", datasize="large", data_path=args.data_path, frame_path=args.frame_path, filter_nonperson_box_frame=True,
                        filter_small_box=False, preprocess=preprocess)
    dataloader_test = torch.utils.data.DataLoader(AG_dataset_test, shuffle=False, num_workers=4,
                                                collate_fn=cuda_collate_fn, pin_memory=False)

    incomnet_model = InComNet()
    incomnet_model.to(args.device)
    evaluation = EvaluateInComNet()
    feat_extractor = FeatureExtractor()

    # Load custom training weight checkpoint
    ckpt = torch.load(args.ckpt, map_location=args.device)
    incomnet_model.load_state_dict(ckpt['state_dict'], strict=False)

    print('*' * 60)
    print(f'🚀 EVALUATING CHECKPOINT: {args.ckpt}')
    print('*' * 60)

    incomnet_model.eval()

    obj_sr_pred_list, obj_sr_gt_list = [], []
    verb_pred_list, verb_gt_list = [], []
    verb_sr_pred_list, verb_sr_gt_list = [], []
    obj_frame_lengths, obj_roles = [], []
    verb_frame_lengths, verb_roles = [], []

    with torch.no_grad():
        for data_test in dataloader_test:
            im_info = copy.deepcopy(data_test[1])
            gt_annotation = AG_dataset_test.gt_annotations[data_test[4]]
            raw_images_pil_test = copy.deepcopy(data_test[5])

            test_features = feat_extractor.get_features(im_info, gt_annotation, raw_images_pil_test, model, preprocess)

            obj_frame_lengths.extend(test_features['noun_frame_lengths'])
            obj_roles.extend(test_features['n_roles'])
            verb_frame_lengths.extend(test_features['v_frame_lengths'])
            verb_roles.extend(test_features['v_roles'])

            # Multi-iteration Message Passing Loop matching training configuration
            for i in range(args.iterations):
                if i == 0:
                    obj_sr_logits, obj_sr_q = incomnet_model(True, False, False, test_features['obj_sr_features'], test_features['obj_sr_mask'], None, None, None, None)
                else:
                    obj_sr2_features = torch.cat([verb_q, test_features['obj_sr_features']], dim=1)
                    obj_sr_logits, obj_sr_q = incomnet_model(True, False, False, obj_sr2_features, test_features['obj_sr_mask'], None, None, None, None)

                verb_feat = torch.cat([test_features['verb_img_features'].unsqueeze(1), test_features['verb_cls_features'].unsqueeze(1), obj_sr_q], dim=1)
                verb_logits, verb_q = incomnet_model(False, True, False, test_features['obj_sr_features'], test_features['obj_sr_mask'], verb_feat, None, None, None)

                verb_sr_feat = torch.cat([verb_q, test_features['verb_sr_features']], dim=1)
                verb_sr_logits, verb_sr_q = incomnet_model(False, False, True, test_features['obj_sr_features'], test_features['obj_sr_mask'], verb_feat, None, verb_sr_feat, test_features['verb_sr_mask'])

            # Flatten logits for scoring pass
            obj_sr_logits = obj_sr_logits.view(-1, 364)
            obj_sr_gt_flat = test_features['obj_sr_gt'].view(-1)
            obj_sr_pred_list.extend(torch.argmax(obj_sr_logits, dim=1).tolist())
            obj_sr_gt_list.extend(obj_sr_gt_flat.tolist())

            verb_logits = verb_logits.squeeze()
            if verb_logits.dim() == 1:
                verb_logits = verb_logits.unsqueeze(0)
            verb_pred_list.extend(torch.argmax(verb_logits, dim=1).tolist())
            verb_gt_list.extend(test_features['verb_gt'].tolist())

            verb_sr_logits = verb_sr_logits.view(-1, 125)
            verb_sr_gt_flat = test_features['verb_sr_gt'].view(-1)
            verb_sr_pred_list.extend(torch.argmax(verb_sr_logits, dim=1).tolist())
            verb_sr_gt_list.extend(verb_sr_gt_flat.tolist())

    obj_result, verb_result, verb_sr_result = evaluation.evaluate(
        obj_sr_gt_list, obj_sr_pred_list, obj_frame_lengths, obj_roles,
        verb_gt_list, verb_pred_list, verb_sr_gt_list, verb_sr_pred_list,
        verb_frame_lengths, verb_roles
    )

    print("\n🔹 Object SR result:")
    for key, value in obj_result.items(): print(f"  {key}: {value}")
    print("\n🔹 Verb result:")
    for key, value in verb_result.items(): print(f"  {key}: {value}")
    print("\n🔹 Verb SR result:")
    for key, value in verb_sr_result.items(): print(f"  {key}: {value}")

if __name__ == "__main__":
    args = parse_args()
    test(args)
# Out:
# Writing test.py

# %%
import sys
for mod in ['config', 'dataset', 'feature_extraction', 'train', 'model']:
    if mod in sys.modules: del sys.modules[mod]

# Execute evaluation pass over your large test dataset split
# !python test.py \
    --data_path "/content/drive/MyDrive/project/SSG/data/" \
    --frame_path "/content/drive/MyDrive/project/SSG/data/frames/" \
    --clip_sft_path "/content/drive/MyDrive/project/SSG/open_clip_backups/checkpoints/epoch_3.pt" \
    --ckpt "/content/drive/MyDrive/project/SSG/temporal/11Jul/incomnet_epoch_2.tar" \
    --device "cuda:0" \
    --iterations 10
# Out:
# /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# -------loading annotations---------slowly-----------
# Removed 03PRW.mp4/000240.png as it has one contacting relationship and it is 'other relationship'
# Removed 00T1E.mp4/000240.png as it has one contacting relationship and it is 'other relationship'
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# There are 4 videos and 126 valid frames
# 1 videos are invalid (no person), remove them
# 0 videos are invalid (only one frame), remove them
# 68 frames have no human bbox in GT, remove them!
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# ************************************************************
# 🚀 EVALUATING CHECKPOINT: /content/drive/MyDrive/project/SSG/temporal/11Jul/incomnet_epoch_2.tar
# ************************************************************
#
# 🔹 Object SR result:
#   Accuracy: 6.28997867803838
#   mR: 3.0303030303030303
#   mP: 0.1906054144860115
#   F1: 0.3586517127138993
#   Value: 24.481327800829874
#   Value-two: 0.0
#   value-all: 0.0
#   role_based_accuracy: 14.7885358078321
#   role_based_mP: 5.553708018876861
#   role_based_mR: 11.856661856661855
#   role_based_f1: 7.209285143169442
#
# 🔹 Verb result:
#   Accuracy: 45.22821576763486
#   mR: 19.758751040161172
#   mP: 12.846560846560845
#   F1: 15.051755053249291
#
# 🔹 Verb SR result:
#   Accuracy: 33.99153737658674
#   mR: 5.263157894736842
#   mP: 1.7890282829782496
#   F1: 2.6703601108033244
#   Value: 45.22821576763486
#   Value-two: 0.0
#   value-all: 0.0
#   role_based_accuracy: 5.025357307514984
#   role_based_mP: 2.512678653757492
#   role_based_mR: 5.555555555555555
#   role_based_f1: 3.4603174603174605
