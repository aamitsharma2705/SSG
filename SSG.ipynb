# %% [markdown]
# <a href="https://colab.research.google.com/github/aamitsharma2705/SSG/blob/main/SSG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Enviornment Set Up**

# %%
import subprocess
import sys
import platform

print("=" * 60)
print("System Information")
print("=" * 60)
print(f"Python: {sys.version.split()[0]}")
print(f"Python: {platform.platform()}")
# Out:
# ============================================================
# System Information
# ============================================================
# Python: 3.12.13
# Python: Linux-6.6.122+-x86_64-with-glibc2.35

# %%
import torch
print("GPU Available:", torch.cuda.is_available())
print("GPU Name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "None")
# Out:
# GPU Available: True
# GPU Name: Tesla T4

# %% [markdown]
# **Install Required Packages**

# %%
# !apt-get update -qq
# !apt-get install -y aria2 ffmpeg > /dev/null 2>&1
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)

# %%
# !pip install --upgrade pip -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 31.3 MB/s eta 0:00:00

# %% [markdown]
# **Install libs**

# %%
import importlib.util

if importlib.util.find_spec('torch') is None:
    # !pip install torch torchvision torchaudio -q

print("pytorch ready")
# Out:
# pytorch ready

# %% [markdown]
# **Install clip**

# %%
# !pip install open-clip-torch -q
print("open-clip ready")
# Out:
# open-clip ready

# %% [markdown]
# Above did not worked hence tryingh !pip install git+https://github.com/openai/CLIP.git opencv-python scikit-learn -q

# %%
# !pip install git+https://github.com/openai/CLIP.git opencv-python scikit-learn -q
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for clip (pyproject.toml) ... done

# %%
# !pip install ftfy imageio opencv-python pillow regex requests scikit-learn scipy tqdm wandb gdown -q
print("dependencies installed")
# Out:
# dependencies installed

# %% [markdown]
# **Verify Installation**

# %%
required_modules = ['torch', 'torchvision', 'clip', 'open_clip', 'PIL', 'cv2' , 'numpy', "sklearn"]

for module in required_modules:
  spec = importlib.util.find_spec(module)
  status = 'installed' if spec else 'not installed'

  print(f'module: - {status}')
# Out:
# module: - installed
# module: - installed
# module: - installed
# module: - installed
# module: - installed
# module: - installed
# module: - installed
# module: - installed

# %%
import torch

print(f'torch version - {torch.__version__}')
print(f'CUDA available: {torch.cuda.is_available()}')

if(torch.cuda.is_available()):
  print(f'CUDA device: {torch.cuda.get_device_name(0)}')
  print(f'CUDA memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f}')
# Out:
# torch version - 2.11.0+cu128
# CUDA available: True
# CUDA device: Tesla T4
# CUDA memory: 15.6
